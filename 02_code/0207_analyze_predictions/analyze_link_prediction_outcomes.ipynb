# %% [markdown]
# ### what this notebook offers:
# ####  check the title of the start-end pairs in the specific link type

# %%
import pandas as pd
import re
import json
import xmltodict
pd.set_option('display.max_rows', 1000)


path = "/Users/yidesdo21/Projects/outputs/12_time_slicing/"

# %% [markdown]
# - Aim: use link prediction to find AD research discoveries
# - Scopes:
#     - corpus from Colin's collections,
#     - articles in 2019 as training data, and 2020 as testing data
#     - PTC and NIO annotators to represent the corpus
#     - co-occurrence on the article level to link the concepts
#     - time slicing to evaluate the model outcomes
# - Contributions:

# %% [markdown]
# ### The outcome we have last time

# %% [markdown]
# - issue 01: the start and end pairs are not interesting
#     - solution: use node types and link types to filter the outcomes
#         - PTC uids have types: Gene, Variant, Disease, Chemical, Species, and Cell Line
#         - NIO uids don't have types. I created the types by classifying uid's ontology prefix into four domains covered by NIO: cognitive functions, neuropsychological tests, Alzheimer's Disease, and brain areas. NIO uids have more than 10 prefixes for the ontologies. I classify them in the following way. The NIO uids have five types:
#             - MF --> AD - cognitive functions
#             - NPT --> AD - neuropsychological tests
#             - ADO, NDDUO --> AD - diagnosis, treatment, and molecular mechanisms
#             - FMA, NDDO --> AD - brain areas
#             - others --> AD - other
#         - The links are the combination of two nodes, e.g. "Gene -- AD - cognitive functions"
#     - outcomes:
#         - classify top 100 results with the link types
#         - check the start and end pairs with a certain link type
#     - thoughts:
#         - Can't tell the evidence for the link between the nodes by looking at the titles. Use co-occurrence on the abstract level as a link might be too weak.
#         - The node type schema might be colliding, e.g. an NIO uid with the type "AD - brain areas" can also be a Gene. This may be the reason of not returning the 'interesting' outcomes in the top.
#         - Filtering the outcomes with node types and link types seems to show more 'interesting' outcomes. But we might need a better node type schema. And the 'interestingness' issue may require work on the modeling and ranking stage, rather than the analysis stage. Also, we might need a way to define 'interestingness' if that is what we are evaluating. So far, the outcomes do answer the research question: what are the AD research discoveries by using link prediction models. It is just the case studies and manual analysis are hard to perform in the evaluation section.

# %% [markdown]
# ##### prefixes for NIO uids. NIO uids example: 'NDDO:NDDO_00000021'
#     Counter({'NDDO': 840,
#      'NDDUO': 217,
#      'dc': 15,
#      'go': 1,
#      'iao': 1,
#      'obo': 2376,
#      'oboInOwl': 10,
#      'rdfs': 1,
#      'AlzheimerOntology': 1306,
#      'OntoDT': 32,
#      'bfo': 9,
#      'http': 1,
#      'snap': 21,
#      'span': 17})
#
# ##### uids with 'obo' as prefix is more complex, e.g. "obo:BFO_0000001"
#     Counter({'BFO': 51,
#          'FMA': 619,
#          'GO': 66,
#          'IAO': 113,
#          'IDO': 1,
#          'MF': 59,
#          'NBO': 489,
#          'NCBITaxon': 13,
#          'ND': 108,
#          'NPT': 470,
#          'OBI': 273,
#          'OGMS': 11,
#          'PATO': 7,
#          'RO': 34,
#          'UBERON': 1,
#          'UO': 55,
#          'fma': 6})

# %% [markdown]
# ![title](img/four_domains_nio.png)

# %% [markdown]
# - issue 02: the limitation of using link prediction models
#     - We filter the training network and the testing network have the same set of nodes. The CN,PA,AA models use local neighbourhood similaries to predict the potential links. They can't predict the links between existing and new nodes. But the filtering ignores a lot of nodes and links.
#         - For instance, using link prediction models and using 2016 as the cut-off date, 31% of nodes will be ignored in the testing dataset, while 67% of nodes will be ignored in the training dataset.
#         - Look at 'predict_missing_links.ipynb' and the gr_ke table
#     - Though with the limitation of current link prediction models, the outcomes still answer the research question.

# %%
measure_19 = pd.read_csv(path+"features/measure_2019.csv")

# %%
measure_19
# Out:
#                                   start                               end  \
# 0       AlzheimerOntology:disease_onset                   obo:OBI_0000070
# 1                 AlzheimerOntology:APP     AlzheimerOntology:Populations
# 2                    NDDUO:Distribution                     obo:FMA_62493
# 3        AlzheimerOntology:inflammation                         snap:Site
# 4                        obo:GO_0007612                    obo:RO_0000081
# ...                                 ...                               ...
# 387114                             4851                     obo:FMA_61924
# 387115                             4851                      MESH:D019833
# 387116                             4851  AlzheimerOntology:Incidence_rate
# 387117                            14805                              4851
# 387118                             4851                      MESH:D013311
#
#          cn      pa         aa
# 0       263  160801  47.994927
# 1       235  155803  42.039344
# 2       232  149703  41.052517
# 3       230  146673  40.976206
# 4       229  139092  40.829211
# ...     ...     ...        ...
# 387114    0     600   0.000000
# 387115    0     250   0.000000
# 387116    0     370   0.000000
# 387117    0     330   0.000000
# 387118    0     530   0.000000
#
# [387119 rows x 5 columns]

# %%
## open the dictionary that links ptc uids and the ptc categories
with open(path+"metadata/"+"ptc_category_uid.txt") as f:
    lines = f.read().split("}, '")
    split = [l.split("': {'") for l in lines]
    
    ptc_uid_category = dict()
    # special case:"defaultdict(<class 'set'>, {'MESH:D009369", "Disease'"    
    ptc_uid_category["MESH:D009369"] = "Disease"

    for s in split[1:]:
        uid, category = s[0], s[1][:-1]
        ptc_uid_category[uid] = category

## open the dictionary that links nio uids and the ptc categories
with open(path+"metadata/"+'nio_category_uid.json', 'r') as fp:
    nio_uid_category = json.load(fp)
    
## add two uid dictionaries together
def merge(D1,D2):
    py={**D1,**D2}
    return py

uid_category =(merge(ptc_uid_category,nio_uid_category))

# %%
len(ptc_uid_category)
# Out:
# 10433

# %%
len(nio_uid_category)
# Out:
# 4847

# %%
len(uid_category)
# Out:
# 15280

# %%
## link nio uid to mention 
xml_path = "/Users/yidesdo21/Projects/inputs/dictionary/"

with open(xml_path+"nio_ado_case.xml") as f:
    nio_xml = f.read()

nio_parsed = xmltodict.parse(nio_xml)
nio_dict = nio_parsed["synonym"]["token"]
nio_uid_canonical = dict()

for nio in nio_dict:
    token_id, cano = nio["@id"], nio["@canonical"]
    nio_uid_canonical[token_id] = cano

## open the dictionary that links ptc uids and the ptc mentions
with open(path+"metadata/"+"ptc_mention_uid.txt") as f:
    lines = f.read().split("}, '")
    split = [l.split("': {'") for l in lines]
    
    ptc_uid_mention = dict()
    # special case:"defaultdict(<class 'set'>, {'MESH:D009369"    
    ptc_uid_mention["MESH:D009369"] = ["'cancer', 'spheroids', 'tumour', 'neoplasia', 'cancers', 'tumors', 'lesions', 'tumoral', 'neoplasms', 'neoplasm', 'keratocarcinomata', 'cancerous', 'carcinomas', 'Tumors', 'malignancies', 'tumor', 'carcinoma', 'malignancy', 'tumours', 'disease', 'Cancer'"]

    for s in split[1:]:
        uid, mention = s[0], s[1:]
        ptc_uid_mention[uid] = mention
        
## add two dictionaries together
uid_canonical =(merge(nio_uid_canonical,ptc_uid_mention))

# %%
len(nio_uid_canonical)
# Out:
# 4847

# %%
len(ptc_uid_mention)
# Out:
# 10433

# %%
len(uid_canonical)
# Out:
# 15280

# %%
## link article to the uid pairs 
with open(path+"metadata/"+'articles_with_anno.json', 'r') as fp:
    articles = json.load(fp)

# %%
def uid_to_article(start,end,yr):
    """enter a start uids and and end uid, and the year of the testing data,
    return the title of the article that both uids co-occur
    -- start: string, end: string, yr: string"""
    titles = list()
#     abstracts = list()
    
    for article in articles:
        year = article.get("year")
        if year == yr:
            ptc_uids,nio_uids = article.get("ptc_uids"),article.get("nio_uids")

            if ptc_uids is None:
                ptc_uids = list()
            if nio_uids is None:
                nio_uids = list()

            uids = []
            uids.extend(ptc_uids)
            uids.extend(nio_uids)

            if start in uids and end in uids:
                titles.append(article.get("title"))
#                 abstracts.append(article.get("abstract"))
    
    return titles

# %%
uid_to_article("AlzheimerOntology:APP","AlzheimerOntology:Populations","2020")
# Out:
# ['abrogation of type-i interferon signalling alters the microglial response to a beta(1-42)',
#  'computational analysis of alzheimer amyloid plaque composition in 2d-and elastically reconstructed 3d-maldi ms images']

# %%
measure_19['start_category'] = measure_19['start'].map(uid_category)
measure_19['end_category'] = measure_19['end'].map(uid_category)
measure_19['start_mention'] = measure_19['start'].map(uid_canonical)
measure_19['end_mention'] = measure_19['end'].map(uid_canonical)
# measure_19[['start_category', 'end_category']] = measure_19[['start_category','end_category']].fillna('AD_hallmark')
measure_19["link"] = measure_19['start_category'] + "+" + measure_19['end_category']
measure_19['rank'] = measure_19.index
measure_19 = measure_19[["rank","start","start_category","start_mention","end",
                         "end_category","end_mention","link","cn","pa","aa"]]
# measure_19.style.hide_index()

# %%
measure_19.iloc[:100]
# Out:
#     rank                                              start  \
# 0      0                    AlzheimerOntology:disease_onset
# 1      1                              AlzheimerOntology:APP
# 2      2                                 NDDUO:Distribution
# 3      3                     AlzheimerOntology:inflammation
# 4      4                                     obo:GO_0007612
# 5      5                                     obo:RO_0002211
# 6      6                                         NDDUO:rate
# 7      7                                              11820
# 8      8                          AlzheimerOntology:Tangles
# 9      9                          AlzheimerOntology:Fibrils
# 10    10                          AlzheimerOntology:Fibrils
# 11    11                          AlzheimerOntology:Fibrils
# 12    12     AlzheimerOntology:Positron_emission_tomography
# 13    13                          AlzheimerOntology:Fibrils
# 14    14                                              11820
# 15    15                                       MESH:D003643
# 16    16                      AlzheimerOntology:Populations
# 17    17                                      NDDUO:Cluster
# 18    18            AlzheimerOntology:Memory_problem_starts
# 19    19                     AlzheimerOntology:inflammation
# 20    20     AlzheimerOntology:Positron_emission_tomography
# 21    21                                         NDDUO:male
# 22    22   AlzheimerOntology:Late_Onset_Alzheimer_s_Disease
# 23    23                        AlzheimerOntology:tauopathy
# 24    24                          AlzheimerOntology:Tangles
# 25    25                        AlzheimerOntology:Microglia
# 26    26                      AlzheimerOntology:Populations
# 27    27                                     NDDUO:Symptoms
# 28    28           AlzheimerOntology:neurofibrillary_tangle
# 29    29                          AlzheimerOntology:Fibrils
# 30    30     AlzheimerOntology:Positron_emission_tomography
# 31    31                                              11820
# 32    32                                       NDDUO:Severe
# 33    33                                              11820
# 34    34                                                348
# 35    35                    AlzheimerOntology:Cohort_effect
# 36    36                                 NDDO:NDDO_00000107
# 37    37                                    NDDUO:inhibitor
# 38    38                                      NDDUO:Neurons
# 39    39                                       MESH:D008569
# 40    40                                       MESH:D009410
# 41    41                                     obo:ND_0000152
# 42    42                          AlzheimerOntology:Tangles
# 43    43                    AlzheimerOntology:disease_onset
# 44    44                       AlzheimerOntology:neurotoxic
# 45    45                   AlzheimerOntology:baseline_state
# 46    46                       AlzheimerOntology:Astrocytes
# 47    47                         AlzheimerOntology:Abeta_42
# 48    48       AlzheimerOntology:Magnetic_resonance_imaging
# 49    49                             AlzheimerOntology:APOE
# 50    50                        AlzheimerOntology:Microglia
# 51    51       AlzheimerOntology:Magnetic_resonance_imaging
# 52    52       AlzheimerOntology:Magnetic_resonance_imaging
# 53    53                         AlzheimerOntology:Abeta_42
# 54    54                                     obo:RO_0000081
# 55    55                     AlzheimerOntology:inflammation
# 56    56              AlzheimerOntology:cerebrospinal_fluid
# 57    57                     AlzheimerOntology:ApoE_Protein
# 58    58                              AlzheimerOntology:APP
# 59    59           AlzheimerOntology:neurofibrillary_tangle
# 60    60                        AlzheimerOntology:Receptors
# 61    61                          AlzheimerOntology:Fibrils
# 62    62          AlzheimerOntology:amyloid_beta_deposition
# 63    63                          AlzheimerOntology:Outcome
# 64    64                                       NDDUO:Gender
# 65    65                                      NDDUO:In_vivo
# 66    66               AlzheimerOntology:gender_risk_factor
# 67    67                    AlzheimerOntology:Brain_Imaging
# 68    68            AlzheimerOntology:Memory_problem_starts
# 69    69                          AlzheimerOntology:Outcome
# 70    70            AlzheimerOntology:Memory_problem_starts
# 71    71                               NDDUO:In_vivo_models
# 72    72          AlzheimerOntology:Cerebospinal_fluid_test
# 73    73  AlzheimerOntology:macrophage_colony_stimulatin...
# 74    74               AlzheimerOntology:Cerebospinal_Fluid
# 75    75                            AlzheimerOntology:white
# 76    76                                   NDDUO:Evaluation
# 77    77                                       MESH:D003643
# 78    78                                   NDDUO:Evaluation
# 79    79                            AlzheimerOntology:ratio
# 80    80                          AlzheimerOntology:Tangles
# 81    81                                       MESH:D003643
# 82    82                   AlzheimerOntology:baseline_state
# 83    83                   AlzheimerOntology:baseline_state
# 84    84           AlzheimerOntology:neurofibrillary_tangle
# 85    85                         AlzheimerOntology:Membrane
# 86    86                              AlzheimerOntology:APP
# 87    87                    AlzheimerOntology:Cohort_effect
# 88    88                        AlzheimerOntology:Receptors
# 89    89                          AlzheimerOntology:Tangles
# 90    90                               NDDUO:Clinical_trial
# 91    91                   AlzheimerOntology:baseline_state
# 92    92                         AlzheimerOntology:Genetics
# 93    93                                       NDDUO:Severe
# 94    94                                       MESH:D020258
# 95    95   AlzheimerOntology:Late_Onset_Alzheimer_s_Disease
# 96    96           AlzheimerOntology:neurofibrillary_tangle
# 97    97                        AlzheimerOntology:secretase
# 98    98                               NDDUO:Clinical_trial
# 99    99                         AlzheimerOntology:Membrane
#
#                                        start_category  \
# 0   AD -- Diagnosis, treatment, and molecular mech...
# 1   AD -- Diagnosis, treatment, and molecular mech...
# 2   AD -- Diagnosis, treatment, and molecular mech...
# 3   AD -- Diagnosis, treatment, and molecular mech...
# 4                                        AD -- Others
# 5                                        AD -- Others
# 6   AD -- Diagnosis, treatment, and molecular mech...
# 7                                                Gene
# 8   AD -- Diagnosis, treatment, and molecular mech...
# 9   AD -- Diagnosis, treatment, and molecular mech...
# 10  AD -- Diagnosis, treatment, and molecular mech...
# 11  AD -- Diagnosis, treatment, and molecular mech...
# 12  AD -- Diagnosis, treatment, and molecular mech...
# 13  AD -- Diagnosis, treatment, and molecular mech...
# 14                                               Gene
# 15                                            Disease
# 16  AD -- Diagnosis, treatment, and molecular mech...
# 17  AD -- Diagnosis, treatment, and molecular mech...
# 18  AD -- Diagnosis, treatment, and molecular mech...
# 19  AD -- Diagnosis, treatment, and molecular mech...
# 20  AD -- Diagnosis, treatment, and molecular mech...
# 21  AD -- Diagnosis, treatment, and molecular mech...
# 22  AD -- Diagnosis, treatment, and molecular mech...
# 23  AD -- Diagnosis, treatment, and molecular mech...
# 24  AD -- Diagnosis, treatment, and molecular mech...
# 25  AD -- Diagnosis, treatment, and molecular mech...
# 26  AD -- Diagnosis, treatment, and molecular mech...
# 27  AD -- Diagnosis, treatment, and molecular mech...
# 28  AD -- Diagnosis, treatment, and molecular mech...
# 29  AD -- Diagnosis, treatment, and molecular mech...
# 30  AD -- Diagnosis, treatment, and molecular mech...
# 31                                               Gene
# 32  AD -- Diagnosis, treatment, and molecular mech...
# 33                                               Gene
# 34                                               Gene
# 35  AD -- Diagnosis, treatment, and molecular mech...
# 36                                  AD -- Brain areas
# 37  AD -- Diagnosis, treatment, and molecular mech...
# 38  AD -- Diagnosis, treatment, and molecular mech...
# 39                                            Disease
# 40                                            Disease
# 41                                       AD -- Others
# 42  AD -- Diagnosis, treatment, and molecular mech...
# 43  AD -- Diagnosis, treatment, and molecular mech...
# 44  AD -- Diagnosis, treatment, and molecular mech...
# 45  AD -- Diagnosis, treatment, and molecular mech...
# 46  AD -- Diagnosis, treatment, and molecular mech...
# 47  AD -- Diagnosis, treatment, and molecular mech...
# 48  AD -- Diagnosis, treatment, and molecular mech...
# 49  AD -- Diagnosis, treatment, and molecular mech...
# 50  AD -- Diagnosis, treatment, and molecular mech...
# 51  AD -- Diagnosis, treatment, and molecular mech...
# 52  AD -- Diagnosis, treatment, and molecular mech...
# 53  AD -- Diagnosis, treatment, and molecular mech...
# 54                                       AD -- Others
# 55  AD -- Diagnosis, treatment, and molecular mech...
# 56  AD -- Diagnosis, treatment, and molecular mech...
# 57  AD -- Diagnosis, treatment, and molecular mech...
# 58  AD -- Diagnosis, treatment, and molecular mech...
# 59  AD -- Diagnosis, treatment, and molecular mech...
# 60  AD -- Diagnosis, treatment, and molecular mech...
# 61  AD -- Diagnosis, treatment, and molecular mech...
# 62  AD -- Diagnosis, treatment, and molecular mech...
# 63  AD -- Diagnosis, treatment, and molecular mech...
# 64  AD -- Diagnosis, treatment, and molecular mech...
# 65  AD -- Diagnosis, treatment, and molecular mech...
# 66  AD -- Diagnosis, treatment, and molecular mech...
# 67  AD -- Diagnosis, treatment, and molecular mech...
# 68  AD -- Diagnosis, treatment, and molecular mech...
# 69  AD -- Diagnosis, treatment, and molecular mech...
# 70  AD -- Diagnosis, treatment, and molecular mech...
# 71  AD -- Diagnosis, treatment, and molecular mech...
# 72  AD -- Diagnosis, treatment, and molecular mech...
# 73  AD -- Diagnosis, treatment, and molecular mech...
# 74  AD -- Diagnosis, treatment, and molecular mech...
# 75  AD -- Diagnosis, treatment, and molecular mech...
# 76  AD -- Diagnosis, treatment, and molecular mech...
# 77                                            Disease
# 78  AD -- Diagnosis, treatment, and molecular mech...
# 79  AD -- Diagnosis, treatment, and molecular mech...
# 80  AD -- Diagnosis, treatment, and molecular mech...
# 81                                            Disease
# 82  AD -- Diagnosis, treatment, and molecular mech...
# 83  AD -- Diagnosis, treatment, and molecular mech...
# 84  AD -- Diagnosis, treatment, and molecular mech...
# 85  AD -- Diagnosis, treatment, and molecular mech...
# 86  AD -- Diagnosis, treatment, and molecular mech...
# 87  AD -- Diagnosis, treatment, and molecular mech...
# 88  AD -- Diagnosis, treatment, and molecular mech...
# 89  AD -- Diagnosis, treatment, and molecular mech...
# 90  AD -- Diagnosis, treatment, and molecular mech...
# 91  AD -- Diagnosis, treatment, and molecular mech...
# 92  AD -- Diagnosis, treatment, and molecular mech...
# 93  AD -- Diagnosis, treatment, and molecular mech...
# 94                                            Disease
# 95  AD -- Diagnosis, treatment, and molecular mech...
# 96  AD -- Diagnosis, treatment, and molecular mech...
# 97  AD -- Diagnosis, treatment, and molecular mech...
# 98  AD -- Diagnosis, treatment, and molecular mech...
# 99  AD -- Diagnosis, treatment, and molecular mech...
#
#                                         start_mention  \
# 0                                       disease onset
# 1                                                 APP
# 2                                        Distribution
# 3                                        inflammation
# 4                                            learning
# 5                                           regulates
# 6                                                rate
# 7   [beta', 'A(beta)', 'AbetaPP', 'arcAbeta', '(Ab...
# 8                                              Tangle
# 9                                              Fibril
# 10                                             Fibril
# 11                                             Fibril
# 12                       Positron emission tomography
# 13                                             Fibril
# 14  [beta', 'A(beta)', 'AbetaPP', 'arcAbeta', '(Ab...
# 15  [Death', 'cancer', 'deaths', 'Dis', 'Mortality...
# 16                                         Population
# 17                                            Cluster
# 18                              Memory problem starts
# 19                                       inflammation
# 20                       Positron emission tomography
# 21                                               male
# 22                     Late Onset Alzheimer's Disease
# 23                                          tauopathy
# 24                                             Tangle
# 25                                          Microglia
# 26                                         Population
# 27                                    Symptom or sign
# 28                             neurofibrillary tangle
# 29                                             Fibril
# 30                       Positron emission tomography
# 31  [beta', 'A(beta)', 'AbetaPP', 'arcAbeta', '(Ab...
# 32                      thing related to severe stage
# 33  [beta', 'A(beta)', 'AbetaPP', 'arcAbeta', '(Ab...
# 34  [E', 'apoe', 'Apoe', 'APOE-4', 'hApoE', 'apoE'...
# 35                                      Cohort effect
# 36                                             cohort
# 37                                          inhibitor
# 38                                             Neuron
# 39  [dementia', 'loss', 'deposits', 'toxicity', 'd...
# 40  [loss', 'toxicity', 'decline', 'dysfunctions',...
# 41                                 Alzheimers disease
# 42                                             Tangle
# 43                                      disease onset
# 44                                         neurotoxic
# 45                                     baseline state
# 46                                          Astrocyte
# 47                                           Abeta 42
# 48                         Magnetic resonance imaging
# 49                                               APOE
# 50                                          Microglia
# 51                         Magnetic resonance imaging
# 52                         Magnetic resonance imaging
# 53                                           Abeta 42
# 54                                            role of
# 55                                       inflammation
# 56                                cerebrospinal fluid
# 57                                       ApoE Protein
# 58                                                APP
# 59                             neurofibrillary tangle
# 60                                           Receptor
# 61                                             Fibril
# 62                            Amyloid-beta deposition
# 63                                            Outcome
# 64                                             Gender
# 65                                      In vivo thing
# 66                                 gender risk factor
# 67                                      Brain Imaging
# 68                              Memory problem starts
# 69                                            Outcome
# 70                              Memory problem starts
# 71                                      In vivo model
# 72                            Cerebospinal fluid test
# 73               macrophage colony stimulating factor
# 74          protein circulating in Cerebospinal Fluid
# 75                                              white
# 76                                         Evaluation
# 77  [Death', 'cancer', 'deaths', 'Dis', 'Mortality...
# 78                                         Evaluation
# 79                                              ratio
# 80                                             Tangle
# 81  [Death', 'cancer', 'deaths', 'Dis', 'Mortality...
# 82                                     baseline state
# 83                                     baseline state
# 84                             neurofibrillary tangle
# 85                                           Membrane
# 86                                                APP
# 87                                      Cohort effect
# 88                                           Receptor
# 89                                             Tangle
# 90                    thing related to clinical trial
# 91                                     baseline state
# 92                                           Genotype
# 93                      thing related to severe stage
# 94  [Neuritogenic-neurotoxic', 'neurotoxicity', 'd...
# 95                     Late Onset Alzheimer's Disease
# 96                             neurofibrillary tangle
# 97                                          secretase
# 98                    thing related to clinical trial
# 99                                           Membrane
#
#                                                  end  \
# 0                                    obo:OBI_0000070
# 1                      AlzheimerOntology:Populations
# 2                                      obo:FMA_62493
# 3                                          snap:Site
# 4                                     obo:RO_0000081
# 5                                     obo:UO_0000036
# 6                                      obo:FMA_62493
# 7                          AlzheimerOntology:Tangles
# 8                                    obo:NBO_0000282
# 9                  AlzheimerOntology:age_risk_factor
# 10                                         NDDUO:Age
# 11  AlzheimerOntology:advanced_glycation_end_product
# 12                                     obo:FMA_62493
# 13                                  obo:PATO_0000011
# 14                     AlzheimerOntology:Populations
# 15                                        NDDUO:Mild
# 16                                   obo:NBO_0000282
# 17                                    obo:ND_0003004
# 18                                   obo:NPT_0015009
# 19                                    NDDUO:Sampling
# 20                                     NDDUO:Neurons
# 21                                   obo:OBI_0000070
# 22                                      NDDUO:Severe
# 23                                   obo:OBI_0000070
# 24                                         snap:Site
# 25                         AlzheimerOntology:Tangles
# 26                                    obo:RO_0002211
# 27                                  obo:OGMS_0000023
# 28                                   obo:NBO_0000282
# 29       AlzheimerOntology:Mild_cognitive_Impairment
# 30                    AlzheimerOntology:inflammation
# 31          AlzheimerOntology:neurofibrillary_tangle
# 32                                   obo:OBI_0000070
# 33                                               348
# 34                                   obo:NBO_0000282
# 35                                    NDDUO:In_vitro
# 36                                    NDDUO:In_vitro
# 37                                    obo:FMA_256135
# 38                                    obo:ND_0003004
# 39                                   obo:NBO_0000282
# 40                                      NDDUO:Severe
# 41                                   obo:NPT_0012026
# 42                                     NDDUO:Enzymes
# 43                                  NDDUO:Evaluation
# 44                                    NDDUO:Sampling
# 45                                     NDDUO:Cluster
# 46                                    NDDUO:Clinical
# 47                                        NDDUO:male
# 48       AlzheimerOntology:amyloid_precursor_protein
# 49                                      MESH:D009410
# 50          AlzheimerOntology:neurofibrillary_tangle
# 51                                   obo:BFO_0000023
# 52                                         snap:Role
# 53                          AlzheimerOntology:enzyme
# 54                                        rdfs:label
# 55                        AlzheimerOntology:mutation
# 56                                      MESH:D003643
# 57                   NDDUO:neurodegenerative_disease
# 58                  AlzheimerOntology:baseline_state
# 59                                         snap:Site
# 60                        AlzheimerOntology:mutation
# 61     AlzheimerOntology:procedures_using_biomarkers
# 62                                    NDDUO:Exposure
# 63                                     NDDUO:In_vivo
# 64                                     NDDUO:In_vivo
# 65                                     NDDUO:Outcome
# 66                                     NDDUO:In_vivo
# 67           AlzheimerOntology:Memory_problem_starts
# 68                                   obo:IAO_0000101
# 69                              NDDUO:In_vivo_models
# 70                                     NDDUO:Cluster
# 71                                     NDDUO:Outcome
# 72                      AlzheimerOntology:neurotoxic
# 73                      AlzheimerOntology:neurotoxic
# 74                      AlzheimerOntology:neurotoxic
# 75                                   obo:IAO_0000230
# 76                                NDDUO:Pathogenesis
# 77                                NDDUO:Pathogenesis
# 78                                   obo:IDO_0000666
# 79                                      MESH:D007249
# 80                        AlzheimerOntology:mutation
# 81                                   obo:IDO_0000666
# 82                                NDDUO:Pathogenesis
# 83                                   obo:IDO_0000666
# 84                                    obo:GO_0007612
# 85                                        NDDUO:gene
# 86                                  NDDUO:Evaluation
# 87                       AlzheimerOntology:Receptors
# 88                                NDDO:NDDO_00000107
# 89                          AlzheimerOntology:enzyme
# 90                                     NDDUO:Cluster
# 91                                   obo:NBO_0000282
# 92                                         snap:Site
# 93                                   NDDUO:inhibitor
# 94                                    NDDUO:Sampling
# 95                                        rdfs:label
# 96                                     NDDUO:Enzymes
# 97                                      MESH:D019636
# 98                                     NDDUO:Neurons
# 99                          AlzheimerOntology:cortex
#
#                                          end_category  \
# 0                                        AD -- Others
# 1   AD -- Diagnosis, treatment, and molecular mech...
# 2                                   AD -- Brain areas
# 3                                        AD -- Others
# 4                                        AD -- Others
# 5                                        AD -- Others
# 6                                   AD -- Brain areas
# 7   AD -- Diagnosis, treatment, and molecular mech...
# 8                                        AD -- Others
# 9   AD -- Diagnosis, treatment, and molecular mech...
# 10  AD -- Diagnosis, treatment, and molecular mech...
# 11  AD -- Diagnosis, treatment, and molecular mech...
# 12                                  AD -- Brain areas
# 13                                       AD -- Others
# 14  AD -- Diagnosis, treatment, and molecular mech...
# 15  AD -- Diagnosis, treatment, and molecular mech...
# 16                                       AD -- Others
# 17                                       AD -- Others
# 18                     AD -- Neuropsychological tests
# 19  AD -- Diagnosis, treatment, and molecular mech...
# 20  AD -- Diagnosis, treatment, and molecular mech...
# 21                                       AD -- Others
# 22  AD -- Diagnosis, treatment, and molecular mech...
# 23                                       AD -- Others
# 24                                       AD -- Others
# 25  AD -- Diagnosis, treatment, and molecular mech...
# 26                                       AD -- Others
# 27                                       AD -- Others
# 28                                       AD -- Others
# 29  AD -- Diagnosis, treatment, and molecular mech...
# 30  AD -- Diagnosis, treatment, and molecular mech...
# 31  AD -- Diagnosis, treatment, and molecular mech...
# 32                                       AD -- Others
# 33                                               Gene
# 34                                       AD -- Others
# 35  AD -- Diagnosis, treatment, and molecular mech...
# 36  AD -- Diagnosis, treatment, and molecular mech...
# 37                                  AD -- Brain areas
# 38                                       AD -- Others
# 39                                       AD -- Others
# 40  AD -- Diagnosis, treatment, and molecular mech...
# 41                     AD -- Neuropsychological tests
# 42  AD -- Diagnosis, treatment, and molecular mech...
# 43  AD -- Diagnosis, treatment, and molecular mech...
# 44  AD -- Diagnosis, treatment, and molecular mech...
# 45  AD -- Diagnosis, treatment, and molecular mech...
# 46  AD -- Diagnosis, treatment, and molecular mech...
# 47  AD -- Diagnosis, treatment, and molecular mech...
# 48  AD -- Diagnosis, treatment, and molecular mech...
# 49                                            Disease
# 50  AD -- Diagnosis, treatment, and molecular mech...
# 51                                       AD -- Others
# 52                                       AD -- Others
# 53  AD -- Diagnosis, treatment, and molecular mech...
# 54                                       AD -- Others
# 55  AD -- Diagnosis, treatment, and molecular mech...
# 56                                            Disease
# 57  AD -- Diagnosis, treatment, and molecular mech...
# 58  AD -- Diagnosis, treatment, and molecular mech...
# 59                                       AD -- Others
# 60  AD -- Diagnosis, treatment, and molecular mech...
# 61  AD -- Diagnosis, treatment, and molecular mech...
# 62  AD -- Diagnosis, treatment, and molecular mech...
# 63  AD -- Diagnosis, treatment, and molecular mech...
# 64  AD -- Diagnosis, treatment, and molecular mech...
# 65  AD -- Diagnosis, treatment, and molecular mech...
# 66  AD -- Diagnosis, treatment, and molecular mech...
# 67  AD -- Diagnosis, treatment, and molecular mech...
# 68                                       AD -- Others
# 69  AD -- Diagnosis, treatment, and molecular mech...
# 70  AD -- Diagnosis, treatment, and molecular mech...
# 71  AD -- Diagnosis, treatment, and molecular mech...
# 72  AD -- Diagnosis, treatment, and molecular mech...
# 73  AD -- Diagnosis, treatment, and molecular mech...
# 74  AD -- Diagnosis, treatment, and molecular mech...
# 75                                       AD -- Others
# 76  AD -- Diagnosis, treatment, and molecular mech...
# 77  AD -- Diagnosis, treatment, and molecular mech...
# 78                                       AD -- Others
# 79                                            Disease
# 80  AD -- Diagnosis, treatment, and molecular mech...
# 81                                       AD -- Others
# 82  AD -- Diagnosis, treatment, and molecular mech...
# 83                                       AD -- Others
# 84                                       AD -- Others
# 85  AD -- Diagnosis, treatment, and molecular mech...
# 86  AD -- Diagnosis, treatment, and molecular mech...
# 87  AD -- Diagnosis, treatment, and molecular mech...
# 88                                  AD -- Brain areas
# 89  AD -- Diagnosis, treatment, and molecular mech...
# 90  AD -- Diagnosis, treatment, and molecular mech...
# 91                                       AD -- Others
# 92                                       AD -- Others
# 93  AD -- Diagnosis, treatment, and molecular mech...
# 94  AD -- Diagnosis, treatment, and molecular mech...
# 95                                       AD -- Others
# 96  AD -- Diagnosis, treatment, and molecular mech...
# 97                                            Disease
# 98  AD -- Diagnosis, treatment, and molecular mech...
# 99  AD -- Diagnosis, treatment, and molecular mech...
#
#                                           end_mention  \
# 0                                               assay
# 1                                          Population
# 2                                         Hippocampus
# 3                                                site
# 4                                             role of
# 5                                                year
# 6                                         Hippocampus
# 7                                              Tangle
# 8                                              liking
# 9                                     age risk factor
# 10                                                Age
# 11                     advanced glycation end product
# 12                                        Hippocampus
# 13                                                age
# 14                                         Population
# 15                        thing related to mild stage
# 16                                             liking
# 17                          mild cognitive impairment
# 18                                                 no
# 19                                           Sampling
# 20                                             Neuron
# 21                                              assay
# 22                      thing related to severe stage
# 23                                              assay
# 24                                               site
# 25                                             Tangle
# 26                                          regulates
# 27                                          phenotype
# 28                                             liking
# 29                          Mild cognitive Impairment
# 30                                       inflammation
# 31                             neurofibrillary tangle
# 32                                              assay
# 33  [E', 'apoe', 'Apoe', 'APOE-4', 'hApoE', 'apoE'...
# 34                                             liking
# 35                                     In vitro thing
# 36                                     In vitro thing
# 37                                               Body
# 38                          mild cognitive impairment
# 39                                             liking
# 40                      thing related to severe stage
# 41                                 cognitive function
# 42                                 Enzymatic activity
# 43                                         Evaluation
# 44                                           Sampling
# 45                                            Cluster
# 46                                     Clinical thing
# 47                                               male
# 48                          amyloid precursor protein
# 49  [loss', 'toxicity', 'decline', 'dysfunctions',...
# 50                             neurofibrillary tangle
# 51                                               role
# 52                                               role
# 53                                             enzyme
# 54                                              label
# 55                                           mutation
# 56  [Death', 'cancer', 'deaths', 'Dis', 'Mortality...
# 57                          neurodegenerative disease
# 58                                     baseline state
# 59                                               site
# 60                                           mutation
# 61        thing related to procedure using biomarkers
# 62                                           Exposure
# 63                                      In vivo thing
# 64                                      In vivo thing
# 65                           Thing related to outcome
# 66                                      In vivo thing
# 67                              Memory problem starts
# 68                                              image
# 69                                      In vivo model
# 70                                            Cluster
# 71                           Thing related to outcome
# 72                                         neurotoxic
# 73                                         neurotoxic
# 74                                         neurotoxic
# 75                                              other
# 76                      thing related to pathogenesis
# 77                      thing related to pathogenesis
# 78                    human pathogenicity disposition
# 79  [impairs', 'inflammation', 'disorder', 'reacti...
# 80                                           mutation
# 81                    human pathogenicity disposition
# 82                      thing related to pathogenesis
# 83                    human pathogenicity disposition
# 84                                           learning
# 85                                               gene
# 86                                         Evaluation
# 87                                           Receptor
# 88                                             cohort
# 89                                             enzyme
# 90                                            Cluster
# 91                                             liking
# 92                                               site
# 93                                          inhibitor
# 94                                           Sampling
# 95                                              label
# 96                                 Enzymatic activity
# 97  [conditions', 'dementia', 'illnesses', 'loss',...
# 98                                             Neuron
# 99                                             cortex
#
#                                                  link   cn      pa         aa
# 0   AD -- Diagnosis, treatment, and molecular mech...  263  160801  47.994927
# 1   AD -- Diagnosis, treatment, and molecular mech...  235  155803  42.039344
# 2   AD -- Diagnosis, treatment, and molecular mech...  232  149703  41.052517
# 3   AD -- Diagnosis, treatment, and molecular mech...  230  146673  40.976206
# 4                           AD -- Others+AD -- Others  229  139092  40.829211
# 5                           AD -- Others+AD -- Others  227  161664  40.584781
# 6   AD -- Diagnosis, treatment, and molecular mech...  225  142197  39.817861
# 7   Gene+AD -- Diagnosis, treatment, and molecular...  224  149292  40.133814
# 8   AD -- Diagnosis, treatment, and molecular mech...  224  136764  40.044052
# 9   AD -- Diagnosis, treatment, and molecular mech...  223  160892  40.315670
# 10  AD -- Diagnosis, treatment, and molecular mech...  223  160892  40.315670
# 11  AD -- Diagnosis, treatment, and molecular mech...  223  160892  40.315670
# 12  AD -- Diagnosis, treatment, and molecular mech...  223  148452  39.663935
# 13  AD -- Diagnosis, treatment, and molecular mech...  223  160892  40.315670
# 14  Gene+AD -- Diagnosis, treatment, and molecular...  222  148863  39.625511
# 15  Disease+AD -- Diagnosis, treatment, and molecu...  220  141148  39.299714
# 16  AD -- Diagnosis, treatment, and molecular mech...  220  136371  39.236449
# 17  AD -- Diagnosis, treatment, and molecular mech...  216  154850  38.596522
# 18  AD -- Diagnosis, treatment, and molecular mech...  215  127236  38.228688
# 19  AD -- Diagnosis, treatment, and molecular mech...  215  129645  37.832968
# 20  AD -- Diagnosis, treatment, and molecular mech...  215  169100  38.032234
# 21  AD -- Diagnosis, treatment, and molecular mech...  214  136340  37.796743
# 22  AD -- Diagnosis, treatment, and molecular mech...  214  109340  37.692831
# 23  AD -- Diagnosis, treatment, and molecular mech...  213  129122  37.552010
# 24  AD -- Diagnosis, treatment, and molecular mech...  213  131892  37.583850
# 25  AD -- Diagnosis, treatment, and molecular mech...  212  120756  37.368613
# 26  AD -- Diagnosis, treatment, and molecular mech...  210  133248  37.321772
# 27  AD -- Diagnosis, treatment, and molecular mech...  210  114504  36.805863
# 28  AD -- Diagnosis, treatment, and molecular mech...  209  124188  36.962508
# 29  AD -- Diagnosis, treatment, and molecular mech...  209  158556  37.147685
# 30  AD -- Diagnosis, treatment, and molecular mech...  209  137772  36.842774
# 31  Gene+AD -- Diagnosis, treatment, and molecular...  208  135564  36.768447
# 32  AD -- Diagnosis, treatment, and molecular mech...  208  123508  36.841551
# 33                                          Gene+Gene  208  138138  37.024926
# 34                                  Gene+AD -- Others  208  126546  36.868345
# 35  AD -- Diagnosis, treatment, and molecular mech...  208  147658  36.771305
# 36  AD -- Brain areas+AD -- Diagnosis, treatment, ...  208  147658  36.771305
# 37  AD -- Diagnosis, treatment, and molecular mech...  206  130476  36.204044
# 38  AD -- Diagnosis, treatment, and molecular mech...  206  154850  36.636027
# 39                               Disease+AD -- Others  206  124974  36.299308
# 40  Disease+AD -- Diagnosis, treatment, and molecu...  206  119812  36.439180
# 41        AD -- Others+AD -- Neuropsychological tests  206  108468  36.325762
# 42  AD -- Diagnosis, treatment, and molecular mech...  206  111708  36.122268
# 43  AD -- Diagnosis, treatment, and molecular mech...  205  111879  36.015321
# 44  AD -- Diagnosis, treatment, and molecular mech...  205  127635  36.196493
# 45  AD -- Diagnosis, treatment, and molecular mech...  204  149625  36.271387
# 46  AD -- Diagnosis, treatment, and molecular mech...  204  141056  36.486931
# 47  AD -- Diagnosis, treatment, and molecular mech...  204  113560  35.789692
# 48  AD -- Diagnosis, treatment, and molecular mech...  204  151256  36.156725
# 49  AD -- Diagnosis, treatment, and molecular mech...  204  122924  35.703188
# 50  AD -- Diagnosis, treatment, and molecular mech...  203  109652  35.623114
# 51  AD -- Diagnosis, treatment, and molecular mech...  203  163812  35.960865
# 52  AD -- Diagnosis, treatment, and molecular mech...  203  163812  35.960865
# 53  AD -- Diagnosis, treatment, and molecular mech...  202  101870  35.315315
# 54                          AD -- Others+AD -- Others  202  110550  35.864241
# 55  AD -- Diagnosis, treatment, and molecular mech...  202  126162  35.334911
# 56  AD -- Diagnosis, treatment, and molecular mech...  201  120132  35.251677
# 57  AD -- Diagnosis, treatment, and molecular mech...  201  134493  35.347240
# 58  AD -- Diagnosis, treatment, and molecular mech...  200  141435  35.261771
# 59  AD -- Diagnosis, treatment, and molecular mech...  200  119764  35.010429
# 60  AD -- Diagnosis, treatment, and molecular mech...  200  122902  35.302261
# 61  AD -- Diagnosis, treatment, and molecular mech...  200  138116  35.411673
# 62  AD -- Diagnosis, treatment, and molecular mech...  200  113518  34.983852
# 63  AD -- Diagnosis, treatment, and molecular mech...  200  130339  34.965761
# 64  AD -- Diagnosis, treatment, and molecular mech...  200  127633  35.195358
# 65  AD -- Diagnosis, treatment, and molecular mech...  200  130339  34.965761
# 66  AD -- Diagnosis, treatment, and molecular mech...  200  127633  35.195358
# 67  AD -- Diagnosis, treatment, and molecular mech...  199  123096  34.929367
# 68  AD -- Diagnosis, treatment, and molecular mech...  199  123096  34.929367
# 69  AD -- Diagnosis, treatment, and molecular mech...  199  141610  34.836765
# 70  AD -- Diagnosis, treatment, and molecular mech...  199  131100  34.934125
# 71  AD -- Diagnosis, treatment, and molecular mech...  199  141610  34.836765
# 72  AD -- Diagnosis, treatment, and molecular mech...  199  132588  34.882914
# 73  AD -- Diagnosis, treatment, and molecular mech...  199  132588  34.882914
# 74  AD -- Diagnosis, treatment, and molecular mech...  199  132588  34.882914
# 75  AD -- Diagnosis, treatment, and molecular mech...  198  113373  34.994470
# 76  AD -- Diagnosis, treatment, and molecular mech...  198  112995  34.843813
# 77  Disease+AD -- Diagnosis, treatment, and molecu...  198  115020  34.723443
# 78  AD -- Diagnosis, treatment, and molecular mech...  198  112995  34.843813
# 79  AD -- Diagnosis, treatment, and molecular mech...  198  123711  34.734339
# 80  AD -- Diagnosis, treatment, and molecular mech...  198  113448  34.613277
# 81                               Disease+AD -- Others  198  115020  34.723443
# 82  AD -- Diagnosis, treatment, and molecular mech...  197  127575  34.727811
# 83  AD -- Diagnosis, treatment, and molecular mech...  197  127575  34.727811
# 84  AD -- Diagnosis, treatment, and molecular mech...  197  109336  34.283283
# 85  AD -- Diagnosis, treatment, and molecular mech...  197  117806  35.020979
# 86  AD -- Diagnosis, treatment, and molecular mech...  197  125271  34.535133
# 87  AD -- Diagnosis, treatment, and molecular mech...  197  139867  34.280298
# 88  AD -- Diagnosis, treatment, and molecular mech...  197  139867  34.280298
# 89  AD -- Diagnosis, treatment, and molecular mech...  197  106140  34.344149
# 90  AD -- Diagnosis, treatment, and molecular mech...  197  129200  34.521918
# 91  AD -- Diagnosis, treatment, and molecular mech...  196  123795  34.627446
# 92  AD -- Diagnosis, treatment, and molecular mech...  196  109152  34.440832
# 93  AD -- Diagnosis, treatment, and molecular mech...  196  121044  34.420556
# 94  Disease+AD -- Diagnosis, treatment, and molecu...  196  117920  34.486635
# 95  AD -- Diagnosis, treatment, and molecular mech...  196   97625  34.343433
# 96  AD -- Diagnosis, treatment, and molecular mech...  195  101436  34.014307
# 97  AD -- Diagnosis, treatment, and molecular mech...  195  135422  34.992562
# 98  AD -- Diagnosis, treatment, and molecular mech...  195  129200  34.225266
# 99  AD -- Diagnosis, treatment, and molecular mech...  194  121992  34.156121

# %%
## no NA values in the dataframe -- each uid has a category 
# measure_19.isnull().sum()

# %%
# cn model -- link categories of top 100 results
measure_19.iloc[:100]["link"].value_counts()
# Out:
# AD -- Diagnosis, treatment, and molecular mechanisms+AD -- Diagnosis, treatment, and molecular mechanisms    49
# AD -- Diagnosis, treatment, and molecular mechanisms+AD -- Others                                            25
# AD -- Diagnosis, treatment, and molecular mechanisms+AD -- Brain areas                                        5
# Disease+AD -- Diagnosis, treatment, and molecular mechanisms                                                  4
# AD -- Diagnosis, treatment, and molecular mechanisms+Disease                                                  4
# Gene+AD -- Diagnosis, treatment, and molecular mechanisms                                                     3
# AD -- Others+AD -- Others                                                                                     3
# Disease+AD -- Others                                                                                          2
# AD -- Brain areas+AD -- Diagnosis, treatment, and molecular mechanisms                                        1
# Gene+AD -- Others                                                                                             1
# AD -- Diagnosis, treatment, and molecular mechanisms+AD -- Neuropsychological tests                           1
# Gene+Gene                                                                                                     1
# AD -- Others+AD -- Neuropsychological tests                                                                   1
# Name: link, dtype: int64

# %%
# check pairs with specific links
measure_19_100 = measure_19.iloc[:100]

def check_links(link):
    check_link = link
    measure_19_100_link = measure_19_100[measure_19_100['link']==check_link]
    return measure_19_100_link[["rank","start","start_mention","end","end_mention","cn"]]

# %%
check_links(link="AD -- Diagnosis, treatment, and molecular mechanisms+AD -- Diagnosis, treatment, and molecular mechanisms")
# Out:
#     rank                                              start  \
# 1      1                              AlzheimerOntology:APP
# 9      9                          AlzheimerOntology:Fibrils
# 10    10                          AlzheimerOntology:Fibrils
# 11    11                          AlzheimerOntology:Fibrils
# 19    19                     AlzheimerOntology:inflammation
# 20    20     AlzheimerOntology:Positron_emission_tomography
# 22    22   AlzheimerOntology:Late_Onset_Alzheimer_s_Disease
# 25    25                        AlzheimerOntology:Microglia
# 29    29                          AlzheimerOntology:Fibrils
# 30    30     AlzheimerOntology:Positron_emission_tomography
# 35    35                    AlzheimerOntology:Cohort_effect
# 42    42                          AlzheimerOntology:Tangles
# 43    43                    AlzheimerOntology:disease_onset
# 44    44                       AlzheimerOntology:neurotoxic
# 45    45                   AlzheimerOntology:baseline_state
# 46    46                       AlzheimerOntology:Astrocytes
# 47    47                         AlzheimerOntology:Abeta_42
# 48    48       AlzheimerOntology:Magnetic_resonance_imaging
# 50    50                        AlzheimerOntology:Microglia
# 53    53                         AlzheimerOntology:Abeta_42
# 55    55                     AlzheimerOntology:inflammation
# 57    57                     AlzheimerOntology:ApoE_Protein
# 58    58                              AlzheimerOntology:APP
# 60    60                        AlzheimerOntology:Receptors
# 61    61                          AlzheimerOntology:Fibrils
# 62    62          AlzheimerOntology:amyloid_beta_deposition
# 63    63                          AlzheimerOntology:Outcome
# 64    64                                       NDDUO:Gender
# 65    65                                      NDDUO:In_vivo
# 66    66               AlzheimerOntology:gender_risk_factor
# 67    67                    AlzheimerOntology:Brain_Imaging
# 69    69                          AlzheimerOntology:Outcome
# 70    70            AlzheimerOntology:Memory_problem_starts
# 71    71                               NDDUO:In_vivo_models
# 72    72          AlzheimerOntology:Cerebospinal_fluid_test
# 73    73  AlzheimerOntology:macrophage_colony_stimulatin...
# 74    74               AlzheimerOntology:Cerebospinal_Fluid
# 76    76                                   NDDUO:Evaluation
# 80    80                          AlzheimerOntology:Tangles
# 82    82                   AlzheimerOntology:baseline_state
# 85    85                         AlzheimerOntology:Membrane
# 86    86                              AlzheimerOntology:APP
# 87    87                    AlzheimerOntology:Cohort_effect
# 89    89                          AlzheimerOntology:Tangles
# 90    90                               NDDUO:Clinical_trial
# 93    93                                       NDDUO:Severe
# 96    96           AlzheimerOntology:neurofibrillary_tangle
# 98    98                               NDDUO:Clinical_trial
# 99    99                         AlzheimerOntology:Membrane
#
#                                 start_mention  \
# 1                                         APP
# 9                                      Fibril
# 10                                     Fibril
# 11                                     Fibril
# 19                               inflammation
# 20               Positron emission tomography
# 22             Late Onset Alzheimer's Disease
# 25                                  Microglia
# 29                                     Fibril
# 30               Positron emission tomography
# 35                              Cohort effect
# 42                                     Tangle
# 43                              disease onset
# 44                                 neurotoxic
# 45                             baseline state
# 46                                  Astrocyte
# 47                                   Abeta 42
# 48                 Magnetic resonance imaging
# 50                                  Microglia
# 53                                   Abeta 42
# 55                               inflammation
# 57                               ApoE Protein
# 58                                        APP
# 60                                   Receptor
# 61                                     Fibril
# 62                    Amyloid-beta deposition
# 63                                    Outcome
# 64                                     Gender
# 65                              In vivo thing
# 66                         gender risk factor
# 67                              Brain Imaging
# 69                                    Outcome
# 70                      Memory problem starts
# 71                              In vivo model
# 72                    Cerebospinal fluid test
# 73       macrophage colony stimulating factor
# 74  protein circulating in Cerebospinal Fluid
# 76                                 Evaluation
# 80                                     Tangle
# 82                             baseline state
# 85                                   Membrane
# 86                                        APP
# 87                              Cohort effect
# 89                                     Tangle
# 90            thing related to clinical trial
# 93              thing related to severe stage
# 96                     neurofibrillary tangle
# 98            thing related to clinical trial
# 99                                   Membrane
#
#                                                  end  \
# 1                      AlzheimerOntology:Populations
# 9                  AlzheimerOntology:age_risk_factor
# 10                                         NDDUO:Age
# 11  AlzheimerOntology:advanced_glycation_end_product
# 19                                    NDDUO:Sampling
# 20                                     NDDUO:Neurons
# 22                                      NDDUO:Severe
# 25                         AlzheimerOntology:Tangles
# 29       AlzheimerOntology:Mild_cognitive_Impairment
# 30                    AlzheimerOntology:inflammation
# 35                                    NDDUO:In_vitro
# 42                                     NDDUO:Enzymes
# 43                                  NDDUO:Evaluation
# 44                                    NDDUO:Sampling
# 45                                     NDDUO:Cluster
# 46                                    NDDUO:Clinical
# 47                                        NDDUO:male
# 48       AlzheimerOntology:amyloid_precursor_protein
# 50          AlzheimerOntology:neurofibrillary_tangle
# 53                          AlzheimerOntology:enzyme
# 55                        AlzheimerOntology:mutation
# 57                   NDDUO:neurodegenerative_disease
# 58                  AlzheimerOntology:baseline_state
# 60                        AlzheimerOntology:mutation
# 61     AlzheimerOntology:procedures_using_biomarkers
# 62                                    NDDUO:Exposure
# 63                                     NDDUO:In_vivo
# 64                                     NDDUO:In_vivo
# 65                                     NDDUO:Outcome
# 66                                     NDDUO:In_vivo
# 67           AlzheimerOntology:Memory_problem_starts
# 69                              NDDUO:In_vivo_models
# 70                                     NDDUO:Cluster
# 71                                     NDDUO:Outcome
# 72                      AlzheimerOntology:neurotoxic
# 73                      AlzheimerOntology:neurotoxic
# 74                      AlzheimerOntology:neurotoxic
# 76                                NDDUO:Pathogenesis
# 80                        AlzheimerOntology:mutation
# 82                                NDDUO:Pathogenesis
# 85                                        NDDUO:gene
# 86                                  NDDUO:Evaluation
# 87                       AlzheimerOntology:Receptors
# 89                          AlzheimerOntology:enzyme
# 90                                     NDDUO:Cluster
# 93                                   NDDUO:inhibitor
# 96                                     NDDUO:Enzymes
# 98                                     NDDUO:Neurons
# 99                          AlzheimerOntology:cortex
#
#                                     end_mention   cn
# 1                                    Population  235
# 9                               age risk factor  223
# 10                                          Age  223
# 11               advanced glycation end product  223
# 19                                     Sampling  215
# 20                                       Neuron  215
# 22                thing related to severe stage  214
# 25                                       Tangle  212
# 29                    Mild cognitive Impairment  209
# 30                                 inflammation  209
# 35                               In vitro thing  208
# 42                           Enzymatic activity  206
# 43                                   Evaluation  205
# 44                                     Sampling  205
# 45                                      Cluster  204
# 46                               Clinical thing  204
# 47                                         male  204
# 48                    amyloid precursor protein  204
# 50                       neurofibrillary tangle  203
# 53                                       enzyme  202
# 55                                     mutation  202
# 57                    neurodegenerative disease  201
# 58                               baseline state  200
# 60                                     mutation  200
# 61  thing related to procedure using biomarkers  200
# 62                                     Exposure  200
# 63                                In vivo thing  200
# 64                                In vivo thing  200
# 65                     Thing related to outcome  200
# 66                                In vivo thing  200
# 67                        Memory problem starts  199
# 69                                In vivo model  199
# 70                                      Cluster  199
# 71                     Thing related to outcome  199
# 72                                   neurotoxic  199
# 73                                   neurotoxic  199
# 74                                   neurotoxic  199
# 76                thing related to pathogenesis  198
# 80                                     mutation  198
# 82                thing related to pathogenesis  197
# 85                                         gene  197
# 86                                   Evaluation  197
# 87                                     Receptor  197
# 89                                       enzyme  197
# 90                                      Cluster  197
# 93                                    inhibitor  196
# 96                           Enzymatic activity  195
# 98                                       Neuron  195
# 99                                       cortex  194

# %%
check_links(link="AD -- Diagnosis, treatment, and molecular mechanisms+AD -- Brain areas")
# Out:
#     rank                                           start  \
# 2      2                              NDDUO:Distribution
# 6      6                                      NDDUO:rate
# 12    12  AlzheimerOntology:Positron_emission_tomography
# 37    37                                 NDDUO:inhibitor
# 88    88                     AlzheimerOntology:Receptors
#
#                    start_mention                 end  end_mention   cn
# 2                   Distribution       obo:FMA_62493  Hippocampus  232
# 6                           rate       obo:FMA_62493  Hippocampus  225
# 12  Positron emission tomography       obo:FMA_62493  Hippocampus  223
# 37                     inhibitor      obo:FMA_256135         Body  206
# 88                      Receptor  NDDO:NDDO_00000107       cohort  197

# %%
check_links(link="AD -- Diagnosis, treatment, and molecular mechanisms+Disease")
# Out:
#     rank                                  start        start_mention  \
# 49    49                 AlzheimerOntology:APOE                 APOE
# 56    56  AlzheimerOntology:cerebrospinal_fluid  cerebrospinal fluid
# 79    79                AlzheimerOntology:ratio                ratio
# 97    97            AlzheimerOntology:secretase            secretase
#
#              end                                        end_mention   cn
# 49  MESH:D009410  [loss', 'toxicity', 'decline', 'dysfunctions',...  204
# 56  MESH:D003643  [Death', 'cancer', 'deaths', 'Dis', 'Mortality...  201
# 79  MESH:D007249  [impairs', 'inflammation', 'disorder', 'reacti...  198
# 97  MESH:D019636  [conditions', 'dementia', 'illnesses', 'loss',...  195

# %%
check_links(link="Disease+AD -- Diagnosis, treatment, and molecular mechanisms")
# Out:
#     rank         start                                      start_mention  \
# 15    15  MESH:D003643  [Death', 'cancer', 'deaths', 'Dis', 'Mortality...
# 40    40  MESH:D009410  [loss', 'toxicity', 'decline', 'dysfunctions',...
# 77    77  MESH:D003643  [Death', 'cancer', 'deaths', 'Dis', 'Mortality...
# 94    94  MESH:D020258  [Neuritogenic-neurotoxic', 'neurotoxicity', 'd...
#
#                    end                    end_mention   cn
# 15          NDDUO:Mild    thing related to mild stage  220
# 40        NDDUO:Severe  thing related to severe stage  206
# 77  NDDUO:Pathogenesis  thing related to pathogenesis  198
# 94      NDDUO:Sampling                       Sampling  196

# %%
check_links(link="Gene+AD -- Diagnosis, treatment, and molecular mechanisms")
# Out:
#     rank  start                                      start_mention  \
# 7      7  11820  [beta', 'A(beta)', 'AbetaPP', 'arcAbeta', '(Ab...
# 14    14  11820  [beta', 'A(beta)', 'AbetaPP', 'arcAbeta', '(Ab...
# 31    31  11820  [beta', 'A(beta)', 'AbetaPP', 'arcAbeta', '(Ab...
#
#                                          end             end_mention   cn
# 7                  AlzheimerOntology:Tangles                  Tangle  224
# 14             AlzheimerOntology:Populations              Population  222
# 31  AlzheimerOntology:neurofibrillary_tangle  neurofibrillary tangle  208

# %%
# check the title of the start-end pairs in the specific link
# a high cn value doesn't necessarily mean the pairs co-occur in the testing network
## need to be careful, the third argument of the uid_to_article needs to be revised when with different testing data
measure_19_100_link["title"] = measure_19_100_link.apply(lambda x: uid_to_article(x['start'], x['end'], "2020"), axis=1)
print(check_link)
result = measure_19_100_link[["rank","start","start_mention","end","end_mention","cn","title"]].to_json(orient="records")
parsed = json.loads(result)
parsed
# Out:
# AD -- Diagnosis, treatment, and molecular mechanisms+Disease
# <ipython-input-45-ece51a50acaf>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   measure_19_100_link["title"] = measure_19_100_link.apply(lambda x: uid_to_article(x['start'], x['end'], "2020"), axis=1)
# [{'rank': 49,
#   'start': 'AlzheimerOntology:APOE',
#   'start_mention': 'APOE',
#   'end': 'MESH:D009410',
#   'end_mention': ["loss', 'toxicity', 'decline', 'dysfunctions', 'disorders', 'mitochondria', 'homeostasis', 'atrophy', 'Dysfunction', 'networks', 'damage', 'deficits', 'dysfunction/degeneration', 'neuritic', 'disorder', 'viability', 'ectopias', 'Toxicity', 'impairment', 'diseases', 'abnormalities', 'bodies', 'activity', 'death', 'linked', 'soma', 'necrosis', 'endocytosis', 'somata', 'glucose', 'dendritic', 'defects', 'alterations', 'metabolism', 'malfunction', 'hyperexcitation', 'hyperactivation', 'astrogliosis', 'injuries', 'dyshomeostasis', 'neuroinflammation', 'glia', 'dysfunction', 'excitotoxicity', 'function', 'dendrites', 'pyroptosis', 'accumulation', 'neuron', 'perturbation', 'degeneration', 'Injury', 'injury', 'insulin', 'Death', 'deaths', 'axons', 'neurons', 'dystrophy', 'Abeta', 'hyperhomocysteinemic', 'colonies', 'hyperexcitability', 'hypometabolism', 'spinal', 'brain', 'neuronal', 'axonal', 'impairments', 'deficiency', 'dependence', 'disease'"],
#   'cn': 204,
#   'title': [[], []]},
#  {'rank': 56,
#   'start': 'AlzheimerOntology:cerebrospinal_fluid',
#   'start_mention': 'cerebrospinal fluid',
#   'end': 'MESH:D003643',
#   'end_mention': ["Death', 'cancer', 'deaths', 'Dis', 'Mortality', 'mortality', 'syndrome', 'mortalities', 'muscle', 'oligodendrocytes', 'died', 'Di-scFv', 'proteins', 'Deaths', 'death', 'prion-infected', 'di', 'injury'"],
#   'cn': 201,
#   'title': [["plasma p-tau181 accurately predicts alzheimer's disease pathology at least 8 years prior to post-mortem and improves the clinical characterisation of cognitive decline",
#     "clinical and biomarker changes of alzheimer's disease in adults with down syndrome: a cross-sectional study",
#     "annexin a5 prevents amyloid-beta-induced toxicity in choroid plexus: implication for alzheimer's disease"],
#    ["the neuropathological confirmation of amyloid-beta (a beta) plaques and tau neurofibrillary tangles (nft) remains the gold standard for a definitive diagnosis of alzheimer's disease (ad). nowadays, the in vivo diagnosis of ad is greatly aided by both cerebrospinal fluid (csf) and positron emission tomography (pet) biomarkers. although highly accurate, their broad implementation is restricted by high cost, limited accessibility and invasiveness. we recently developed a high-performance, ultrasensitive immunoassay for the quantification of tau phosphorylated at threonine-181 (p-tau181) in plasma, which identifies ad pathophysiology with high accuracy. however, it remains unclear whether plasma p-tau181, measured years before the death, can predict the eventual neuropathological confirmation of ad, and successfully discriminates ad from non-ad dementia pathologies. we studied a unique cohort of 115 individuals with longitudinal blood collections with clinical evaluation at 8, 4 and 2 years prior to neuropathological assessment at death. the results demonstrate that plasma p-tau181 associates better with ad neuropathology and braak staging than a clinical diagnosis 8 years before post-mortem. moreover, while all patients had a diagnosis of ad dementia during life, plasma p-tau181 proved to discriminate ad from non-ad pathologies with high accuracy (auc = 97.4%, 95% ci = 94.1-100%) even 8 years before death. additionally, the longitudinal trajectory of plasma p-tau181 was assessed in all patients. we found that the main increases in plasma p-tau181 occurred between 8 and 4 years prior to death in patients with ad neuropathology and later plateauing. in contrast, non-ad pathologies and controls exhibited minor, albeit significant, increases in p-tau181 up until death. overall, our study demonstrates that plasma p-tau181 is highly predictive and specific of ad neuropathology years before post-mortem examination. these data add further support for the use of plasma p-tau181 to aid clinical management in primary care and recruitment for clinical trials.",
#     "background: alzheimer's disease and its complications are the leading cause of death in adults with down syndrome. studies have assessed alzheimer's disease in individuals with down syndrome, but the natural history of biomarker changes in down syndrome has not been established. we characterised the order and timing of changes in biomarkers of alzheimer's disease in a population of adults with down syndrome. methods: we did a dual-centre cross-sectional study of adults with down syndrome recruited through a population-based health plan in barcelona (spain) and through services for people with intellectual disabilities in cambridge (uk). cognitive impairment in participants with down syndrome was classified with the cambridge cognitive examination for older adults with down syndrome (camcog-ds). only participants with mild or moderate disability were included who had at least one of the following alzheimer's disease measures: apolipoprotein e allele carrier status; plasma concentrations of amyloid β peptides 1-42 and 1-40 and their ratio (aβ(1-42/1-40)), total tau protein, and neurofilament light chain (nfl); tau phosphorylated at threonine 181 (p-tau), and nfl in cerebrospinal fluid (csf); and one or more of pet with (18)f-fluorodeoxyglucose, pet with amyloid tracers, and mri. cognitively healthy euploid controls aged up to 75 years who had no biomarker abnormalities were recruited from the sant pau initiative on neurodegeneration. we used a first-order locally estimated scatterplot smoothing curve to determine the order and age at onset of the biomarker changes, and the lowest ages at the divergence with 95% cis are also reported where appropriate. findings: between feb 1, 2013, and june 28, 2019 (barcelona), and between june 1, 2009, and dec 31, 2014 (cambridge), we included 388 participants with down syndrome (257 [66%] asymptomatic, 48 [12%] with prodromal alzheimer's disease, and 83 [21%] with alzheimer's disease dementia) and 242 euploid controls. csf aβ(1-42/1-40) and plasma nfl values changed in individuals with down syndrome as early as the third decade of life, and amyloid pet uptake changed in the fourth decade. (18)f-fluorodeoxyglucose pet and csf p-tau changes occurred later in the fourth decade of life, followed by hippocampal atrophy and changes in cognition in the fifth decade of life. prodromal alzheimer's disease was diagnosed at a median age of 50·2 years (iqr 47·5-54·1), and alzheimer's disease dementia at 53·7 years (49·5-57·2). symptomatic alzheimer's disease prevalence increased with age in individuals with down syndrome, reaching 90-100% in the seventh decade of life. interpretation: alzheimer's disease in individuals with down syndrome has a long preclinical phase in which biomarkers follow a predictable order of changes over more than two decades. the similarities with sporadic and autosomal dominant alzheimer's disease and the prevalence of down syndrome make this population a suitable target for alzheimer's disease preventive treatments. funding: instituto de salud carlos iii, fundació bancaria la caixa, fundació la marató de tv3, medical research council, and national institutes of health.",
#     "in alzheimer's disease (ad) amyloid-beta (a beta) deposits may cause impairments in choroid plexus, a specialised brain structure which forms the blood-cerebrospinal fluid (csf) barrier. we previously carried out a mass proteomic-based study in choroid plexus from ad patients and we found several differentially regulated proteins compared with healthy subjects. one of these proteins, annexin a5, was previously demonstrated implicated in blocking a beta -induced cytotoxicity in neuronal cell cultures. here, we investigated the effects of annexin a5 on a beta toxicity in choroid plexus. we used choroid plexus tissue samples and csf from mild cognitive impairment (mci) and ad patients to analyse a beta accumulation, cell death and annexin a5 levels compared with control subjects. choroid plexus cell cultures from rats were used to analyse annexin a5 effects on a beta -induced cytotoxicity. ad choroid plexus exhibited progressive reduction of annexin a5 levels along with progressive increased a beta accumulation and cell death as disease stage was higher. on the other hand, annexin a5 levels in csf from patients were found progressively increased as the disease stage increased in severity. in choroid plexus primary cultures, a beta administration reduced endogenous annexin a5 levels in a time-course dependent manner and simultaneously increased annexin a5 levels in extracellular medium. annexin a5 addition to choroid plexus cell cultures restored the a beta -induced impairments on autophagy flux and apoptosis in a calcium-dependent manner. we propose that annexin a5 would exert a protective role in choroid plexus and this protection is lost as a beta accumulates with the disease progression. then, brain protection against further toxic insults would be jeopardised."]]},
#  {'rank': 79,
#   'start': 'AlzheimerOntology:ratio',
#   'start_mention': 'ratio',
#   'end': 'MESH:D007249',
#   'end_mention': ["impairs', 'inflammation', 'disorder', 'reaction', 'related-inflammation', 'disorders', 'Inflammation', 'diseases', 'IL', 'neuro-inflammation', 'stigmata', 'abnormalities', 'damage', 'disease', 'injury', 'TLRs'"],
#   'cn': 198,
#   'title': [[], []]},
#  {'rank': 97,
#   'start': 'AlzheimerOntology:secretase',
#   'start_mention': 'secretase',
#   'end': 'MESH:D019636',
#   'end_mention': ["conditions', 'dementia', 'illnesses', 'loss', 'NDDs', 'decline', 'system', 'disorders', 'neurodegeneration', 'atrophy', 'deficiencies', 'Neurodegenerative', 'Disease', 'damage', 'neurodegeneration/atrophy', 'deficits', 'neurodegenerative-disease', 'neurodegenerations', 'microglia', 'disorder', 'Neurodegeneration', 'brains', 'lesions', 'neurites', 'opens', 'condition', 'diseases', 'ND', 'prionopathies', 'foldopathies', 'NDs', 'Initiative', 'Diseases', 'syndromes', 'deficit', 'Alzheimer', '(18)fluorodeoxyglucose', 'abnormalities', 'illness', 'dendritic', 'alterations', 'degenerative', 'cortex', 'neuroinflammation', 'iNDI', 'dementias', 'maladies', 'neurodegeneration-linked', 'status', 'proteotoxicity', 'aggregation', 'injury', 'proteinopathy', 'proteinopathies', 'late', 'syndrome', 'pathologies', 'disease', 'AT(N', 'malady', 'brain', 'Disorders', 'neurodegenerative', 'failure'"],
#   'cn': 195,
#   'title': [["delta-secretase triggers alzheimer's disease pathologies in wild-type happ/hmapt double transgenic mice",
#     "endosomal dysfunction induced by directly overactivating rab5 recapitulates prodromal and neurodegenerative features of alzheimer's disease",
#     "an agnostic reevaluation of the amyloid cascade hypothesis of alzheimer's disease pathogenesis: the role of app homeostasis"],
#    ["alzheimer's disease (ad) is the most common neurodegenerative disease with multifactorial pathologies including a beta containing senile plaques and neurofibrillary tangles (nft) consisted of aggregated tau. most of the ad patients are sporadic and the familial mutation hereditary patients are composed only 1% of all cases. however, the current ad mouse models employ mutated app, ps1, or even tau mutant, in order to display a portion of ad pathologies. delta-secretase (legumain, or asparaginyl endopeptidase, aep) simultaneously cleaves both app and tau and augments a beta production and tau hyperphosphorylation and aggregation, contributing to ad pathogenesis. here we show that delta -secretase is sufficient to promote prominent ad pathologies in wild-type happ/hmapt double transgenic mice. we crossed happ l5 mice and hmapt mice to generate double transgenic mouse model carrying both human wild-type app and tau. compared to the single transgenic parents, these double transgenic mice demonstrated ad-related pathologies in one-year-old happ/hmapt mice. notably, overexpression of delta -secretase in happ/hmapt double-transgenic mice evidently accelerated enormous senile plaques and nft, associated with prominent synaptic defects and cognitive deficits. hence, delta -secretase facilitates ad pathogenesis independent of any patient-derived mutation.",
#     "neuronal endosomal dysfunction, the earliest known pathobiology specific to alzheimer's disease (ad), is mediated by the aberrant activation of rab5 triggered by app-β secretase cleaved c-terminal fragment (app-βctf). to distinguish pathophysiological consequences specific to overactivated rab5 itself, we activate rab5 independently from app-βctf in the pa-rab5 mouse model. we report that rab5 overactivation alone recapitulates diverse prodromal and degenerative features of ad. modest neuron-specific transgenic rab5 expression inducing hyperactivation of rab5 comparable to that in ad brain reproduces ad-related rab5-endosomal enlargement and mistrafficking, hippocampal synaptic plasticity deficits via accelerated ampar endocytosis and dendritic spine loss, and tau hyperphosphorylation via activated glycogen synthase kinase-3β. importantly, rab5-mediated endosomal dysfunction induces progressive cholinergic neurodegeneration and impairs hippocampal-dependent memory. aberrant neuronal rab5-endosome signaling, therefore, drives a pathogenic cascade distinct from β-amyloid-related neurotoxicity, which includes prodromal and neurodegenerative features of ad, and suggests rab5 overactivation as a potential therapeutic target.",
#     "objective: to reassess the role of amyloid beta (a beta) and the amyloid precursor protein (app) system in the pathogenesis of alzheimer's disease (ad). background: app is a cell adhesion molecule that has been highly conserved over the course of phylogeny that has critical roles in brain development, synaptic plasticity, and the brain's intrinsic immune system. the amyloid cascade hypothesis describes a relatively linear, deterministic sequence of events triggered by a gain of a beta peptide fragment toxicity that results in neurodegeneration and cognitive loss, yet well designed immunotherapy and beta secretase inhibitor trials that have successfully targeted a beta have failed to have any consistent effects on the steady decline of cognition. new/updated hypothesis: mutations of the app and presenilin genes not only alter the ratio of longer to shorter a beta fragments (resulting in a gain of a beta toxicity), but also disrupt the normal homeostatic roles of their respective proteins. the evolutionary history, physiological importance, and complexity of the app and presenilin systems, as well as other critical components including tau and apolipoprotein e (apoe) imply that altered function of such systems could have severe consequences that include but need not be limited to a gain of a beta toxicity and would more generally result in altered homeostasis of app-related functions. major challenges addressed by our hypothesis: challenges that a loss of app homeostasis addresses better than the more limited gain of a beta toxicity model include the topographic mismatches between a beta and tau pathology, the profile and chronology of cognitive and biomarker changes that precede the clinical expression of mild cognitive impairment and dementia, and the disappointments of a beta targeted therapeutics among others. linkage to other major theories: the importance of app, alpha- and beta-secretases, the presenilins and.-secretase, as well as tau was recognized by the authors of the amyloid cascade hypothesis, and has since led multiple investigators to propose alternative, more balanced hypotheses including reduced homeostasis and frank loss-of-function of key components that include but go beyond the currently envisioned linear model of a beta toxicity."]]}]
