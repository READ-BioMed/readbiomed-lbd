# %%
from sklearn.feature_extraction.text import CountVectorizer
import csv
import json
import re
from collections import defaultdict
import itertools
import sys

# %%
path = "/Users/yidesdo21/Projects/outputs/10_ptc_ten_recent/bag_of_identifiers/"

# %% [markdown]
# ### create a co-occurrence matrix for identifiers in the articles and write the matrix to a CSV file
# - if two identifiers appear in the same article, then they co-occur.
# - 1) we start with each article and it's bag of identifiers,
# - 2) then create a document-term matrix with the transform method in CountVectorizer. The term in the matrix is made up of the set of all identifiers from all the articles. The transform method allows us to define the vocabulary (the set of identifiers) and turn the vocabulary and the articles into a document-term matrix.
# - 3) aftet that, we use matrix multiplication to get word-word co-occurrence matrix.
# - 4) create the CSV from the co-occurence matrix, columns include: concept_id1, concept_id2, frequency

# %%
article1 = ["id:id_1", "id:id_2", "id:id_3"]
article2 = ["id:id_2", "id:id_4"]
article3 = ["id:id_1", "id:id_3"]

# %%
articles = [article1, article2, article3]

# %%
articles
# Out:
# [['id:id_1', 'id:id_2', 'id:id_3'],
#  ['id:id_2', 'id:id_4'],
#  ['id:id_1', 'id:id_3']]

# %%
# ## test 
# article1 = ['AlzheimerOntology:t_tau', 'AlzheimerOntology:tauopathy']
# article2 = ["9606", 'AlzheimerOntology:t_tau', 'AlzheimerOntology:tauopathy']
# article3 = ["9606", 'AlzheimerOntology:t_tau']
# articles = [article1, article2, article3]

# %%
vocab = set()
article_transform = list()

for article in articles:
    article_transform.append(" ".join(article))
    for identifier in article:
        vocab.add(identifier.lower())

vocab = sorted(list(vocab))

# %%
vocab
# Out:
# ['id:id_1', 'id:id_2', 'id:id_3', 'id:id_4']

# %%
article_transform
# Out:
# ['id:id_1 id:id_2 id:id_3', 'id:id_2 id:id_4', 'id:id_1 id:id_3']

# %%
vectorizer = CountVectorizer(vocabulary=vocab, token_pattern=r"(?u)\b\w\w+:?\w+\b")  # need to add colon as part of the tokens
X = vectorizer.transform(article_transform)  
X[X > 0] = 1   # filter spurious result, but I don't think we need this line

# %%
Xc = (X.T * X) # this is co-occurrence matrix in sparse csr format
Xc.setdiag(0) # sometimes you want to fill same word cooccurence to 0
Xc = Xc.tolil()   # this line removes the sparsewarning
# co_occur = Xc.toarray()
# print(Xc.todense()) # print out matrix in dense format

# %%
print(Xc)
# Out:
#   (0, 0)	0
#   (0, 1)	1
#   (0, 2)	2
#   (1, 0)	1
#   (1, 1)	0
#   (1, 2)	1
#   (1, 3)	1
#   (2, 0)	2
#   (2, 1)	1
#   (2, 2)	0
#   (3, 1)	1
#   (3, 3)	0

# %%
indices = list(zip(*Xc.nonzero()))
# indices = list(map(set, zip(*Xc.nonzero())))

# %%
indices
# Out:
# [(0, 1), (0, 2), (1, 0), (1, 2), (1, 3), (2, 0), (2, 1), (3, 1)]

# %%
indices_set = list()
co_occur_dict = dict()
ind2vocab = dict(zip(range(len(vocab)), vocab))

for i in indices:
    index_set = {i[0],i[1]}
    if index_set not in indices_set: 
#         print(i)
#         print(Xc[i])
        indices_set.append(index_set)
        co_occur_dict[(ind2vocab[i[0]],ind2vocab[i[1]])] = Xc[i]

# %%
co_occur_dict
# Out:
# {('id:id_1', 'id:id_2'): 1,
#  ('id:id_1', 'id:id_3'): 2,
#  ('id:id_2', 'id:id_3'): 1,
#  ('id:id_2', 'id:id_4'): 1}

# %%
# Xc.shape
# Out:
# (4, 4)

# %%
# co_occur_dict = dict()
# vocab2ind = dict(zip(vocab, range(len(vocab))))
# ind2vocab = dict(zip(range(len(vocab)), vocab))

# for i in range(len(vocab)-1):
#     print(co_occur[i])
#     for j in range(i+1,len(vocab)):   # skip the diagano and the duplicated half of the pyramid 
#         freq = co_occur[i][j]
#         if freq != 0:
#             print(freq)
#             co_occur_dict[(ind2vocab[i],ind2vocab[j])] = freq
#     print("-----------")
# Out:
# [0 1 2 0]
# 1
# 2
# -----------
# [1 0 1 1]
# 1
# 1
# -----------
# [2 1 0 0]
# -----------

# %%
def write_to_csv(path, file_name, co_occur_dict):
    """write the co-occurrence dictionary to a CSV file
    input -- path that saves the CSV file
             the co-occurrence dictionary"""
    
    header = ["concept_id1", "concept_id2", "frequency"]  # co-occurrence frequency in the same abtract

    with open(path+file_name+'.csv', 'w') as f:
        writer = csv.writer(f)
        writer.writerow(header) # write the header
        for k,v in co_occur_dict.items():
            writer.writerow([k[0],k[1],v])

# %%
co_occur_dict
# Out:
# {('id:id_1', 'id:id_2'): 1,
#  ('id:id_1', 'id:id_3'): 2,
#  ('id:id_2', 'id:id_3'): 1,
#  ('id:id_2', 'id:id_4'): 1}

# %%
write_to_csv(path,"test",co_occur_dict)

# %% [markdown]
# ### write a function to create the co-occurrence CSV

# %%
def create_vocab(articles):
    """create a set of vocabularies -- all the identifiers in all articles are included
    input -- a list of lists. [["id_1", "id_2"], ["id_1"], ...]
             Each nested list is a bag of identifiers from each article
    output -- a sorted list of strings. ["id_1", "id_2", ...]"""
    
    vocab = set()
    article_transform = list()

    for article in articles:
        article_transform.append(" ".join(article))
        for identifier in article:
            vocab.add(identifier.lower())   # the CountVector convert all characters to lowercase before tokenizing

    vocab = sorted(list(vocab))
    return vocab, article_transform

# %%
articles
# Out:
# [['id:id_1', 'id:id_2', 'id:id_3'],
#  ['id:id_2', 'id:id_4'],
#  ['id:id_1', 'id:id_3']]

# %%
create_vocab(articles)
# Out:
# (['id:id_1', 'id:id_2', 'id:id_3', 'id:id_4'],
#  ['id:id_1 id:id_2 id:id_3', 'id:id_2 id:id_4', 'id:id_1 id:id_3'])

# %%
def create_co_occur(vocab, article_transform):
    """create a co-occurrence dictionary
    output -- keys are tuples of strings, and values are numbers (frequency of co-occurrences).
              {("id_1", "id_2"), 10}
    input -- a vocabulary list, 
             a list of strings, the strings are joined by the bag of identifiers"""
    
    # create the document-term matrix
    
    vectorizer = CountVectorizer(vocabulary=vocab, token_pattern=r"(?u)\b\w\w+:?\w+\b")  # need to add colon as part of the tokens
    X = vectorizer.transform(article_transform)  
    X[X > 0] = 1   # filter spurious result, but I don't think we need this line
#     print(X.toarray())
#     print(vectorizer.get_feature_names())
    
    # creat the co-occurrence matrix
    Xc = (X.T * X) 
    Xc.setdiag(0) 
    Xc = Xc.tolil()   # this line removes the sparsewarning
    indices = list(zip(*Xc.nonzero()))
#     print(Xc)
#     print(indices)
    
    indices_set = list()
    co_occur_dict = dict()
    ind2vocab = dict(zip(range(len(vocab)), vocab))

    for i in indices:
#         print(i)
#         print((ind2vocab[i[0]],ind2vocab[i[1]]), Xc[i])
        index_set = {i[0],i[1]}
        if index_set not in indices_set: 
            indices_set.append(index_set)
            co_occur_dict[(ind2vocab[i[0]],ind2vocab[i[1]])] = Xc[i]

                              
    return co_occur_dict

# %%
result = create_vocab(articles)
vocab, trans = result[0], result[1]

# %%
vocab
# Out:
# ['id:id_1', 'id:id_2', 'id:id_3', 'id:id_4']

# %%
create_co_occur(vocab, trans)
# Out:
# {('id:id_1', 'id:id_2'): 1,
#  ('id:id_1', 'id:id_3'): 2,
#  ('id:id_2', 'id:id_3'): 1,
#  ('id:id_2', 'id:id_4'): 1}

# %%
# ## test 
# article1 = ['AlzheimerOntology:t_tau', 'AlzheimerOntology:tauopathy']
# article2 = ["9606", 'AlzheimerOntology:t_tau', 'AlzheimerOntology:tauopathy']
# article3 = ["9606", 'AlzheimerOntology:t_tau']
# articles = [article1, article2, article3]

# %%
# articles
# Out:
# [['AlzheimerOntology:t_tau', 'AlzheimerOntology:tauopathy'],
#  ['9606', 'AlzheimerOntology:t_tau', 'AlzheimerOntology:tauopathy'],
#  ['9606', 'AlzheimerOntology:t_tau']]

# %%
# result = create_vocab(articles)
# vocab, trans = result[0], result[1]

# %%
# vocab
# Out:
# ['9606', 'AlzheimerOntology:t_tau', 'AlzheimerOntology:tauopathy']

# %%
# trans
# Out:
# ['AlzheimerOntology:t_tau AlzheimerOntology:tauopathy',
#  '9606 AlzheimerOntology:t_tau AlzheimerOntology:tauopathy',
#  '9606 AlzheimerOntology:t_tau']

# %%
write_to_csv(path,"test",co_occur_dict)

# %% [markdown]
# ### create the co-occurrence matrix and CSV file for the 10 most recent articles

# %%
json_path = "/Users/yidesdo21/Projects/outputs/10_ptc_ten_recent/json/"
article_file = "combined_ten_recent_spans_nested_case.json"

# %%
with open(json_path+article_file) as f:
    data = json.load(f)

# %%
len(data)
# Out:
# 10

# %%
bag_identifiers = dict()   # a pointer from the article titles to the bag of identifiers in the titles
list_identifiers = list() # a list of lists of bag of identifiers to create the vocabulary for the co-occurrence matrix

for a in data:
    title, ents = a["title"], a["ents"]
    identifiers = set()
    
    for ent in ents:
        identifiers.add(ent["identifier"])
    
    sort_ids = sorted(list(identifiers))
    list_identifiers.append(sort_ids)
    bag_identifiers[title] = sort_ids

# %%
bag_identifiers
# Out:
# {'CCC_000637925000033': ['351',
#   '6647',
#   '847',
#   'AlzheimerOntology:Endocytosis',
#   'AlzheimerOntology:Intervention',
#   'AlzheimerOntology:Membrane',
#   'AlzheimerOntology:Microglia',
#   'AlzheimerOntology:Receptors',
#   'AlzheimerOntology:amyloid_beta_protein',
#   'AlzheimerOntology:antioxidant',
#   'AlzheimerOntology:brain',
#   'AlzheimerOntology:inflammation',
#   'AlzheimerOntology:oxygen',
#   'AlzheimerOntology:phagocytosis',
#   'MESH:C405953',
#   'MESH:D008345',
#   'MESH:D010100',
#   'MESH:D016229',
#   'NDDUO:Intervention',
#   'NDDUO:Study_type',
#   'NDDUO:disease',
#   'none',
#   'obo:BFO_0000015',
#   'obo:FMA_50801',
#   'obo:IAO_0000230',
#   'obo:OGMS_0000031',
#   'span:Process'],
#  'CCC_000647663200001': ['10090',
#   '11820',
#   '19164',
#   'AlzheimerOntology:APP',
#   'AlzheimerOntology:Subtypes',
#   'AlzheimerOntology:amyloid_beta_protein',
#   'AlzheimerOntology:amyloid_precursor_protein',
#   'AlzheimerOntology:brain',
#   'AlzheimerOntology:presence_of_amyloid_plaque',
#   'AlzheimerOntology:presenilin',
#   'AlzheimerOntology:presenilin_1',
#   'AlzheimerOntology:protein',
#   'AlzheimerOntology:senile_plaque',
#   'MESH:C011973',
#   'MESH:C468911',
#   'MESH:D000544',
#   'MESH:D010300',
#   'MESH:D014786',
#   'MESH:D016229',
#   'NDDUO:Cluster',
#   'NDDUO:In_vivo',
#   'NDDUO:In_vivo_models',
#   'NDDUO:Mouse_',
#   'NDDUO:disease',
#   'NDDUO:female',
#   'NDDUO:male',
#   'NDDUO:model',
#   'obo:BFO_0000023',
#   'obo:BFO_0000034',
#   'obo:FMA_50801',
#   'obo:NBO_0000215',
#   'obo:OBI_0000070',
#   'obo:OGMS_0000023',
#   'obo:OGMS_0000031',
#   'obo:RO_0000081',
#   'snap:Function',
#   'snap:Role'],
#  'CCC_000653155500009': ['351',
#   'AlzheimerOntology:Intervention',
#   'AlzheimerOntology:Memory_orientation_screening_test',
#   'AlzheimerOntology:Subtypes',
#   'AlzheimerOntology:amyloid_beta_protein',
#   'MESH:C011126',
#   'MESH:C039408',
#   'MESH:D000544',
#   'MESH:D016229',
#   'NDDUO:Intervention',
#   'NDDUO:Sampling',
#   'NDDUO:Study_type',
#   'NDDUO:disease',
#   'obo:NBO_0000282',
#   'obo:OBI_0000070',
#   'obo:OGMS_0000031'],
#  'NLM_31721178': ['AlzheimerOntology:Filaments',
#   'AlzheimerOntology:Subtypes',
#   'AlzheimerOntology:Tangles',
#   'AlzheimerOntology:brain',
#   'AlzheimerOntology:brain_tissue',
#   'AlzheimerOntology:neurofibrillary_tangle',
#   'AlzheimerOntology:t_tau',
#   'AlzheimerOntology:tauopathy',
#   'MESH:C536599',
#   'MESH:D000544',
#   'MESH:D006493',
#   'MESH:D024801',
#   'NDDUO:Cluster',
#   'NDDUO:Screening',
#   'NDDUO:Study_type',
#   'NDDUO:disease',
#   'NDDUO:inhibitor',
#   'NDDUO:model',
#   'obo:FMA_50801',
#   'obo:IAO_0000224',
#   'obo:IAO_0000230',
#   'obo:NBO_0000215',
#   'obo:ND_0000151',
#   'obo:OGMS_0000031'],
#  'NLM_33730588': ['9606',
#   'AlzheimerOntology:Cerebospinal_Fluid',
#   'AlzheimerOntology:Cerebospinal_fluid_test',
#   'AlzheimerOntology:Filaments',
#   'AlzheimerOntology:Subtypes',
#   'AlzheimerOntology:antibody',
#   'AlzheimerOntology:brain',
#   'AlzheimerOntology:cerebrospinal_fluid',
#   'AlzheimerOntology:macrophage_colony_stimulating_factor',
#   'AlzheimerOntology:procedures_using_biomarkers',
#   'AlzheimerOntology:t_tau',
#   'AlzheimerOntology:tauopathy',
#   'MESH:C536599',
#   'MESH:D000544',
#   'MESH:D020774',
#   'MESH:D024801',
#   'NDDUO:Cluster',
#   'NDDUO:biomarker',
#   'NDDUO:disease',
#   'NDDUO:model',
#   'obo:FMA_50801',
#   'obo:IAO_0000224',
#   'obo:IAO_0000230',
#   'obo:IAO_0000310',
#   'obo:NBO_0000215',
#   'obo:ND_0000151',
#   'obo:ND_0000169',
#   'obo:OBI_0000070',
#   'obo:OGMS_0000031'],
#  'NLM_33958804': ['10090',
#   '11816',
#   '348',
#   '9606',
#   'AlzheimerOntology:APOE',
#   'AlzheimerOntology:ApoE_Protein',
#   'AlzheimerOntology:Hippocampus',
#   'AlzheimerOntology:Nucleus',
#   'AlzheimerOntology:RNA',
#   'AlzheimerOntology:Subtypes',
#   'AlzheimerOntology:brain',
#   'AlzheimerOntology:t_tau',
#   'AlzheimerOntology:tauopathy',
#   'MESH:D000544',
#   'MESH:D019636',
#   'NDDUO:Mouse_',
#   'NDDUO:Neurons',
#   'NDDUO:disease',
#   'obo:FMA_50801',
#   'obo:FMA_62493',
#   'obo:IAO_0000230',
#   'obo:OGMS_0000031'],
#  'NLM_33988687': ['10090',
#   'AlzheimerOntology:APP',
#   'AlzheimerOntology:Cell_cultures',
#   'AlzheimerOntology:Subtypes',
#   'AlzheimerOntology:amyloid_precursor_protein',
#   'AlzheimerOntology:brain',
#   'AlzheimerOntology:mutation',
#   'MESH:D000544',
#   'NDDUO:Mouse_',
#   'NDDUO:disease',
#   'obo:FMA_50801',
#   'obo:IAO_0000230',
#   'obo:OGMS_0000031'],
#  'NLM_34060233': ['274',
#   'AlzheimerOntology:BIN1',
#   'AlzheimerOntology:Cognitive_Tests',
#   'AlzheimerOntology:Moderate_cognitive_Decline',
#   'AlzheimerOntology:Positron_emission_tomography',
#   'AlzheimerOntology:Subtypes',
#   'AlzheimerOntology:amyloid_beta_protein',
#   'AlzheimerOntology:mental_disorder',
#   'AlzheimerOntology:neuroimaging',
#   'AlzheimerOntology:procedures_using_biomarkers',
#   'AlzheimerOntology:t_tau',
#   'AlzheimerOntology:tauopathy',
#   'MESH:D000544',
#   'MESH:D003072',
#   'MESH:D005461',
#   'MESH:D016229',
#   'MESH:D017887',
#   'MESH:D019636',
#   'NDDUO:Risk_factor',
#   'NDDUO:Sampling',
#   'NDDUO:biomarker',
#   'NDDUO:disease',
#   'NDDUO:disorder',
#   'NDDUO:neurodegenerative_disease',
#   'none',
#   'obo:OGMS_0000031',
#   'rs744373'],
#  'NLM_34095440': ['AlzheimerOntology:Cognitive_Tests',
#   'AlzheimerOntology:Intervention',
#   'AlzheimerOntology:Memory_orientation_screening_test',
#   'AlzheimerOntology:Neuropsychiatric_symptoms',
#   'AlzheimerOntology:Subtypes',
#   'AlzheimerOntology:procedures_using_biomarkers',
#   'AlzheimerOntology:psychological_symptom',
#   'MESH:D000544',
#   'NDDUO:Clinical',
#   'NDDUO:Clinical_trial',
#   'NDDUO:Intervention',
#   'NDDUO:Symptoms',
#   'NDDUO:biomarker',
#   'NDDUO:disease',
#   'NDDUO:drug',
#   'NDDUO:phase_1',
#   'NDDUO:phase_2',
#   'NDDUO:phase_3',
#   'NDDUO:rate',
#   'obo:BFO_0000015',
#   'obo:OGMS_0000031',
#   'span:Process'],
#  'NLM_34101788': ['9606',
#   'AlzheimerOntology:Cohort_effect',
#   'AlzheimerOntology:Intervention',
#   'AlzheimerOntology:Outcome',
#   'AlzheimerOntology:Populations',
#   'AlzheimerOntology:Subtypes',
#   'AlzheimerOntology:control_group_study_arm',
#   'MESH:C559645',
#   'MESH:D000544',
#   'NDDO:NDDO_00000107',
#   'NDDUO:Clinical',
#   'NDDUO:Clinical_trial',
#   'NDDUO:Intervention',
#   'NDDUO:Outcome',
#   'NDDUO:Stages',
#   'NDDUO:disease',
#   'NDDUO:drug',
#   'NDDUO:outcome_measure',
#   'obo:GO_0007612',
#   'obo:IAO_0000230',
#   'obo:MF_0000027',
#   'obo:OBI_0000260',
#   'obo:OBI_0000272',
#   'obo:OBI_0000339',
#   'obo:OGMS_0000031']}

# %%
cnt_ids = 0 # including duplications
for i in list_identifiers:  # number of identifiers in each article
    print(len(i))
    cnt_ids += len(i)

print(cnt_ids)
# Out:
# 27
# 37
# 16
# 24
# 29
# 22
# 13
# 27
# 22
# 25
# 242

# %%
# list_identifiers

# %%
vocab_ids, art_transform = create_vocab(list_identifiers)

# %%
len(vocab_ids)
# Out:
# 137

# %%
# vocab_ids

# %%
# art_transform

# %%
# vocab_ids

# %%
ten_dict = create_co_occur(vocab_ids, art_transform)
ten_dict_sorted = dict(sorted(ten_dict.items(), key=lambda x: x[1], reverse=True))

# %%
write_to_csv(path,"ten_article_co_occur",ten_dict_sorted)

# %% [markdown]
# ### create the id information CSV file for the 10 most recent articles

# %%
## expected dictionary 
# {"AlzheimerOntology:Subtypes": {"article": ["NLM_33988687", "CCC_000653155500009"],
#                                 "span": [[10,27], [13,15]],
#                                 "mention": ["Alzheimer Disease", "AD"],
#                                 "canonical name": ["Alzheimer Disease"],
#                                 "type": [],
#                                 "annotator": ["NIO"]}}

# %%
id_dict = defaultdict(lambda: defaultdict(set))  # either set or list, but list has too many duplications

# %%
id_dict
# Out:
# defaultdict(<function __main__.<lambda>()>, {})

# %%
for a in data:
    title, ents = a["title"], a["ents"]  
#     id_dict = defaultdict(lambda: defaultdict(list))
    
    for ent in ents:
        identifier = ent["identifier"]
        id_dict[identifier]["article"].add(title)
#         print(id_dict[identifier]["span"])
#         print(ent["span"])
        id_dict[identifier]["span"].add(str(ent["span"]))
        id_dict[identifier]["mention"].add(ent["mention"])
        id_dict[identifier]["canonical name"].add(ent["concept"])
        id_dict[identifier]["type"].add(ent["type"])
        id_dict[identifier]["annotator"].add(ent["annotator"])

# %%
len(id_dict)
# Out:
# 137

# %%
id_dict
# Out:
# defaultdict(<function __main__.<lambda>()>,
#             {'AlzheimerOntology:Receptors': defaultdict(set,
#                          {'article': {'CCC_000637925000033'},
#                           'span': {'[1232, 1241]',
#                            '[165, 173]',
#                            '[1723, 1731]',
#                            '[28, 37]',
#                            '[371, 380]',
#                            '[462, 471]',
#                            '[758, 767]'},
#                           'mention': {'receptor', 'receptors'},
#                           'canonical name': {'Receptor'},
#                           'type': {''},
#                           'annotator': {'NIO'}}),
#              'AlzheimerOntology:Microglia': defaultdict(set,
#                          {'article': {'CCC_000637925000033'},
#                           'span': {'[204, 213]',
#                            '[42, 51]',
#                            '[562, 571]',
#                            '[779, 788]'},
#                           'mention': {'microglia'},
#                           'canonical name': {'Microglia'},
#                           'type': {''},
#                           'annotator': {'NIO'}}),
#              '351': defaultdict(set,
#                          {'article': {'CCC_000637925000033',
#                            'CCC_000653155500009'},
#                           'span': {'[1122, 1128]',
#                            '[1225, 1231]',
#                            '[124, 130]',
#                            '[1271, 1277]',
#                            '[1412, 1418]',
#                            '[1458, 1464]',
#                            '[1486, 1492]',
#                            '[1672, 1678]',
#                            '[237, 243]',
#                            '[323, 329]',
#                            '[496, 502]',
#                            '[576, 582]',
#                            '[67, 73]',
#                            '[751, 757]',
#                            '[804, 810]',
#                            '[946, 952]'},
#                           'mention': {'A beta'},
#                           'canonical name': {''},
#                           'type': {'Gene'},
#                           'annotator': {'PTC'}}),
#              'AlzheimerOntology:amyloid_beta_protein': defaultdict(set,
#                          {'article': {'CCC_000637925000033',
#                            'CCC_000647663200001',
#                            'CCC_000653155500009',
#                            'NLM_34060233'},
#                           'span': {'[110, 117]',
#                            '[110, 122]',
#                            '[152, 159]',
#                            '[223, 230]',
#                            '[223, 235]',
#                            '[228, 235]',
#                            '[228, 240]',
#                            '[332, 339]',
#                            '[332, 344]',
#                            '[44, 51]',
#                            '[44, 56]',
#                            '[595, 602]'},
#                           'mention': {'Amyloid',
#                            'amyloid',
#                            'amyloid beta',
#                            'amyloid-beta'},
#                           'canonical name': {'amyloid beta protein'},
#                           'type': {''},
#                           'annotator': {'NIO'}}),
#              'MESH:D016229': defaultdict(set,
#                          {'article': {'CCC_000637925000033',
#                            'CCC_000647663200001',
#                            'CCC_000653155500009',
#                            'NLM_34060233'},
#                           'span': {'[110, 122]',
#                            '[223, 235]',
#                            '[228, 235]',
#                            '[332, 339]',
#                            '[44, 51]',
#                            '[595, 602]'},
#                           'mention': {'amyloid', 'amyloid-beta'},
#                           'canonical name': {''},
#                           'type': {'Chemical'},
#                           'annotator': {'PTC'}}),
#              'AlzheimerOntology:Endocytosis': defaultdict(set,
#                          {'article': {'CCC_000637925000033'},
#                           'span': {'[183, 194]'},
#                           'mention': {'endocytosis'},
#                           'canonical name': {'Endocytosis'},
#                           'type': {''},
#                           'annotator': {'NIO'}}),
#              'none': defaultdict(set,
#                          {'article': {'CCC_000637925000033', 'NLM_34060233'},
#                           'span': {'[190, 193]', '[196, 199]', '[43, 46]'},
#                           'mention': {'RME', 'SNP'},
#                           'canonical name': {''},
#                           'type': {'Chemical', 'Disease'},
#                           'annotator': {'PTC'}}),
#              'obo:FMA_50801': defaultdict(set,
#                          {'article': {'CCC_000637925000033',
#                            'CCC_000647663200001',
#                            'NLM_31721178',
#                            'NLM_33730588',
#                            'NLM_33958804',
#                            'NLM_33988687'},
#                           'span': {'[114, 119]',
#                            '[251, 256]',
#                            '[289, 295]',
#                            '[654, 660]',
#                            '[689, 694]',
#                            '[733, 739]',
#                            '[867, 872]',
#                            '[947, 952]'},
#                           'mention': {'brain', 'brains'},
#                           'canonical name': {'Brain'},
#                           'type': {''},
#                           'annotator': {'NIO'}}),
#              'AlzheimerOntology:brain': defaultdict(set,
#                          {'article': {'CCC_000637925000033',
#                            'CCC_000647663200001',
#                            'NLM_31721178',
#                            'NLM_33730588',
#                            'NLM_33958804',
#                            'NLM_33988687'},
#                           'span': {'[114, 119]',
#                            '[251, 256]',
#                            '[289, 295]',
#                            '[654, 660]',
#                            '[689, 694]',
#                            '[733, 739]',
#                            '[867, 872]',
#                            '[947, 952]'},
#                           'mention': {'brain', 'brains'},
#                           'canonical name': {'brain'},
#                           'type': {''},
#                           'annotator': {'NIO'}}),
#              'AlzheimerOntology:inflammation': defaultdict(set,
#                          {'article': {'CCC_000637925000033'},
#                           'span': {'[276, 288]', '[276, 296]'},
#                           'mention': {'inflammatory', 'inflammatory cascade'},
#                           'canonical name': {'inflammation'},
#                           'type': {''},
#                           'annotator': {'NIO'}}),
#              'AlzheimerOntology:Membrane': defaultdict(set,
#                          {'article': {'CCC_000637925000033'},
#                           'span': {'[393, 401]', '[718, 727]'},
#                           'mention': {'membrane', 'membranes'},
#                           'canonical name': {'Membrane'},
#                           'type': {''},
#                           'annotator': {'NIO'}}),
#              'obo:BFO_0000015': defaultdict(set,
#                          {'article': {'CCC_000637925000033', 'NLM_34095440'},
#                           'span': {'[837, 846]', '[894, 901]'},
#                           'mention': {'process', 'processes'},
#                           'canonical name': {'process'},
#                           'type': {''},
#                           'annotator': {'NIO'}}),
#              'span:Process': defaultdict(set,
#                          {'article': {'CCC_000637925000033', 'NLM_34095440'},
#                           'span': {'[837, 846]', '[894, 901]'},
#                           'mention': {'process', 'processes'},
#                           'canonical name': {'process'},
#                           'type': {''},
#                           'annotator': {'NIO'}}),
#              'MESH:D008345': defaultdict(set,
#                          {'article': {'CCC_000637925000033'},
#                           'span': {'[1016, 1023]', '[977, 989]'},
#                           'mention': {'Mn-MOFs', 'Mn-porphyrin'},
#                           'canonical name': {''},
#                           'type': {'Chemical'},
#                           'annotator': {'PTC'}}),
#              '6647': defaultdict(set,
#                          {'article': {'CCC_000637925000033'},
#                           'span': {'[1030, 1050]', '[1052, 1055]'},
#                           'mention': {'SOD', 'superoxide dismutase'},
#                           'canonical name': {''},
#                           'type': {'Gene'},
#                           'annotator': {'PTC'}}),
#              '847': defaultdict(set,
#                          {'article': {'CCC_000637925000033'},
#                           'span': {'[1061, 1069]', '[1071, 1074]'},
#                           'mention': {'CAT', 'catalase'},
#                           'canonical name': {''},
#                           'type': {'Gene'},
#                           'annotator': {'PTC'}}),
#              'MESH:C405953': defaultdict(set,
#                          {'article': {'CCC_000637925000033'},
#                           'span': {'[1113, 1137]'},
#                           'mention': {'N-azidoacetylmannosamine'},
#                           'canonical name': {''},
#                           'type': {'Chemical'},
#                           'annotator': {'PTC'}}),
#              'MESH:D010100': defaultdict(set,
#                          {'article': {'CCC_000637925000033'},
#                           'span': {'[1187, 1193]'},
#                           'mention': {'oxygen'},
#                           'canonical name': {''},
#                           'type': {'Chemical'},
#                           'annotator': {'PTC'}}),
#              'AlzheimerOntology:oxygen': defaultdict(set,
#                          {'article': {'CCC_000637925000033'},
#                           'span': {'[1187, 1193]'},
#                           'mention': {'oxygen'},
#                           'canonical name': {'oxygen'},
#                           'type': {''},
#                           'annotator': {'NIO'}}),
#              'AlzheimerOntology:antioxidant': defaultdict(set,
#                          {'article': {'CCC_000637925000033'},
#                           'span': {'[1327, 1338]'},
#                           'mention': {'antioxidant'},
#                           'canonical name': {'antioxidant'},
#                           'type': {''},
#                           'annotator': {'NIO'}}),
#              'AlzheimerOntology:phagocytosis': defaultdict(set,
#                          {'article': {'CCC_000637925000033'},
#                           'span': {'[1382, 1394]'},
#                           'mention': {'phagocytosis'},
#                           'canonical name': {'phagocytosis'},
#                           'type': {''},
#                           'annotator': {'NIO'}}),
#              'NDDUO:Study_type': defaultdict(set,
#                          {'article': {'CCC_000637925000033',
#                            'CCC_000653155500009',
#                            'NLM_31721178'},
#                           'span': {'[1500, 1505]',
#                            '[1809, 1816]',
#                            '[925, 933]'},
#                           'mention': {'studies', 'study', 'studying'},
#                           'canonical name': {'clinical trial study'},
#                           'type': {''},
#                           'annotator': {'NIO'}}),
#              'obo:IAO_0000230': defaultdict(set,
#                          {'article': {'CCC_000637925000033',
#                            'NLM_31721178',
#                            'NLM_33730588',
#                            'NLM_33958804',
#                            'NLM_33988687',
#                            'NLM_34101788'},
#                           'span': {'[143, 148]',
#                            '[1680, 1685]',
#                            '[169, 174]',
#                            '[254, 260]',
#                            '[291, 296]',
#                            '[667, 672]'},
#                           'mention': {'other', 'others'},
#                           'canonical name': {'other'},
#                           'type': {''},
#                           'annotator': {'NIO'}}),
#              'obo:OGMS_0000031': defaultdict(set,
#                          {'article': {'CCC_000637925000033',
#                            'CCC_000647663200001',
#                            'CCC_000653155500009',
#                            'NLM_31721178',
#                            'NLM_33730588',
#                            'NLM_33958804',
#                            'NLM_33988687',
#                            'NLM_34060233',
#                            'NLM_34095440',
#                            'NLM_34101788'},
#                           'span': {'[106, 113]',
#                            '[119, 126]',
#                            '[12, 19]',
#                            '[152, 159]',
#                            '[1686, 1693]',
#                            '[174, 181]',
#                            '[1858, 1865]',
#                            '[1910, 1917]',
#                            '[231, 238]',
#                            '[239, 246]',
#                            '[274, 281]',
#                            '[276, 283]',
#                            '[30, 37]',
#                            '[470, 477]',
#                            '[60, 67]',
#                            '[632, 639]',
#                            '[929, 936]',
#                            '[95, 102]',
#                            '[98, 105]'},
#                           'mention': {'Disease', 'disease'},
#                           'canonical name': {'disease'},
#                           'type': {''},
#                           'annotator': {'NIO'}}),
#              'NDDUO:disease': defaultdict(set,
#                          {'article': {'CCC_000637925000033',
#                            'CCC_000647663200001',
#                            'CCC_000653155500009',
#                            'NLM_31721178',
#                            'NLM_33730588',
#                            'NLM_33958804',
#                            'NLM_33988687',
#                            'NLM_34060233',
#                            'NLM_34095440',
#                            'NLM_34101788'},
#                           'span': {'[106, 113]',
#                            '[119, 126]',
#                            '[12, 19]',
#                            '[152, 159]',
#                            '[1686, 1693]',
#                            '[174, 181]',
#                            '[1858, 1865]',
#                            '[1910, 1917]',
#                            '[231, 238]',
#                            '[239, 246]',
#                            '[274, 281]',
#                            '[276, 283]',
#                            '[30, 37]',
#                            '[470, 477]',
#                            '[60, 67]',
#                            '[632, 639]',
#                            '[929, 936]',
#                            '[95, 102]',
#                            '[98, 105]'},
#                           'mention': {'Disease', 'disease'},
#                           'canonical name': {'disease'},
#                           'type': {''},
#                           'annotator': {'NIO'}}),
#              'AlzheimerOntology:Intervention': defaultdict(set,
#                          {'article': {'CCC_000637925000033',
#                            'CCC_000653155500009',
#                            'NLM_34095440',
#                            'NLM_34101788'},
#                           'span': {'[1056, 1065]',
#                            '[1263, 1273]',
#                            '[164, 174]',
#                            '[1694, 1706]',
#                            '[1886, 1895]',
#                            '[263, 272]',
#                            '[314, 323]',
#                            '[415, 424]',
#                            '[473, 483]',
#                            '[899, 912]',
#                            '[981, 990]'},
#                           'mention': {'intervention',
#                            'interventions',
#                            'treatment',
#                            'treatments'},
#                           'canonical name': {'Intervention'},
#                           'type': {''},
#                           'annotator': {'NIO'}}),
#              'NDDUO:Intervention': defaultdict(set,
#                          {'article': {'CCC_000637925000033',
#                            'CCC_000653155500009',
#                            'NLM_34095440',
#                            'NLM_34101788'},
#                           'span': {'[1056, 1065]',
#                            '[1263, 1273]',
#                            '[164, 174]',
#                            '[1694, 1706]',
#                            '[1886, 1895]',
#                            '[263, 272]',
#                            '[314, 323]',
#                            '[415, 424]',
#                            '[473, 483]',
#                            '[899, 912]',
#                            '[981, 990]'},
#                           'mention': {'intervention',
#                            'interventions',
#                            'treatment',
#                            'treatments'},
#                           'canonical name': {'Thing related to intervention'},
#                           'type': {''},
#                           'annotator': {'NIO'}}),
#              'MESH:D014786': defaultdict(set,
#                          {'article': {'CCC_000647663200001'},
#                           'span': {'[0, 40]'},
#                           'mention': {'Impairment of visual cortical plasticity'},
#                           'canonical name': {''},
#                           'type': {'Disease'},
#                           'annotator': {'PTC'}}),
#              '10090': defaultdict(set,
#                          {'article': {'CCC_000647663200001',
#                            'NLM_33958804',
#                            'NLM_33988687'},
#                           'span': {'[1001, 1006]',
#                            '[116, 120]',
#                            '[1292, 1296]',
#                            '[1417, 1432]',
#                            '[1494, 1498]',
#                            '[1596, 1601]',
#                            '[308, 323]',
#                            '[328, 332]',
#                            '[674, 678]',
#                            '[700, 704]',
#                            '[888, 903]',
#                            '[991, 1006]'},
#                           'mention': {'Transgenic mice',
#                            'mice',
#                            'mouse',
#                            'transgenic mice'},
#                           'canonical name': {''},
#                           'type': {'Species'},
#                           'annotator': {'PTC'}}),
#              'NDDUO:Mouse_': defaultdict(set,
#                          {'article': {'CCC_000647663200001',
#                            'NLM_33958804',
#                            'NLM_33988687'},
#                           'span': {'[1001, 1006]',
#                            '[1002, 1006]',
#                            '[116, 120]',
#                            '[1292, 1296]',
#                            '[1428, 1432]',
#                            '[1494, 1498]',
#                            '[1596, 1601]',
#                            '[319, 323]',
#                            '[328, 332]',
#                            '[674, 678]',
#                            '[700, 704]',
#                            '[899, 903]'},
#                           'mention': {'mice', 'mouse'},
#                           'canonical name': {'Mouse'},
#                           'type': {''},
#                           'annotator': {'NIO'}}),
#              '11820': defaultdict(set,
#                          {'article': {'CCC_000647663200001'},
#                           'span': {'[152, 177]'},
#                           'mention': {'Amyloid precursor protein'},
#                           'canonical name': {''},
#                           'type': {'Gene'},
#                           'annotator': {'PTC'}}),
#              'AlzheimerOntology:amyloid_precursor_protein': defaultdict(set,
#                          {'article': {'CCC_000647663200001', 'NLM_33988687'},
#                           'span': {'[1464, 1467]',
#                            '[1486, 1489]',
#                            '[152, 177]',
#                            '[1560, 1563]',
#                            '[179, 182]',
#                            '[24, 27]',
#                            '[373, 376]',
#                            '[464, 467]',
#                            '[971, 974]'},
#                           'mention': {'APP', 'Amyloid precursor protein'},
#                           'canonical name': {'amyloid precursor protein'},
#                           'type': {''},
#                           'annotator': {'NIO'}}),
#              'AlzheimerOntology:protein': defaultdict(set,
#                          {'article': {'CCC_000647663200001'},
#                           'span': {'[170, 177]'},
#                           'mention': {'protein'},
#                           'canonical name': {'protein'},
#                           'type': {''},
#                           'annotator': {'NIO'}}),
#              'AlzheimerOntology:APP': defaultdict(set,
#                          {'article': {'CCC_000647663200001', 'NLM_33988687'},
#                           'span': {'[1464, 1467]',
#                            '[1486, 1489]',
#                            '[1560, 1563]',
#                            '[179, 182]',
#                            '[24, 27]',
#                            '[373, 376]',
#                            '[464, 467]',
#                            '[971, 974]'},
#                           'mention': {'APP'},
#                           'canonical name': {'APP'},
#                           'type': {''},
#                           'annotator': {'NIO'}}),
#              'obo:NBO_0000215': defaultdict(set,
#                          {'article': {'CCC_000647663200001',
#                            'NLM_31721178',
#                            'NLM_33730588'},
#                           'span': {'[1047, 1055]',
#                            '[1602, 1608]',
#                            '[202, 207]',
#                            '[908, 913]'},
#                           'mention': {'model', 'modeling', 'models'},
#                           'canonical name': {'observational learning'},
#                           'type': {''},
#                           'annotator': {'NIO'}}),
#              'NDDUO:model': defaultdict(set,
#                          {'article': {'CCC_000647663200001',
#                            'NLM_31721178',
#                            'NLM_33730588'},
#                           'span': {'[1047, 1055]',
#                            '[1602, 1608]',
#                            '[202, 207]',
#                            '[908, 913]'},
#                           'mention': {'model', 'modeling', 'models'},
#                           'canonical name': {'model'},
#                           'type': {''},
#                           'annotator': {'NIO'}}),
#              'obo:BFO_0000034': defaultdict(set,
#                          {'article': {'CCC_000647663200001'},
#                           'span': {'[252, 260]', '[747, 755]', '[830, 838]'},
#                           'mention': {'function'},
#                           'canonical name': {'function'},
#                           'type': {''},
#                           'annotator': {'NIO'}}),
#              'snap:Function': defaultdict(set,
#                          {'article': {'CCC_000647663200001'},
#                           'span': {'[252, 260]', '[747, 755]', '[830, 838]'},
#                           'mention': {'function'},
#                           'canonical name': {'function'},
#                           'type': {''},
#                           'annotator': {'NIO'}}),
#              'MESH:D000544': defaultdict(set,
#                          {'article': {'CCC_000647663200001',
#                            'CCC_000653155500009',
#                            'NLM_31721178',
#                            'NLM_33730588',
#                            'NLM_33958804',
#                            'NLM_33988687',
#                            'NLM_34060233',
#                            'NLM_34095440',
#                            'NLM_34101788'},
#                           'span': {'[0, 19]',
#                            '[0, 9]',
#                            '[1023, 1025]',
#                            '[1046, 1048]',
#                            '[107, 126]',
#                            '[1260, 1262]',
#                            '[128, 130]',
#                            '[128, 159]',
#                            '[1476, 1478]',
#                            '[1612, 1614]',
#                            '[162, 181]',
#                            '[18, 37]',
#                            '[183, 185]',
#                            '[1846, 1865]',
#                            '[1867, 1869]',
#                            '[219, 238]',
#                            '[227, 246]',
#                            '[240, 242]',
#                            '[248, 250]',
#                            '[262, 281]',
#                            '[264, 273]',
#                            '[276, 278]',
#                            '[283, 285]',
#                            '[285, 287]',
#                            '[466, 468]',
#                            '[557, 559]',
#                            '[578, 587]',
#                            '[610, 612]',
#                            '[626, 628]',
#                            '[732, 734]',
#                            '[770, 772]',
#                            '[788, 790]',
#                            '[83, 102]',
#                            '[86, 105]',
#                            '[94, 113]',
#                            '[994, 996]'},
#                           'mention': {'AD',
#                            'Alzheimer',
#                            "Alzheimer's disease",
#                            "hallmark of Alzheimer's disease"},
#                           'canonical name': {''},
#                           'type': {'Disease'},
#                           'annotator': {'PTC'}}),
#              'AlzheimerOntology:Subtypes': defaultdict(set,
#                          {'article': {'CCC_000647663200001',
#                            'CCC_000653155500009',
#                            'NLM_31721178',
#                            'NLM_33730588',
#                            'NLM_33958804',
#                            'NLM_33988687',
#                            'NLM_34060233',
#                            'NLM_34095440',
#                            'NLM_34101788'},
#                           'span': {'[0, 11]',
#                            '[0, 19]',
#                            '[0, 9]',
#                            '[1023, 1025]',
#                            '[1046, 1048]',
#                            '[107, 116]',
#                            '[107, 118]',
#                            '[107, 126]',
#                            '[1260, 1262]',
#                            '[128, 130]',
#                            '[140, 149]',
#                            '[140, 151]',
#                            '[140, 159]',
#                            '[1476, 1478]',
#                            '[161, 163]',
#                            '[1612, 1614]',
#                            '[162, 171]',
#                            '[162, 173]',
#                            '[162, 181]',
#                            '[18, 27]',
#                            '[18, 29]',
#                            '[18, 37]',
#                            '[183, 185]',
#                            '[1846, 1855]',
#                            '[1846, 1857]',
#                            '[1846, 1865]',
#                            '[1867, 1869]',
#                            '[219, 228]',
#                            '[219, 230]',
#                            '[219, 238]',
#                            '[227, 236]',
#                            '[227, 238]',
#                            '[227, 246]',
#                            '[240, 242]',
#                            '[248, 250]',
#                            '[262, 271]',
#                            '[262, 273]',
#                            '[262, 281]',
#                            '[264, 273]',
#                            '[264, 275]',
#                            '[264, 283]',
#                            '[276, 278]',
#                            '[283, 285]',
#                            '[285, 287]',
#                            '[358, 360]',
#                            '[4, 6]',
#                            '[458, 467]',
#                            '[458, 469]',
#                            '[458, 477]',
#                            '[466, 468]',
#                            '[48, 57]',
#                            '[48, 59]',
#                            '[48, 67]',
#                            '[493, 495]',
#                            '[525, 527]',
#                            '[547, 549]',
#                            '[557, 559]',
#                            '[578, 587]',
#                            '[578, 589]',
#                            '[610, 612]',
#                            '[626, 628]',
#                            '[732, 734]',
#                            '[767, 769]',
#                            '[770, 772]',
#                            '[788, 790]',
#                            '[83, 102]',
#                            '[83, 92]',
#                            '[83, 94]',
#                            '[86, 105]',
#                            '[86, 95]',
#                            '[86, 97]',
#                            '[94, 103]',
#                            '[94, 105]',
#                            '[94, 113]',
#                            '[994, 996]'},
#                           'mention': {'AD',
#                            'Alzheimer',
#                            "Alzheimer's",
#                            "Alzheimer's Disease",
#                            "Alzheimer's disease",
#                            'Alzheimer?s',
#                            'Alzheimer?s disease'},
#                           'canonical name': {'Alzheimer disease'},
#                           'type': {''},
#                           'annotator': {'NIO'}}),
#              'MESH:D010300': defaultdict(set,
#                          {'article': {'CCC_000647663200001'},
#                           'span': {'[274, 283]'},
#                           'mention': {'s disease'},
#                           'canonical name': {''},
#                           'type': {'Disease'},
#                           'annotator': {'PTC'}}),
#              'obo:OGMS_0000023': defaultdict(set,
#                          {'article': {'CCC_000647663200001'},
#                           'span': {'[298, 308]'},
#                           'mention': {'phenotypes'},
#                           'canonical name': {'phenotype'},
#                           'type': {''},
#                           'annotator': {'NIO'}}),
#              'MESH:C468911': defaultdict(set,
#                          {'article': {'CCC_000647663200001'},
#                           'span': {'[524, 537]'},
#                           'mention': {'amyloidogenic'},
#                           'canonical name': {''},
#                           'type': {'Chemical'},
#                           'annotator': {'PTC'}}),
#              'MESH:C011973': defaultdict(set,
#                          {'article': {'CCC_000647663200001'},
#                           'span': {'[1324, 1337]', '[539, 552]'},
#                           'mention': {'42-amino acid'},
#                           'canonical name': {''},
#                           'type': {'Chemical'},
#                           'annotator': {'PTC'}}),
#              'AlzheimerOntology:presence_of_amyloid_plaque': defaultdict(set,
#                          {'article': {'CCC_000647663200001'},
#                           'span': {'[595, 609]', '[603, 609]'},
#                           'mention': {'amyloid plaque', 'plaque'},
#                           'canonical name': {'presence of amyloid plaque'},
#                           'type': {''},
#                           'annotator': {'NIO'}}),
#              'AlzheimerOntology:senile_plaque': defaultdict(set,
#                          {'article': {'CCC_000647663200001'},
#                           'span': {'[603, 609]'},
#                           'mention': {'plaque'},
#                           'canonical name': {'presence of senile plaque'},
#                           'type': {''},
#                           'annotator': {'NIO'}}),
#              'NDDUO:In_vivo': defaultdict(set,
#                          {'article': {'CCC_000647663200001'},
#                           'span': {'[842, 846]'},
#                           'mention': {'vivo'},
#                           'canonical name': {'In vivo thing'},
#                           'type': {''},
#                           'annotator': {'NIO'}}),
#              'obo:OBI_0000070': defaultdict(set,
#                          {'article': {'CCC_000647663200001',
#                            'CCC_000653155500009',
#                            'NLM_33730588'},
#                           'span': {'[1045, 1052]',
#                            '[1415, 1420]',
#                            '[1747, 1752]',
#                            '[835, 840]'},
#                           'mention': {'assay', 'assayed'},
#                           'canonical name': {'assay'},
#                           'type': {''},
#                           'annotator': {'NIO'}}),
#              'NDDUO:male': defaultdict(set,
#                          {'article': {'CCC_000647663200001'},
#                           'span': {'[1276, 1280]'},
#                           'mention': {'male'},
#                           'canonical name': {'male'},
#                           'type': {''},
#                           'annotator': {'NIO'}}),
#              'NDDUO:female': defaultdict(set,
#                          {'article': {'CCC_000647663200001'},
#                           'span': {'[1285, 1291]'},
#                           'mention': {'female'},
#                           'canonical name': {'female'},
#                           'type': {''},
#                           'annotator': {'NIO'}}),
#              'AlzheimerOntology:presenilin': defaultdict(set,
#                          {'article': {'CCC_000647663200001'},
#                           'span': {'[1472, 1482]'},
#                           'mention': {'Presenilin'},
#                           'canonical name': {'presenilin'},
#                           'type': {''},
#                           'annotator': {'NIO'}}),
#              '19164': defaultdict(set,
#                          {'article': {'CCC_000647663200001'},
#                           'span': {'[1472, 1484]', '[1490, 1493]'},
#                           'mention': {'PS1', 'Presenilin 1'},
#                           'canonical name': {''},
#                           'type': {'Gene'},
#                           'annotator': {'PTC'}}),
#              'AlzheimerOntology:presenilin_1': defaultdict(set,
#                          {'article': {'CCC_000647663200001'},
#                           'span': {'[1472, 1484]'},
#                           'mention': {'Presenilin 1'},
#                           'canonical name': {'presenilin 1'},
#                           'type': {''},
#                           'annotator': {'NIO'}}),
#              'NDDUO:In_vivo_models': defaultdict(set,
#                          {'article': {'CCC_000647663200001'},
#                           'span': {'[1596, 1608]'},
#                           'mention': {'mouse models'},
#                           'canonical name': {'In vivo model'},
#                           'type': {''},
#                           'annotator': {'NIO'}}),
#              'NDDUO:Cluster': defaultdict(set,
#                          {'article': {'CCC_000647663200001',
#                            'NLM_31721178',
#                            'NLM_33730588'},
#                           'span': {'[1060, 1071]',
#                            '[1798, 1809]',
#                            '[216, 227]',
#                            '[571, 582]',
#                            '[995, 1006]'},
#                           'mention': {'aggregation'},
#                           'canonical name': {'Cluster'},
#                           'type': {''},
#                           'annotator': {'NIO'}}),
#              'obo:BFO_0000023': defaultdict(set,
#                          {'article': {'CCC_000647663200001'},
#                           'span': {'[1856, 1860]'},
#                           'mention': {'role'},
#                           'canonical name': {'role'},
#                           'type': {''},
#                           'annotator': {'NIO'}}),
#              'snap:Role': defaultdict(set,
#                          {'article': {'CCC_000647663200001'},
#                           'span': {'[1856, 1860]'},
#                           'mention': {'role'},
#                           'canonical name': {'role'},
#                           'type': {''},
#                           'annotator': {'NIO'}}),
#              'obo:RO_0000081': defaultdict(set,
#                          {'article': {'CCC_000647663200001'},
#                           'span': {'[1856, 1863]'},
#                           'mention': {'role of'},
#                           'canonical name': {'role of'},
#                           'type': {''},
#                           'annotator': {'NIO'}}),
#              'MESH:C039408': defaultdict(set,
#                          {'article': {'CCC_000653155500009'},
#                           'span': {'[927, 947]'},
#                           'mention': {'Trithiocyanuric acid'},
#                           'canonical name': {''},
#                           'type': {'Chemical'},
#                           'annotator': {'PTC'}}),
#              'MESH:C011126': defaultdict(set,
#                          {'article': {'CCC_000653155500009'},
#                           'span': {'[1015, 1017]', '[949, 951]'},
#                           'mention': {'TA'},
#                           'canonical name': {''},
#                           'type': {'Chemical'},
#                           'annotator': {'PTC'}}),
#              'obo:NBO_0000282': defaultdict(set,
#                          {'article': {'CCC_000653155500009'},
#                           'span': {'[1010, 1014]'},
#                           'mention': {'like'},
#                           'canonical name': {'liking'},
#                           'type': {''},
#                           'annotator': {'NIO'}}),
#              'NDDUO:Sampling': defaultdict(set,
#                          {'article': {'CCC_000653155500009', 'NLM_34060233'},
#                           'span': {'[1694, 1701]', '[449, 456]'},
#                           'mention': {'samples'},
#                           'canonical name': {'Sampling'},
#                           'type': {''},
#                           'annotator': {'NIO'}}),
#              'AlzheimerOntology:Memory_orientation_screening_test': defaultdict(set,
#                          {'article': {'CCC_000653155500009', 'NLM_34095440'},
#                           'span': {'[1804, 1808]', '[851, 855]', '[884, 888]'},
#                           'mention': {'many', 'more'},
#                           'canonical name': {'Memory Orientation Screening Test'},
#                           'type': {''},
#                           'annotator': {'NIO'}}),
#              'AlzheimerOntology:t_tau': defaultdict(set,
#                          {'article': {'NLM_31721178',
#                            'NLM_33730588',
#                            'NLM_33958804',
#                            'NLM_34060233'},
#                           'span': {'[0, 3]',
#                            '[1006, 1009]',
#                            '[1042, 1045]',
#                            '[1056, 1059]',
#                            '[1123, 1126]',
#                            '[1135, 1138]',
#                            '[1157, 1160]',
#                            '[1277, 1280]',
#                            '[1397, 1400]',
#                            '[1521, 1524]',
#                            '[212, 215]',
#                            '[268, 271]',
#                            '[287, 290]',
#                            '[291, 294]',
#                            '[322, 325]',
#                            '[361, 364]',
#                            '[406, 409]',
#                            '[485, 488]',
#                            '[496, 499]',
#                            '[528, 531]',
#                            '[550, 553]',
#                            '[608, 611]',
#                            '[674, 677]',
#                            '[7, 10]',
#                            '[70, 73]',
#                            '[804, 807]',
#                            '[865, 868]',
#                            '[87, 90]',
#                            '[892, 895]',
#                            '[944, 947]',
#                            '[991, 994]'},
#                           'mention': {'Tau', 'tau'},
#                           'canonical name': {'t-tau'},
#                           'type': {''},
#                           'annotator': {'NIO'}}),
#              'AlzheimerOntology:Filaments': defaultdict(set,
#                          {'article': {'NLM_31721178', 'NLM_33730588'},
#                           'span': {'[151, 160]',
#                            '[20, 29]',
#                            '[291, 299]',
#                            '[505, 514]',
#                            '[571, 580]',
#                            '[671, 680]',
#                            '[77, 86]',
#                            '[81, 90]',
#                            '[868, 876]',
#                            '[967, 976]'},
#                           'mention': {'filament', 'filaments'},
#                           'canonical name': {'Filament'},
#                           'type': {''},
#                           'annotator': {'NIO'}}),
#              'obo:IAO_0000224': defaultdict(set,
#                          {'article': {'NLM_31721178', 'NLM_33730588'},
#                           'span': {'[11, 15]',
#                            '[300, 305]',
#                            '[365, 369]',
#                            '[468, 472]',
#                            '[500, 504]',
#                            '[554, 558]',
#                            '[58, 62]',
#                            '[877, 882]',
#                            '[934, 938]'},
#                           'mention': {'core', 'cores'},
#                           'canonical name': {'core'},
#                           'type': {''},
#                           'annotator': {'NIO'}}),
#              'AlzheimerOntology:neurofibrillary_tangle': defaultdict(set,
#                          {'article': {'NLM_31721178'},
#                           'span': {'[171, 194]'},
#                           'mention': {'neurofibrillary tangles'},
#                           'canonical name': {'neurofibrillary tangle'},
#                           'type': {''},
#                           'annotator': {'NIO'}}),
#              'AlzheimerOntology:Tangles': defaultdict(set,
#                          {'article': {'NLM_31721178'},
#                           'span': {'[187, 194]'},
#                           'mention': {'tangles'},
#                           'canonical name': {'Tangle'},
#                           'type': {''},
#                           'annotator': {'NIO'}}),
#              'MESH:D024801': defaultdict(set,
#                          {'article': {'NLM_31721178', 'NLM_33730588'},
#                           'span': {'[175, 186]', '[297, 308]'},
#                           'mention': {'tauopathies'},
#                           'canonical name': {''},
#                           'type': {'Disease'},
#                           'annotator': {'PTC'}}),
#              'obo:ND_0000151': defaultdict(set,
#                          {'article': {'NLM_31721178', 'NLM_33730588'},
#                           'span': {'[175, 186]', '[297, 308]'},
#                           'mention': {'tauopathies'},
#                           'canonical name': {'tauopathy'},
#                           'type': {''},
#                           'annotator': {'NIO'}}),
#              'AlzheimerOntology:tauopathy': defaultdict(set,
#                          {'article': {'NLM_31721178',
#                            'NLM_33730588',
#                            'NLM_33958804',
#                            'NLM_34060233'},
#                           'span': {'[1157, 1170]',
#                            '[175, 186]',
#                            '[268, 281]',
#                            '[297, 308]',
#                            '[528, 541]',
#                            '[865, 878]',
#                            '[944, 957]'},
#                           'mention': {'tau pathology', 'tauopathies'},
#                           'canonical name': {'tauopathy'},
#                           'type': {''},
#                           'annotator': {'NIO'}}),
#              'MESH:D006493': defaultdict(set,
#                          {'article': {'NLM_31721178'},
#                           'span': {'[377, 384]'},
#                           'mention': {'heparin'},
#                           'canonical name': {''},
#                           'type': {'Chemical'},
#                           'annotator': {'PTC'}}),
#              'AlzheimerOntology:brain_tissue': defaultdict(set,
#                          {'article': {'NLM_31721178'},
#                           'span': {'[867, 879]'},
#                           'mention': {'brain tissue'},
#                           'canonical name': {'brain tissue'},
#                           'type': {''},
#                           'annotator': {'NIO'}}),
#              'NDDUO:Screening': defaultdict(set,
#                          {'article': {'NLM_31721178'},
#                           'span': {'[963, 972]'},
#                           'mention': {'screening'},
#                           'canonical name': {'Screening'},
#                           'type': {''},
#                           'annotator': {'NIO'}}),
#              'NDDUO:inhibitor': defaultdict(set,
#                          {'article': {'NLM_31721178'},
#                           'span': {'[977, 987]'},
#                           'mention': {'inhibitors'},
#                           'canonical name': {'inhibitor'},
#                           'type': {''},
#                           'annotator': {'NIO'}}),
#              'MESH:C536599': defaultdict(set,
#                          {'article': {'NLM_31721178', 'NLM_33730588'},
#                           'span': {'[1056, 1071]',
#                            '[212, 227]',
#                            '[991, 1006]'},
#                           'mention': {'tau aggregation'},
#                           'canonical name': {''},
#                           'type': {'Disease'},
#                           'annotator': {'PTC'}}),
#              'AlzheimerOntology:antibody': defaultdict(set,
#                          {'article': {'NLM_33730588'},
#                           'span': {'[464, 474]'},
#                           'mention': {'antibodies'},
#                           'canonical name': {'antibody'},
#                           'type': {''},
#                           'annotator': {'NIO'}}),
#              'AlzheimerOntology:cerebrospinal_fluid': defaultdict(set,
#                          {'article': {'NLM_33730588'},
#                           'span': {'[722, 741]', '[743, 746]'},
#                           'mention': {'CSF', 'cerebrospinal fluid'},
#                           'canonical name': {'cerebrospinal fluid'},
#                           'type': {''},
#                           'annotator': {'NIO'}}),
#              'AlzheimerOntology:Cerebospinal_Fluid': defaultdict(set,
#                          {'article': {'NLM_33730588'},
#                           'span': {'[743, 746]'},
#                           'mention': {'CSF'},
#                           'canonical name': {'protein circulating in Cerebospinal Fluid'},
# ...
#                           'type': {'Gene'},
#                           'annotator': {'PTC'}}),
#              'AlzheimerOntology:BIN1': defaultdict(set,
#                          {'article': {'NLM_34060233'},
#                           'span': {'[1232, 1236]',
#                            '[144, 148]',
#                            '[1460, 1464]',
#                            '[369, 373]',
#                            '[4, 8]',
#                            '[763, 767]',
#                            '[867, 871]',
#                            '[950, 954]'},
#                           'mention': {'BIN1'},
#                           'canonical name': {'BIN1'},
#                           'type': {''},
#                           'annotator': {'NIO'}}),
#              'rs744373': defaultdict(set,
#                          {'article': {'NLM_34060233'},
#                           'span': {'[1091, 1099]',
#                            '[1328, 1336]',
#                            '[149, 157]',
#                            '[374, 382]',
#                            '[768, 776]',
#                            '[872, 880]',
#                            '[9, 17]',
#                            '[955, 963]'},
#                           'mention': {'rs744373'},
#                           'canonical name': {''},
#                           'type': {'SNP'},
#                           'annotator': {'PTC'}}),
#              'NDDUO:Risk_factor': defaultdict(set,
#                          {'article': {'NLM_34060233'},
#                           'span': {'[1237, 1241]',
#                            '[1479, 1483]',
#                            '[212, 216]',
#                            '[38, 42]',
#                            '[964, 968]'},
#                           'mention': {'risk'},
#                           'canonical name': {'Risk factor'},
#                           'type': {''},
#                           'annotator': {'NIO'}}),
#              'AlzheimerOntology:Cognitive_Tests': defaultdict(set,
#                          {'article': {'NLM_34060233', 'NLM_34095440'},
#                           'span': {'[108, 117]',
#                            '[1348, 1357]',
#                            '[673, 682]',
#                            '[720, 729]',
#                            '[922, 931]'},
#                           'mention': {'cognitive'},
#                           'canonical name': {'Cognitive Test'},
#                           'type': {''},
#                           'annotator': {'NIO'}}),
#              'AlzheimerOntology:Moderate_cognitive_Decline': defaultdict(set,
#                          {'article': {'NLM_34060233'},
#                           'span': {'[108, 125]', '[1348, 1365]', '[922, 939]'},
#                           'mention': {'cognitive decline'},
#                           'canonical name': {'Moderate cognitive Decline'},
#                           'type': {''},
#                           'annotator': {'NIO'}}),
#              'AlzheimerOntology:mental_disorder': defaultdict(set,
#                          {'article': {'NLM_34060233'},
#                           'span': {'[108, 125]', '[1348, 1365]', '[922, 939]'},
#                           'mention': {'cognitive decline'},
#                           'canonical name': {'mental disorder'},
#                           'type': {''},
#                           'annotator': {'NIO'}}),
#              'AlzheimerOntology:neuroimaging': defaultdict(set,
#                          {'article': {'NLM_34060233'},
#                           'span': {'[1028, 1032]',
#                            '[1139, 1143]',
#                            '[1322, 1326]',
#                            '[458, 501]',
#                            '[478, 490]',
#                            '[503, 507]'},
#                           'mention': {'ADNI',
#                            "Alzheimer's Disease Neuroimaging Initiative",
#                            'Neuroimaging'},
#                           'canonical name': {'neuroimaging'},
#                           'type': {''},
#                           'annotator': {'NIO'}}),
#              'NDDUO:disorder': defaultdict(set,
#                          {'article': {'NLM_34060233'},
#                           'span': {'[546, 573]', '[564, 573]'},
#                           'mention': {'Disorders',
#                            'Neurodegenerative Disorders'},
#                           'canonical name': {'disorder'},
#                           'type': {''},
#                           'annotator': {'NIO'}}),
#              'NDDUO:neurodegenerative_disease': defaultdict(set,
#                          {'article': {'NLM_34060233'},
#                           'span': {'[546, 573]'},
#                           'mention': {'Neurodegenerative Disorders'},
#                           'canonical name': {'neurodegenerative disease'},
#                           'type': {''},
#                           'annotator': {'NIO'}}),
#              'MESH:D017887': defaultdict(set,
#                          {'article': {'NLM_34060233'},
#                           'span': {'[619, 631]'},
#                           'mention': {'longitudinal'},
#                           'canonical name': {''},
#                           'type': {'Disease'},
#                           'annotator': {'PTC'}}),
#              'MESH:D005461': defaultdict(set,
#                          {'article': {'NLM_34060233'},
#                           'span': {'[637, 660]'},
#                           'mention': {'F-Flortaucipir positron'},
#                           'canonical name': {''},
#                           'type': {'Chemical'},
#                           'annotator': {'PTC'}}),
#              'AlzheimerOntology:Positron_emission_tomography': defaultdict(set,
#                          {'article': {'NLM_34060233'},
#                           'span': {'[1010, 1013]',
#                            '[1127, 1130]',
#                            '[1281, 1284]',
#                            '[1401, 1404]',
#                            '[652, 680]',
#                            '[682, 685]',
#                            '[808, 811]',
#                            '[896, 899]'},
#                           'mention': {'PET', 'positron emission tomography'},
#                           'canonical name': {'Positron emission tomography'},
#                           'type': {''},
#                           'annotator': {'NIO'}}),
#              'MESH:D003072': defaultdict(set,
#                          {'article': {'NLM_34060233'},
#                           'span': {'[707, 729]'},
#                           'mention': {'longitudinal cognitive'},
#                           'canonical name': {''},
#                           'type': {'Disease'},
#                           'annotator': {'PTC'}}),
#              'NDDUO:drug': defaultdict(set,
#                          {'article': {'NLM_34095440', 'NLM_34101788'},
#                           'span': {'[1049, 1054]',
#                            '[20, 24]',
#                            '[230, 235]',
#                            '[28, 32]',
#                            '[377, 382]',
#                            '[553, 558]',
#                            '[714, 719]'},
#                           'mention': {'Drug', 'drug', 'drugs'},
#                           'canonical name': {'drug'},
#                           'type': {''},
#                           'annotator': {'NIO'}}),
#              'NDDUO:rate': defaultdict(set,
#                          {'article': {'NLM_34095440'},
#                           'span': {'[154, 158]'},
#                           'mention': {'rate'},
#                           'canonical name': {'rate'},
#                           'type': {''},
#                           'annotator': {'NIO'}}),
#              'NDDUO:Clinical': defaultdict(set,
#                          {'article': {'NLM_34095440', 'NLM_34101788'},
#                           'span': {'[199, 207]',
#                            '[239, 247]',
#                            '[349, 357]',
#                            '[756, 764]'},
#                           'mention': {'clinical'},
#                           'canonical name': {'Clinical thing'},
#                           'type': {''},
#                           'annotator': {'NIO'}}),
#              'NDDUO:Clinical_trial': defaultdict(set,
#                          {'article': {'NLM_34095440', 'NLM_34101788'},
#                           'span': {'[199, 214]',
#                            '[239, 254]',
#                            '[349, 364]',
#                            '[756, 770]'},
#                           'mention': {'clinical trial', 'clinical trials'},
#                           'canonical name': {'thing related to clinical trial'},
#                           'type': {''},
#                           'annotator': {'NIO'}}),
#              'NDDUO:phase_3': defaultdict(set,
#                          {'article': {'NLM_34095440'},
#                           'span': {'[487, 494]'},
#                           'mention': {'Phase 3'},
#                           'canonical name': {'phase 3'},
#                           'type': {''},
#                           'annotator': {'NIO'}}),
#              'NDDUO:phase_2': defaultdict(set,
#                          {'article': {'NLM_34095440'},
#                           'span': {'[509, 516]'},
#                           'mention': {'Phase 2'},
#                           'canonical name': {'phase 2'},
#                           'type': {''},
#                           'annotator': {'NIO'}}),
#              'NDDUO:phase_1': defaultdict(set,
#                          {'article': {'NLM_34095440'},
#                           'span': {'[528, 535]'},
#                           'mention': {'Phase 1'},
#                           'canonical name': {'phase 1'},
#                           'type': {''},
#                           'annotator': {'NIO'}}),
#              'AlzheimerOntology:Neuropsychiatric_symptoms': defaultdict(set,
#                          {'article': {'NLM_34095440'},
#                           'span': {'[746, 771]'},
#                           'mention': {'neuropsychiatric symptoms'},
#                           'canonical name': {'Neuropsychiatric symptom'},
#                           'type': {''},
#                           'annotator': {'NIO'}}),
#              'AlzheimerOntology:psychological_symptom': defaultdict(set,
#                          {'article': {'NLM_34095440'},
#                           'span': {'[746, 771]'},
#                           'mention': {'neuropsychiatric symptoms'},
#                           'canonical name': {'psychological symptom'},
#                           'type': {''},
#                           'annotator': {'NIO'}}),
#              'NDDUO:Symptoms': defaultdict(set,
#                          {'article': {'NLM_34095440'},
#                           'span': {'[763, 771]'},
#                           'mention': {'symptoms'},
#                           'canonical name': {'Symptom or sign'},
#                           'type': {''},
#                           'annotator': {'NIO'}}),
#              'AlzheimerOntology:control_group_study_arm': defaultdict(set,
#                          {'article': {'NLM_34101788'},
#                           'span': {'[349, 355]'},
#                           'mention': {'groups'},
#                           'canonical name': {'control group study arm'},
#                           'type': {''},
#                           'annotator': {'NIO'}}),
#              'obo:OBI_0000272': defaultdict(set,
#                          {'article': {'NLM_34101788'},
#                           'span': {'[369, 378]'},
#                           'mention': {'protocols'},
#                           'canonical name': {'protocol'},
#                           'type': {''},
#                           'annotator': {'NIO'}}),
#              'AlzheimerOntology:Outcome': defaultdict(set,
#                          {'article': {'NLM_34101788'},
#                           'span': {'[383, 390]', '[482, 490]'},
#                           'mention': {'outcome', 'outcomes'},
#                           'canonical name': {'Outcome'},
#                           'type': {''},
#                           'annotator': {'NIO'}}),
#              'NDDUO:Outcome': defaultdict(set,
#                          {'article': {'NLM_34101788'},
#                           'span': {'[383, 390]', '[482, 490]'},
#                           'mention': {'outcome', 'outcomes'},
#                           'canonical name': {'Thing related to outcome'},
#                           'type': {''},
#                           'annotator': {'NIO'}}),
#              'NDDUO:outcome_measure': defaultdict(set,
#                          {'article': {'NLM_34101788'},
#                           'span': {'[383, 399]'},
#                           'mention': {'outcome measures'},
#                           'canonical name': {'outcome measure'},
#                           'type': {''},
#                           'annotator': {'NIO'}}),
#              'obo:GO_0007612': defaultdict(set,
#                          {'article': {'NLM_34101788'},
#                           'span': {'[540, 547]'},
#                           'mention': {'learned'},
#                           'canonical name': {'learning'},
#                           'type': {''},
#                           'annotator': {'NIO'}}),
#              'MESH:C559645': defaultdict(set,
#                          {'article': {'NLM_34101788'},
#                           'span': {'[611, 618]', '[851, 858]'},
#                           'mention': {'DIAN-TU'},
#                           'canonical name': {''},
#                           'type': {'Chemical'},
#                           'annotator': {'PTC'}}),
#              'obo:MF_0000027': defaultdict(set,
#                          {'article': {'NLM_34101788'},
#                           'span': {'[722, 730]'},
#                           'mention': {'planning'},
#                           'canonical name': {'planning'},
#                           'type': {''},
#                           'annotator': {'NIO'}}),
#              'obo:OBI_0000260': defaultdict(set,
#                          {'article': {'NLM_34101788'},
#                           'span': {'[722, 730]'},
#                           'mention': {'planning'},
#                           'canonical name': {'plan'},
#                           'type': {''},
#                           'annotator': {'NIO'}}),
#              'obo:OBI_0000339': defaultdict(set,
#                          {'article': {'NLM_34101788'},
#                           'span': {'[722, 730]'},
#                           'mention': {'planning'},
#                           'canonical name': {'planning'},
#                           'type': {''},
#                           'annotator': {'NIO'}}),
#              'NDDUO:Stages': defaultdict(set,
#                          {'article': {'NLM_34101788'},
#                           'span': {'[731, 737]'},
#                           'mention': {'stages'},
#                           'canonical name': {'thing related to stage'},
#                           'type': {''},
#                           'annotator': {'NIO'}}),
#              'NDDO:NDDO_00000107': defaultdict(set,
#                          {'article': {'NLM_34101788'},
#                           'span': {'[989, 996]'},
#                           'mention': {'cohorts'},
#                           'canonical name': {'cohort'},
#                           'type': {''},
#                           'annotator': {'NIO'}}),
#              'AlzheimerOntology:Cohort_effect': defaultdict(set,
#                          {'article': {'NLM_34101788'},
#                           'span': {'[989, 996]'},
#                           'mention': {'cohorts'},
#                           'canonical name': {'Cohort effect'},
#                           'type': {''},
#                           'annotator': {'NIO'}}),
#              'AlzheimerOntology:Populations': defaultdict(set,
#                          {'article': {'NLM_34101788'},
#                           'span': {'[1034, 1044]'},
#                           'mention': {'population'},
#                           'canonical name': {'Population'},
#                           'type': {''},
#                           'annotator': {'NIO'}})})

# %%
path
# Out:
# '/Users/yidesdo21/Projects/outputs/10_ptc_ten_recent/bag_of_identifiers/'

# %%
fields = ['concept_id', 'article', 'span', 'mention', 'canonical name', 'type', 'annotator']
file_name = "ten_article_id_info"

with open(path+file_name+'.csv', 'w') as f:
    writer = csv.DictWriter(f, fields)
    writer.writeheader()
    
    for key,val in sorted(id_dict.items()):
        row = {'concept_id': key}
        row.update(val)
        writer.writerow(row)
