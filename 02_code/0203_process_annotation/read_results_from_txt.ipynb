# %%
import spacy
from spacy import displacy
import xmltodict
from pathlib import Path
import json
from collections import defaultdict
import jsbeautifier

# %% [markdown]
# ### The first part is for the NIO annotations:
# - visusalize the NIO annotations removing the nested annotations in disPlacy
# - output the full NIO annotations (including the nested ones) in the json format

# %%
# automate the text span reading process
## step 1: read the outputs from the PathogenExperimenter, the outputs look like:
# ['article id:217583',
#  'predicted mention id:[obo:GO_0007613, obo:OGMS_0000031, NDDUO:Study_type, NDDUO:Study_type, obo:NBO_0000175, obo:GO_0007613, obo:BFO_0000015, obo:NBO_0000215, obo:NBO_0000175, obo:GO_0007613, obo:OBI_0000753, obo:BFO_0000015, obo:NBO_0000175, obo:GO_0007613, obo:BFO_0000015, obo:NBO_0000175, obo:GO_0007613]',
#  'predicted mention starts:[64, 382, 448, 448, 525, 546, 645, 725, 742, 763, 820, 1061, 1355, 1384, 1664, 1777, 1798]',
#  'predicted mention ends:[70, 389, 453, 453, 541, 552, 655, 730, 758, 769, 825, 1071, 1371, 1390, 1674, 1793, 1804]',
#  '----------',
## update for step 1: after running the articles in a large volume ~ 1000, the outputs look like:
# [[ISI_000328805100012], [[obo:GO_0007610, obo:NBO_0000313, ...]],
#  [[8, 8, ...]], [[17, 17, ...]], 
#  [NLM_17085785], [[AlzheimerOntology:amyloid_beta_protein, AlzheimerOntology:amyloid_beta_protein, ...]],
#  [[54, 54, ...]], [[66, 66, ...]], ...]
# [[article_title 1], [[UIDs for a1]], [[starting indices for a1]], [[ending indices for a1]],
#  [article_title 2], [[UIDs for a2]], [[starting indices for a2]], [[ending indices for a2]], ...]


output_path = "/Users/yidesdo21/Projects/outputs/10_ptc_ten_recent/txt/"
# output_file = "02_nio_with_canonical_as_variant/02_07_memory_recent_10.txt"
output_file = "nio_ten_recent_spans_nested_case.txt"

with open(output_path+output_file) as f:
    output = f.read().splitlines()[14:-2]

# %%
## step 2: link mention id to the canonical
##  goal - turn the nio.xml into a dictionary format
##  this is to use the canonical as the label in the spaCy's annotation 
## input format:
# <?xml version="1.0" ?>
# <synonym>
#     <token id="NDDO:NDDO_00000021" canonical="visit">
#         <variant base="visit"/>
#     </token>
#     <token id="NDDO:NDDO_00000022" canonical="diagnostic data">
#         <variant base="diagnostic data"/>
#     </token>
# </synonym>

## expected format:
# {"NDDO:NDDO_00000021": "visit",
#  "NDDO:NDDO_00000022": "diagnostic data"}

xml_path = "/Users/yidesdo21/Projects/inputs/dictionary/nio_ado_case.xml"
# xml_path = "/Users/yidesdo21/Projects/codes/nio_iri_v3_2.xml"

with open(xml_path) as f:
    nio_xml = f.read()

token_cano = dict()  # {"token_id": "canonical"}
nio_dict = xmltodict.parse(nio_xml)

canos = nio_dict["synonym"]["token"]
for cano in canos:
    token_cano[cano["@id"]] = cano["@canonical"]

# %%
## step 3: pull out the mentioned entities by slicing the article with starting and ending indices
##  3.1: create the package for each article, so we can access the mention ids, starting 
##       and ending indices for each article with the same index.
article_ids = list() # article_ids[i] to access the article id
mention_ids = list() # mention_ids[i] to access the list of mention ids for the [i]th article
start_ind = list()   # start_ind[i] to access the list of start indices for the [i]th article
end_ind = list()     # end_ind[i] to access the list of end indices for the [i]th article
docs = list()   # to create the list of dictionaries as the input for spaCy visualizer
                 # this has to be ourside of the articles iteration
docs_text = list()   # not for diaplacy, but for showing the mentioned entites with the canonical  

for k in range(len(output)):
    if k%5 == 0:  
        article_ids.append(output[k].split(":")[1])
    elif k%5 == 1:
        mention_id = output[k].split("[")[1][:-1].split(", ")
        mention_ids.append(mention_id)
    elif k%5 == 2:
        starts = output[k].split("[")[1][:-1].split(", ")
        start_ind.append([int(x) for x in starts])
    elif k%5 == 3:
        ends = output[k].split("[")[1][:-1].split(", ")
        end_ind.append([int(x) for x in ends])

# %%
##  3.2: iterate each article to create the annotation 
article_path = "/Users/yidesdo21/Projects/inputs/articles/04_ptc_ten_recent/articles-txt-format/" 
# article_path = "/Users/yidesdo21/Projects/inputs/articles/03_tests_for_dictionary/"
article_num = len(article_ids)
titles = dict()

for i in range(article_num):  # iteratre over each of the i[th] article
    with open(article_path+str(article_ids[i])+".txt") as f:  # use article ids here
        article = f.readlines()
        
    # for the i[th] article, get the lists of mention ids, starting and ending indices
    mention_ids_for_i = mention_ids[i]
    start_ind_for_i = start_ind[i]
    end_ind_for_i = end_ind[i]
    anno_len = len(mention_ids_for_i)
    
    ## step 4: visualize the text span with the annotations by using spaCy visualizer
    # create the list of dictionaries as the input for spaCy visualizer
    # ex = [{"text": "But Google is starting from behind.",
    #        "ents": [{"start": 4, "end": 10, "label": "ORG"}],
    #        "title": "Test"}]
    # html = displacy.render(ex, style="ent", manual=True, options={"colors":{"ORG":"yellow"}})

    article_dict = dict() 
    article_dict_text = dict()
    article_dict["title"] = article_ids[i]   
    article_dict["text"] = article[0]  # article is list of string, ["article"]
    article_dict_text["title"] = article_ids[i]   
    article_dict_text["text"] = article[0]  # article is list of string, ["article"]    
    
    title_mapping = article_ids[i].split("_")
    if len(title_mapping) > 1:   ## this is for the database_identifier format only
        titles[title_mapping[1]] = article_ids[i]   # to help the PTC titles to map from identifiers to the database_identfiier
    
    ents_list = list()
    ents_list_text = list()  # for docs_text

    ## there are duplications, need to filter; no need to filter if using spaCy visualizer, will overlay 
    # NDDUO:Study_type 549 554 study
    # ----------
    # NDDUO:Study_type 549 554 study

    start_end = set()  # use this to avoid the duplications in the starting-ending range 
    
    for anno_cnt in range(anno_len):  # iterate over all entity annotations in the i[th] article 
        mentioned_id = mention_ids_for_i[anno_cnt]
        start_index = start_ind_for_i[anno_cnt]
        end_index = end_ind_for_i[anno_cnt]
        mentioned_entity = article[0][start_index:end_index]
        canonical = token_cano[mentioned_id]
        
        if (start_index,end_index) not in start_end:
            start_end.add((start_index,end_index))
            ent = dict()
            ent["start"] = start_index
            ent["end"] = end_index
            ent["label"] = ""   # for illustration reasons
#             ent["label"] = mentioned_id+"|"+canonical  # change mentioned_entity into canonical in the xml dictionary
            ents_list.append(ent)                             # the labels can only be in uppercase

        ent_text = dict()   # this part is not affected because it is for the json not for the displacy
        ent_text["span"] = start_index, end_index
        ent_text["mention"] = mentioned_entity
        ent_text["identifier"] = mentioned_id    # the mention after grounding: ontological identifier
        ent_text["concept"] = canonical         # the mention after grounding: ontological concept
        ent_text["type"] = ""
        ent_text["annotator"] = "NIO"
        if ent_text not in ents_list_text:
#             print(ent_text)
#             print("--------")
            ents_list_text.append(ent_text)  
        
    article_dict["ents"] = ents_list 
    article_dict_text["ents"] = ents_list_text

    docs.append(article_dict)   # this has to be outside of the articles iteration
    docs_text.append(article_dict_text)  # similar to docs, but have mentioned_entities
# Out:
# {'span': (0, 3), 'mention': 'Tau', 'identifier': 'AlzheimerOntology:t_tau', 'concept': 't-tau', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (20, 29), 'mention': 'filaments', 'identifier': 'AlzheimerOntology:Filaments', 'concept': 'Filament', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (58, 62), 'mention': 'core', 'identifier': 'obo:IAO_0000224', 'concept': 'core', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (81, 90), 'mention': 'filaments', 'identifier': 'AlzheimerOntology:Filaments', 'concept': 'Filament', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (94, 113), 'mention': "Alzheimer's disease", 'identifier': 'AlzheimerOntology:Subtypes', 'concept': 'Alzheimer disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (94, 105), 'mention': "Alzheimer's", 'identifier': 'AlzheimerOntology:Subtypes', 'concept': 'Alzheimer disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (94, 103), 'mention': 'Alzheimer', 'identifier': 'AlzheimerOntology:Subtypes', 'concept': 'Alzheimer disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (106, 113), 'mention': 'disease', 'identifier': 'obo:OGMS_0000031', 'concept': 'disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (106, 113), 'mention': 'disease', 'identifier': 'NDDUO:disease', 'concept': 'disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (114, 119), 'mention': 'brain', 'identifier': 'obo:FMA_50801', 'concept': 'Brain', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (114, 119), 'mention': 'brain', 'identifier': 'AlzheimerOntology:brain', 'concept': 'brain', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (151, 160), 'mention': 'filaments', 'identifier': 'AlzheimerOntology:Filaments', 'concept': 'Filament', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (171, 194), 'mention': 'neurofibrillary tangles', 'identifier': 'AlzheimerOntology:neurofibrillary_tangle', 'concept': 'neurofibrillary tangle', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (187, 194), 'mention': 'tangles', 'identifier': 'AlzheimerOntology:Tangles', 'concept': 'Tangle', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (262, 281), 'mention': "Alzheimer's disease", 'identifier': 'AlzheimerOntology:Subtypes', 'concept': 'Alzheimer disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (262, 273), 'mention': "Alzheimer's", 'identifier': 'AlzheimerOntology:Subtypes', 'concept': 'Alzheimer disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (262, 271), 'mention': 'Alzheimer', 'identifier': 'AlzheimerOntology:Subtypes', 'concept': 'Alzheimer disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (274, 281), 'mention': 'disease', 'identifier': 'obo:OGMS_0000031', 'concept': 'disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (274, 281), 'mention': 'disease', 'identifier': 'NDDUO:disease', 'concept': 'disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (283, 285), 'mention': 'AD', 'identifier': 'AlzheimerOntology:Subtypes', 'concept': 'Alzheimer disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (291, 296), 'mention': 'other', 'identifier': 'obo:IAO_0000230', 'concept': 'other', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (297, 308), 'mention': 'tauopathies', 'identifier': 'obo:ND_0000151', 'concept': 'tauopathy', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (297, 308), 'mention': 'tauopathies', 'identifier': 'AlzheimerOntology:tauopathy', 'concept': 'tauopathy', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (322, 325), 'mention': 'tau', 'identifier': 'AlzheimerOntology:t_tau', 'concept': 't-tau', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (468, 472), 'mention': 'core', 'identifier': 'obo:IAO_0000224', 'concept': 'core', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (485, 488), 'mention': 'tau', 'identifier': 'AlzheimerOntology:t_tau', 'concept': 't-tau', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (571, 580), 'mention': 'filaments', 'identifier': 'AlzheimerOntology:Filaments', 'concept': 'Filament', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (671, 680), 'mention': 'filaments', 'identifier': 'AlzheimerOntology:Filaments', 'concept': 'Filament', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (733, 739), 'mention': 'brains', 'identifier': 'obo:FMA_50801', 'concept': 'Brain', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (733, 739), 'mention': 'brains', 'identifier': 'AlzheimerOntology:brain', 'concept': 'brain', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (770, 772), 'mention': 'AD', 'identifier': 'AlzheimerOntology:Subtypes', 'concept': 'Alzheimer disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (867, 879), 'mention': 'brain tissue', 'identifier': 'AlzheimerOntology:brain_tissue', 'concept': 'brain tissue', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (867, 872), 'mention': 'brain', 'identifier': 'obo:FMA_50801', 'concept': 'Brain', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (867, 872), 'mention': 'brain', 'identifier': 'AlzheimerOntology:brain', 'concept': 'brain', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (908, 913), 'mention': 'model', 'identifier': 'obo:NBO_0000215', 'concept': 'observational learning', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (908, 913), 'mention': 'model', 'identifier': 'NDDUO:model', 'concept': 'model', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (925, 933), 'mention': 'studying', 'identifier': 'NDDUO:Study_type', 'concept': 'clinical trial study', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (934, 938), 'mention': 'core', 'identifier': 'obo:IAO_0000224', 'concept': 'core', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (963, 972), 'mention': 'screening', 'identifier': 'NDDUO:Screening', 'concept': 'Screening', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (977, 987), 'mention': 'inhibitors', 'identifier': 'NDDUO:inhibitor', 'concept': 'inhibitor', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (991, 994), 'mention': 'tau', 'identifier': 'AlzheimerOntology:t_tau', 'concept': 't-tau', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (995, 1006), 'mention': 'aggregation', 'identifier': 'NDDUO:Cluster', 'concept': 'Cluster', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (44, 56), 'mention': 'amyloid-beta', 'identifier': 'AlzheimerOntology:amyloid_beta_protein', 'concept': 'amyloid beta protein', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (44, 51), 'mention': 'amyloid', 'identifier': 'AlzheimerOntology:amyloid_beta_protein', 'concept': 'amyloid beta protein', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (228, 240), 'mention': 'amyloid-beta', 'identifier': 'AlzheimerOntology:amyloid_beta_protein', 'concept': 'amyloid beta protein', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (228, 235), 'mention': 'amyloid', 'identifier': 'AlzheimerOntology:amyloid_beta_protein', 'concept': 'amyloid beta protein', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (1010, 1014), 'mention': 'like', 'identifier': 'obo:NBO_0000282', 'concept': 'liking', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (1415, 1420), 'mention': 'assay', 'identifier': 'obo:OBI_0000070', 'concept': 'assay', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (1694, 1701), 'mention': 'samples', 'identifier': 'NDDUO:Sampling', 'concept': 'Sampling', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (1747, 1752), 'mention': 'assay', 'identifier': 'obo:OBI_0000070', 'concept': 'assay', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (1804, 1808), 'mention': 'many', 'identifier': 'AlzheimerOntology:Memory_orientation_screening_test', 'concept': 'Memory Orientation Screening Test', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (1809, 1816), 'mention': 'studies', 'identifier': 'NDDUO:Study_type', 'concept': 'clinical trial study', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (1846, 1865), 'mention': "Alzheimer's disease", 'identifier': 'AlzheimerOntology:Subtypes', 'concept': 'Alzheimer disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (1846, 1857), 'mention': "Alzheimer's", 'identifier': 'AlzheimerOntology:Subtypes', 'concept': 'Alzheimer disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (1846, 1855), 'mention': 'Alzheimer', 'identifier': 'AlzheimerOntology:Subtypes', 'concept': 'Alzheimer disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (1858, 1865), 'mention': 'disease', 'identifier': 'obo:OGMS_0000031', 'concept': 'disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (1858, 1865), 'mention': 'disease', 'identifier': 'NDDUO:disease', 'concept': 'disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (1867, 1869), 'mention': 'AD', 'identifier': 'AlzheimerOntology:Subtypes', 'concept': 'Alzheimer disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (1886, 1895), 'mention': 'treatment', 'identifier': 'AlzheimerOntology:Intervention', 'concept': 'Intervention', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (1886, 1895), 'mention': 'treatment', 'identifier': 'NDDUO:Intervention', 'concept': 'Thing related to intervention', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (28, 37), 'mention': 'receptors', 'identifier': 'AlzheimerOntology:Receptors', 'concept': 'Receptor', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (42, 51), 'mention': 'microglia', 'identifier': 'AlzheimerOntology:Microglia', 'concept': 'Microglia', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (110, 122), 'mention': 'amyloid-beta', 'identifier': 'AlzheimerOntology:amyloid_beta_protein', 'concept': 'amyloid beta protein', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (110, 117), 'mention': 'amyloid', 'identifier': 'AlzheimerOntology:amyloid_beta_protein', 'concept': 'amyloid beta protein', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (165, 173), 'mention': 'receptor', 'identifier': 'AlzheimerOntology:Receptors', 'concept': 'Receptor', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (183, 194), 'mention': 'endocytosis', 'identifier': 'AlzheimerOntology:Endocytosis', 'concept': 'Endocytosis', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (204, 213), 'mention': 'microglia', 'identifier': 'AlzheimerOntology:Microglia', 'concept': 'Microglia', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (251, 256), 'mention': 'brain', 'identifier': 'obo:FMA_50801', 'concept': 'Brain', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (251, 256), 'mention': 'brain', 'identifier': 'AlzheimerOntology:brain', 'concept': 'brain', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (276, 296), 'mention': 'inflammatory cascade', 'identifier': 'AlzheimerOntology:inflammation', 'concept': 'inflammation', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (276, 288), 'mention': 'inflammatory', 'identifier': 'AlzheimerOntology:inflammation', 'concept': 'inflammation', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (371, 380), 'mention': 'receptors', 'identifier': 'AlzheimerOntology:Receptors', 'concept': 'Receptor', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (393, 401), 'mention': 'membrane', 'identifier': 'AlzheimerOntology:Membrane', 'concept': 'Membrane', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (462, 471), 'mention': 'receptors', 'identifier': 'AlzheimerOntology:Receptors', 'concept': 'Receptor', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (562, 571), 'mention': 'microglia', 'identifier': 'AlzheimerOntology:Microglia', 'concept': 'Microglia', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (718, 727), 'mention': 'membranes', 'identifier': 'AlzheimerOntology:Membrane', 'concept': 'Membrane', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (758, 767), 'mention': 'receptors', 'identifier': 'AlzheimerOntology:Receptors', 'concept': 'Receptor', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (779, 788), 'mention': 'microglia', 'identifier': 'AlzheimerOntology:Microglia', 'concept': 'Microglia', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (894, 901), 'mention': 'process', 'identifier': 'obo:BFO_0000015', 'concept': 'process', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (894, 901), 'mention': 'process', 'identifier': 'span:Process', 'concept': 'process', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (1187, 1193), 'mention': 'oxygen', 'identifier': 'AlzheimerOntology:oxygen', 'concept': 'oxygen', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (1232, 1241), 'mention': 'receptors', 'identifier': 'AlzheimerOntology:Receptors', 'concept': 'Receptor', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (1327, 1338), 'mention': 'antioxidant', 'identifier': 'AlzheimerOntology:antioxidant', 'concept': 'antioxidant', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (1382, 1394), 'mention': 'phagocytosis', 'identifier': 'AlzheimerOntology:phagocytosis', 'concept': 'phagocytosis', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (1500, 1505), 'mention': 'study', 'identifier': 'NDDUO:Study_type', 'concept': 'clinical trial study', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (1680, 1685), 'mention': 'other', 'identifier': 'obo:IAO_0000230', 'concept': 'other', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (1686, 1693), 'mention': 'disease', 'identifier': 'obo:OGMS_0000031', 'concept': 'disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (1686, 1693), 'mention': 'disease', 'identifier': 'NDDUO:disease', 'concept': 'disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (1694, 1706), 'mention': 'intervention', 'identifier': 'AlzheimerOntology:Intervention', 'concept': 'Intervention', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (1694, 1706), 'mention': 'intervention', 'identifier': 'NDDUO:Intervention', 'concept': 'Thing related to intervention', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (1723, 1731), 'mention': 'receptor', 'identifier': 'AlzheimerOntology:Receptors', 'concept': 'Receptor', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (28, 32), 'mention': 'Drug', 'identifier': 'NDDUO:drug', 'concept': 'drug', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (48, 67), 'mention': "Alzheimer's Disease", 'identifier': 'AlzheimerOntology:Subtypes', 'concept': 'Alzheimer disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (48, 59), 'mention': "Alzheimer's", 'identifier': 'AlzheimerOntology:Subtypes', 'concept': 'Alzheimer disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (48, 57), 'mention': 'Alzheimer', 'identifier': 'AlzheimerOntology:Subtypes', 'concept': 'Alzheimer disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (60, 67), 'mention': 'Disease', 'identifier': 'obo:OGMS_0000031', 'concept': 'disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (60, 67), 'mention': 'Disease', 'identifier': 'NDDUO:disease', 'concept': 'disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (199, 214), 'mention': 'clinical trials', 'identifier': 'NDDUO:Clinical_trial', 'concept': 'thing related to clinical trial', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (199, 207), 'mention': 'clinical', 'identifier': 'NDDUO:Clinical', 'concept': 'Clinical thing', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (219, 238), 'mention': "Alzheimer's disease", 'identifier': 'AlzheimerOntology:Subtypes', 'concept': 'Alzheimer disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (219, 230), 'mention': "Alzheimer's", 'identifier': 'AlzheimerOntology:Subtypes', 'concept': 'Alzheimer disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (219, 228), 'mention': 'Alzheimer', 'identifier': 'AlzheimerOntology:Subtypes', 'concept': 'Alzheimer disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (231, 238), 'mention': 'disease', 'identifier': 'obo:OGMS_0000031', 'concept': 'disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (231, 238), 'mention': 'disease', 'identifier': 'NDDUO:disease', 'concept': 'disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (240, 242), 'mention': 'AD', 'identifier': 'AlzheimerOntology:Subtypes', 'concept': 'Alzheimer disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (314, 323), 'mention': 'treatment', 'identifier': 'AlzheimerOntology:Intervention', 'concept': 'Intervention', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (314, 323), 'mention': 'treatment', 'identifier': 'NDDUO:Intervention', 'concept': 'Thing related to intervention', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (349, 355), 'mention': 'groups', 'identifier': 'AlzheimerOntology:control_group_study_arm', 'concept': 'control group study arm', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (369, 378), 'mention': 'protocols', 'identifier': 'obo:OBI_0000272', 'concept': 'protocol', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (383, 399), 'mention': 'outcome measures', 'identifier': 'NDDUO:outcome_measure', 'concept': 'outcome measure', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (383, 390), 'mention': 'outcome', 'identifier': 'AlzheimerOntology:Outcome', 'concept': 'Outcome', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (383, 390), 'mention': 'outcome', 'identifier': 'NDDUO:Outcome', 'concept': 'Thing related to outcome', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (415, 424), 'mention': 'treatment', 'identifier': 'AlzheimerOntology:Intervention', 'concept': 'Intervention', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (415, 424), 'mention': 'treatment', 'identifier': 'NDDUO:Intervention', 'concept': 'Thing related to intervention', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (482, 490), 'mention': 'outcomes', 'identifier': 'AlzheimerOntology:Outcome', 'concept': 'Outcome', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (482, 490), 'mention': 'outcomes', 'identifier': 'NDDUO:Outcome', 'concept': 'Thing related to outcome', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (540, 547), 'mention': 'learned', 'identifier': 'obo:GO_0007612', 'concept': 'learning', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (578, 589), 'mention': "Alzheimer's", 'identifier': 'AlzheimerOntology:Subtypes', 'concept': 'Alzheimer disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (578, 587), 'mention': 'Alzheimer', 'identifier': 'AlzheimerOntology:Subtypes', 'concept': 'Alzheimer disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (667, 672), 'mention': 'other', 'identifier': 'obo:IAO_0000230', 'concept': 'other', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (722, 730), 'mention': 'planning', 'identifier': 'obo:MF_0000027', 'concept': 'planning', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (722, 730), 'mention': 'planning', 'identifier': 'obo:OBI_0000260', 'concept': 'plan', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (722, 730), 'mention': 'planning', 'identifier': 'obo:OBI_0000339', 'concept': 'planning', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (731, 737), 'mention': 'stages', 'identifier': 'NDDUO:Stages', 'concept': 'thing related to stage', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (756, 770), 'mention': 'clinical trial', 'identifier': 'NDDUO:Clinical_trial', 'concept': 'thing related to clinical trial', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (756, 764), 'mention': 'clinical', 'identifier': 'NDDUO:Clinical', 'concept': 'Clinical thing', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (788, 790), 'mention': 'AD', 'identifier': 'AlzheimerOntology:Subtypes', 'concept': 'Alzheimer disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (899, 912), 'mention': 'interventions', 'identifier': 'AlzheimerOntology:Intervention', 'concept': 'Intervention', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (899, 912), 'mention': 'interventions', 'identifier': 'NDDUO:Intervention', 'concept': 'Thing related to intervention', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (989, 996), 'mention': 'cohorts', 'identifier': 'NDDO:NDDO_00000107', 'concept': 'cohort', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (989, 996), 'mention': 'cohorts', 'identifier': 'AlzheimerOntology:Cohort_effect', 'concept': 'Cohort effect', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (1023, 1025), 'mention': 'AD', 'identifier': 'AlzheimerOntology:Subtypes', 'concept': 'Alzheimer disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (1034, 1044), 'mention': 'population', 'identifier': 'AlzheimerOntology:Populations', 'concept': 'Population', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (1046, 1048), 'mention': 'AD', 'identifier': 'AlzheimerOntology:Subtypes', 'concept': 'Alzheimer disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (1049, 1054), 'mention': 'drugs', 'identifier': 'NDDUO:drug', 'concept': 'drug', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (1056, 1065), 'mention': 'treatment', 'identifier': 'AlzheimerOntology:Intervention', 'concept': 'Intervention', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (1056, 1065), 'mention': 'treatment', 'identifier': 'NDDUO:Intervention', 'concept': 'Thing related to intervention', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (1260, 1262), 'mention': 'AD', 'identifier': 'AlzheimerOntology:Subtypes', 'concept': 'Alzheimer disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (1263, 1273), 'mention': 'treatments', 'identifier': 'AlzheimerOntology:Intervention', 'concept': 'Intervention', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (1263, 1273), 'mention': 'treatments', 'identifier': 'NDDUO:Intervention', 'concept': 'Thing related to intervention', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (9, 13), 'mention': 'ApoE', 'identifier': 'AlzheimerOntology:APOE', 'concept': 'APOE', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (9, 13), 'mention': 'ApoE', 'identifier': 'AlzheimerOntology:ApoE_Protein', 'concept': 'ApoE Protein', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (83, 102), 'mention': "Alzheimer's disease", 'identifier': 'AlzheimerOntology:Subtypes', 'concept': 'Alzheimer disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (83, 94), 'mention': "Alzheimer's", 'identifier': 'AlzheimerOntology:Subtypes', 'concept': 'Alzheimer disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (83, 92), 'mention': 'Alzheimer', 'identifier': 'AlzheimerOntology:Subtypes', 'concept': 'Alzheimer disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (95, 102), 'mention': 'disease', 'identifier': 'obo:OGMS_0000031', 'concept': 'disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (95, 102), 'mention': 'disease', 'identifier': 'NDDUO:disease', 'concept': 'disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (162, 181), 'mention': "Alzheimer's disease", 'identifier': 'AlzheimerOntology:Subtypes', 'concept': 'Alzheimer disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (162, 173), 'mention': "Alzheimer's", 'identifier': 'AlzheimerOntology:Subtypes', 'concept': 'Alzheimer disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (162, 171), 'mention': 'Alzheimer', 'identifier': 'AlzheimerOntology:Subtypes', 'concept': 'Alzheimer disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (174, 181), 'mention': 'disease', 'identifier': 'obo:OGMS_0000031', 'concept': 'disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (174, 181), 'mention': 'disease', 'identifier': 'NDDUO:disease', 'concept': 'disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (183, 185), 'mention': 'AD', 'identifier': 'AlzheimerOntology:Subtypes', 'concept': 'Alzheimer disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (227, 234), 'mention': 'neurons', 'identifier': 'NDDUO:Neurons', 'concept': 'Neuron', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (254, 260), 'mention': 'others', 'identifier': 'obo:IAO_0000230', 'concept': 'other', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (365, 372), 'mention': 'nucleus', 'identifier': 'AlzheimerOntology:Nucleus', 'concept': 'Nucleus', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (373, 376), 'mention': 'RNA', 'identifier': 'AlzheimerOntology:RNA', 'concept': 'RNA', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (408, 412), 'mention': 'ApoE', 'identifier': 'AlzheimerOntology:APOE', 'concept': 'APOE', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (408, 412), 'mention': 'ApoE', 'identifier': 'AlzheimerOntology:ApoE_Protein', 'concept': 'ApoE Protein', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (514, 518), 'mention': 'ApoE', 'identifier': 'AlzheimerOntology:APOE', 'concept': 'APOE', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (514, 518), 'mention': 'ApoE', 'identifier': 'AlzheimerOntology:ApoE_Protein', 'concept': 'ApoE Protein', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (557, 559), 'mention': 'AD', 'identifier': 'AlzheimerOntology:Subtypes', 'concept': 'Alzheimer disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (639, 646), 'mention': 'neurons', 'identifier': 'NDDUO:Neurons', 'concept': 'Neuron', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (654, 660), 'mention': 'brains', 'identifier': 'obo:FMA_50801', 'concept': 'Brain', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (654, 660), 'mention': 'brains', 'identifier': 'AlzheimerOntology:brain', 'concept': 'brain', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (674, 678), 'mention': 'mice', 'identifier': 'NDDUO:Mouse_', 'concept': 'Mouse', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (686, 690), 'mention': 'ApoE', 'identifier': 'AlzheimerOntology:APOE', 'concept': 'APOE', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (686, 690), 'mention': 'ApoE', 'identifier': 'AlzheimerOntology:ApoE_Protein', 'concept': 'ApoE Protein', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (700, 704), 'mention': 'mice', 'identifier': 'NDDUO:Mouse_', 'concept': 'Mouse', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (732, 734), 'mention': 'AD', 'identifier': 'AlzheimerOntology:Subtypes', 'concept': 'Alzheimer disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (779, 783), 'mention': 'ApoE', 'identifier': 'AlzheimerOntology:APOE', 'concept': 'APOE', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (779, 783), 'mention': 'ApoE', 'identifier': 'AlzheimerOntology:ApoE_Protein', 'concept': 'ApoE Protein', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (821, 825), 'mention': 'ApoE', 'identifier': 'AlzheimerOntology:APOE', 'concept': 'APOE', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (821, 825), 'mention': 'ApoE', 'identifier': 'AlzheimerOntology:ApoE_Protein', 'concept': 'ApoE Protein', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (865, 878), 'mention': 'tau pathology', 'identifier': 'AlzheimerOntology:tauopathy', 'concept': 'tauopathy', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (865, 868), 'mention': 'tau', 'identifier': 'AlzheimerOntology:t_tau', 'concept': 't-tau', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (944, 957), 'mention': 'tau pathology', 'identifier': 'AlzheimerOntology:tauopathy', 'concept': 'tauopathy', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (944, 947), 'mention': 'tau', 'identifier': 'AlzheimerOntology:t_tau', 'concept': 't-tau', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (986, 993), 'mention': 'neurons', 'identifier': 'NDDUO:Neurons', 'concept': 'Neuron', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (1001, 1006), 'mention': 'mouse', 'identifier': 'NDDUO:Mouse_', 'concept': 'Mouse', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (1007, 1017), 'mention': 'hippocampi', 'identifier': 'obo:FMA_62493', 'concept': 'Hippocampus', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (1007, 1017), 'mention': 'hippocampi', 'identifier': 'AlzheimerOntology:Hippocampus', 'concept': 'Hippocampus', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (1042, 1045), 'mention': 'tau', 'identifier': 'AlzheimerOntology:t_tau', 'concept': 't-tau', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (1099, 1103), 'mention': 'ApoE', 'identifier': 'AlzheimerOntology:APOE', 'concept': 'APOE', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (1099, 1103), 'mention': 'ApoE', 'identifier': 'AlzheimerOntology:ApoE_Protein', 'concept': 'ApoE Protein', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (1157, 1170), 'mention': 'tau pathology', 'identifier': 'AlzheimerOntology:tauopathy', 'concept': 'tauopathy', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (1157, 1160), 'mention': 'tau', 'identifier': 'AlzheimerOntology:t_tau', 'concept': 't-tau', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (0, 9), 'mention': 'Alzheimer', 'identifier': 'AlzheimerOntology:Subtypes', 'concept': 'Alzheimer disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (24, 27), 'mention': 'APP', 'identifier': 'AlzheimerOntology:APP', 'concept': 'APP', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (24, 27), 'mention': 'APP', 'identifier': 'AlzheimerOntology:amyloid_precursor_protein', 'concept': 'amyloid precursor protein', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (86, 105), 'mention': "Alzheimer's disease", 'identifier': 'AlzheimerOntology:Subtypes', 'concept': 'Alzheimer disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (86, 97), 'mention': "Alzheimer's", 'identifier': 'AlzheimerOntology:Subtypes', 'concept': 'Alzheimer disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (86, 95), 'mention': 'Alzheimer', 'identifier': 'AlzheimerOntology:Subtypes', 'concept': 'Alzheimer disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (98, 105), 'mention': 'disease', 'identifier': 'obo:OGMS_0000031', 'concept': 'disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (98, 105), 'mention': 'disease', 'identifier': 'NDDUO:disease', 'concept': 'disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (143, 148), 'mention': 'other', 'identifier': 'obo:IAO_0000230', 'concept': 'other', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (149, 158), 'mention': 'mutations', 'identifier': 'AlzheimerOntology:mutation', 'concept': 'mutation', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (289, 295), 'mention': 'brains', 'identifier': 'obo:FMA_50801', 'concept': 'Brain', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (289, 295), 'mention': 'brains', 'identifier': 'AlzheimerOntology:brain', 'concept': 'brain', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (319, 323), 'mention': 'mice', 'identifier': 'NDDUO:Mouse_', 'concept': 'Mouse', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (359, 373), 'mention': 'cultured cells', 'identifier': 'AlzheimerOntology:Cell_cultures', 'concept': 'Cell culture', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (44, 56), 'mention': 'amyloid-beta', 'identifier': 'AlzheimerOntology:amyloid_beta_protein', 'concept': 'amyloid beta protein', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (44, 51), 'mention': 'amyloid', 'identifier': 'AlzheimerOntology:amyloid_beta_protein', 'concept': 'amyloid beta protein', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (116, 120), 'mention': 'mice', 'identifier': 'NDDUO:Mouse_', 'concept': 'Mouse', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (152, 177), 'mention': 'Amyloid precursor protein', 'identifier': 'AlzheimerOntology:amyloid_precursor_protein', 'concept': 'amyloid precursor protein', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (152, 159), 'mention': 'Amyloid', 'identifier': 'AlzheimerOntology:amyloid_beta_protein', 'concept': 'amyloid beta protein', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (170, 177), 'mention': 'protein', 'identifier': 'AlzheimerOntology:protein', 'concept': 'protein', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (179, 182), 'mention': 'APP', 'identifier': 'AlzheimerOntology:APP', 'concept': 'APP', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (179, 182), 'mention': 'APP', 'identifier': 'AlzheimerOntology:amyloid_precursor_protein', 'concept': 'amyloid precursor protein', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (202, 207), 'mention': 'model', 'identifier': 'obo:NBO_0000215', 'concept': 'observational learning', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (202, 207), 'mention': 'model', 'identifier': 'NDDUO:model', 'concept': 'model', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (223, 235), 'mention': 'amyloid-beta', 'identifier': 'AlzheimerOntology:amyloid_beta_protein', 'concept': 'amyloid beta protein', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (223, 230), 'mention': 'amyloid', 'identifier': 'AlzheimerOntology:amyloid_beta_protein', 'concept': 'amyloid beta protein', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (252, 260), 'mention': 'function', 'identifier': 'obo:BFO_0000034', 'concept': 'function', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (252, 260), 'mention': 'function', 'identifier': 'snap:Function', 'concept': 'function', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (264, 283), 'mention': 'Alzheimer?s disease', 'identifier': 'AlzheimerOntology:Subtypes', 'concept': 'Alzheimer disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (264, 275), 'mention': 'Alzheimer?s', 'identifier': 'AlzheimerOntology:Subtypes', 'concept': 'Alzheimer disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (264, 273), 'mention': 'Alzheimer', 'identifier': 'AlzheimerOntology:Subtypes', 'concept': 'Alzheimer disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (276, 283), 'mention': 'disease', 'identifier': 'obo:OGMS_0000031', 'concept': 'disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (276, 283), 'mention': 'disease', 'identifier': 'NDDUO:disease', 'concept': 'disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (285, 287), 'mention': 'AD', 'identifier': 'AlzheimerOntology:Subtypes', 'concept': 'Alzheimer disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (298, 308), 'mention': 'phenotypes', 'identifier': 'obo:OGMS_0000023', 'concept': 'phenotype', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (328, 332), 'mention': 'mice', 'identifier': 'NDDUO:Mouse_', 'concept': 'Mouse', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (373, 376), 'mention': 'APP', 'identifier': 'AlzheimerOntology:APP', 'concept': 'APP', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (373, 376), 'mention': 'APP', 'identifier': 'AlzheimerOntology:amyloid_precursor_protein', 'concept': 'amyloid precursor protein', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (464, 467), 'mention': 'APP', 'identifier': 'AlzheimerOntology:APP', 'concept': 'APP', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (464, 467), 'mention': 'APP', 'identifier': 'AlzheimerOntology:amyloid_precursor_protein', 'concept': 'amyloid precursor protein', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (595, 609), 'mention': 'amyloid plaque', 'identifier': 'AlzheimerOntology:presence_of_amyloid_plaque', 'concept': 'presence of amyloid plaque', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (595, 602), 'mention': 'amyloid', 'identifier': 'AlzheimerOntology:amyloid_beta_protein', 'concept': 'amyloid beta protein', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (603, 609), 'mention': 'plaque', 'identifier': 'AlzheimerOntology:presence_of_amyloid_plaque', 'concept': 'presence of amyloid plaque', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (603, 609), 'mention': 'plaque', 'identifier': 'AlzheimerOntology:senile_plaque', 'concept': 'presence of senile plaque', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (626, 628), 'mention': 'AD', 'identifier': 'AlzheimerOntology:Subtypes', 'concept': 'Alzheimer disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (747, 755), 'mention': 'function', 'identifier': 'obo:BFO_0000034', 'concept': 'function', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (747, 755), 'mention': 'function', 'identifier': 'snap:Function', 'concept': 'function', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (830, 838), 'mention': 'function', 'identifier': 'obo:BFO_0000034', 'concept': 'function', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (830, 838), 'mention': 'function', 'identifier': 'snap:Function', 'concept': 'function', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (842, 846), 'mention': 'vivo', 'identifier': 'NDDUO:In_vivo', 'concept': 'In vivo thing', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (899, 903), 'mention': 'mice', 'identifier': 'NDDUO:Mouse_', 'concept': 'Mouse', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (947, 952), 'mention': 'brain', 'identifier': 'obo:FMA_50801', 'concept': 'Brain', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (947, 952), 'mention': 'brain', 'identifier': 'AlzheimerOntology:brain', 'concept': 'brain', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (971, 974), 'mention': 'APP', 'identifier': 'AlzheimerOntology:APP', 'concept': 'APP', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (971, 974), 'mention': 'APP', 'identifier': 'AlzheimerOntology:amyloid_precursor_protein', 'concept': 'amyloid precursor protein', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (1002, 1006), 'mention': 'mice', 'identifier': 'NDDUO:Mouse_', 'concept': 'Mouse', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (1045, 1052), 'mention': 'assayed', 'identifier': 'obo:OBI_0000070', 'concept': 'assay', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (1276, 1280), 'mention': 'male', 'identifier': 'NDDUO:male', 'concept': 'male', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (1285, 1291), 'mention': 'female', 'identifier': 'NDDUO:female', 'concept': 'female', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (1292, 1296), 'mention': 'mice', 'identifier': 'NDDUO:Mouse_', 'concept': 'Mouse', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (1428, 1432), 'mention': 'mice', 'identifier': 'NDDUO:Mouse_', 'concept': 'Mouse', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (1464, 1467), 'mention': 'APP', 'identifier': 'AlzheimerOntology:APP', 'concept': 'APP', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (1464, 1467), 'mention': 'APP', 'identifier': 'AlzheimerOntology:amyloid_precursor_protein', 'concept': 'amyloid precursor protein', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (1472, 1484), 'mention': 'Presenilin 1', 'identifier': 'AlzheimerOntology:presenilin_1', 'concept': 'presenilin 1', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (1472, 1482), 'mention': 'Presenilin', 'identifier': 'AlzheimerOntology:presenilin', 'concept': 'presenilin', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (1486, 1489), 'mention': 'APP', 'identifier': 'AlzheimerOntology:APP', 'concept': 'APP', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (1486, 1489), 'mention': 'APP', 'identifier': 'AlzheimerOntology:amyloid_precursor_protein', 'concept': 'amyloid precursor protein', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (1494, 1498), 'mention': 'mice', 'identifier': 'NDDUO:Mouse_', 'concept': 'Mouse', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (1560, 1563), 'mention': 'APP', 'identifier': 'AlzheimerOntology:APP', 'concept': 'APP', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (1560, 1563), 'mention': 'APP', 'identifier': 'AlzheimerOntology:amyloid_precursor_protein', 'concept': 'amyloid precursor protein', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (1596, 1608), 'mention': 'mouse models', 'identifier': 'NDDUO:In_vivo_models', 'concept': 'In vivo model', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (1596, 1601), 'mention': 'mouse', 'identifier': 'NDDUO:Mouse_', 'concept': 'Mouse', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (1602, 1608), 'mention': 'models', 'identifier': 'obo:NBO_0000215', 'concept': 'observational learning', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (1602, 1608), 'mention': 'models', 'identifier': 'NDDUO:model', 'concept': 'model', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (1612, 1614), 'mention': 'AD', 'identifier': 'AlzheimerOntology:Subtypes', 'concept': 'Alzheimer disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (1798, 1809), 'mention': 'aggregation', 'identifier': 'NDDUO:Cluster', 'concept': 'Cluster', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (1856, 1863), 'mention': 'role of', 'identifier': 'obo:RO_0000081', 'concept': 'role of', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (1856, 1860), 'mention': 'role', 'identifier': 'obo:BFO_0000023', 'concept': 'role', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (1856, 1860), 'mention': 'role', 'identifier': 'snap:Role', 'concept': 'role', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (1910, 1917), 'mention': 'disease', 'identifier': 'obo:OGMS_0000031', 'concept': 'disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (1910, 1917), 'mention': 'disease', 'identifier': 'NDDUO:disease', 'concept': 'disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (4, 8), 'mention': 'BIN1', 'identifier': 'AlzheimerOntology:BIN1', 'concept': 'BIN1', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (18, 37), 'mention': "Alzheimer's disease", 'identifier': 'AlzheimerOntology:Subtypes', 'concept': 'Alzheimer disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (18, 29), 'mention': "Alzheimer's", 'identifier': 'AlzheimerOntology:Subtypes', 'concept': 'Alzheimer disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (18, 27), 'mention': 'Alzheimer', 'identifier': 'AlzheimerOntology:Subtypes', 'concept': 'Alzheimer disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (30, 37), 'mention': 'disease', 'identifier': 'obo:OGMS_0000031', 'concept': 'disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (30, 37), 'mention': 'disease', 'identifier': 'NDDUO:disease', 'concept': 'disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (38, 42), 'mention': 'risk', 'identifier': 'NDDUO:Risk_factor', 'concept': 'Risk factor', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (87, 90), 'mention': 'tau', 'identifier': 'AlzheimerOntology:t_tau', 'concept': 't-tau', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (108, 125), 'mention': 'cognitive decline', 'identifier': 'AlzheimerOntology:Moderate_cognitive_Decline', 'concept': 'Moderate cognitive Decline', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (108, 125), 'mention': 'cognitive decline', 'identifier': 'AlzheimerOntology:mental_disorder', 'concept': 'mental disorder', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (108, 117), 'mention': 'cognitive', 'identifier': 'AlzheimerOntology:Cognitive_Tests', 'concept': 'Cognitive Test', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (144, 148), 'mention': 'BIN1', 'identifier': 'AlzheimerOntology:BIN1', 'concept': 'BIN1', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (212, 216), 'mention': 'risk', 'identifier': 'NDDUO:Risk_factor', 'concept': 'Risk factor', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (227, 246), 'mention': "Alzheimer's disease", 'identifier': 'AlzheimerOntology:Subtypes', 'concept': 'Alzheimer disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (227, 238), 'mention': "Alzheimer's", 'identifier': 'AlzheimerOntology:Subtypes', 'concept': 'Alzheimer disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (227, 236), 'mention': 'Alzheimer', 'identifier': 'AlzheimerOntology:Subtypes', 'concept': 'Alzheimer disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (239, 246), 'mention': 'disease', 'identifier': 'obo:OGMS_0000031', 'concept': 'disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (239, 246), 'mention': 'disease', 'identifier': 'NDDUO:disease', 'concept': 'disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (248, 250), 'mention': 'AD', 'identifier': 'AlzheimerOntology:Subtypes', 'concept': 'Alzheimer disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (268, 281), 'mention': 'tau pathology', 'identifier': 'AlzheimerOntology:tauopathy', 'concept': 'tauopathy', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (268, 271), 'mention': 'tau', 'identifier': 'AlzheimerOntology:t_tau', 'concept': 't-tau', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (291, 294), 'mention': 'tau', 'identifier': 'AlzheimerOntology:t_tau', 'concept': 't-tau', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (332, 344), 'mention': 'amyloid beta', 'identifier': 'AlzheimerOntology:amyloid_beta_protein', 'concept': 'amyloid beta protein', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (332, 339), 'mention': 'amyloid', 'identifier': 'AlzheimerOntology:amyloid_beta_protein', 'concept': 'amyloid beta protein', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (369, 373), 'mention': 'BIN1', 'identifier': 'AlzheimerOntology:BIN1', 'concept': 'BIN1', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (406, 409), 'mention': 'tau', 'identifier': 'AlzheimerOntology:t_tau', 'concept': 't-tau', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (449, 456), 'mention': 'samples', 'identifier': 'NDDUO:Sampling', 'concept': 'Sampling', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (458, 501), 'mention': "Alzheimer's Disease Neuroimaging Initiative", 'identifier': 'AlzheimerOntology:neuroimaging', 'concept': 'neuroimaging', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (458, 477), 'mention': "Alzheimer's Disease", 'identifier': 'AlzheimerOntology:Subtypes', 'concept': 'Alzheimer disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (458, 469), 'mention': "Alzheimer's", 'identifier': 'AlzheimerOntology:Subtypes', 'concept': 'Alzheimer disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (458, 467), 'mention': 'Alzheimer', 'identifier': 'AlzheimerOntology:Subtypes', 'concept': 'Alzheimer disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (470, 477), 'mention': 'Disease', 'identifier': 'obo:OGMS_0000031', 'concept': 'disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (470, 477), 'mention': 'Disease', 'identifier': 'NDDUO:disease', 'concept': 'disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (478, 490), 'mention': 'Neuroimaging', 'identifier': 'AlzheimerOntology:neuroimaging', 'concept': 'neuroimaging', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (503, 507), 'mention': 'ADNI', 'identifier': 'AlzheimerOntology:neuroimaging', 'concept': 'neuroimaging', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (519, 529), 'mention': 'Biomarkers', 'identifier': 'AlzheimerOntology:procedures_using_biomarkers', 'concept': 'thing related to procedure using biomarkers', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (519, 529), 'mention': 'Biomarkers', 'identifier': 'NDDUO:biomarker', 'concept': 'biomarker', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (546, 573), 'mention': 'Neurodegenerative Disorders', 'identifier': 'NDDUO:disorder', 'concept': 'disorder', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (546, 573), 'mention': 'Neurodegenerative Disorders', 'identifier': 'NDDUO:neurodegenerative_disease', 'concept': 'neurodegenerative disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (564, 573), 'mention': 'Disorders', 'identifier': 'NDDUO:disorder', 'concept': 'disorder', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (652, 680), 'mention': 'positron emission tomography', 'identifier': 'AlzheimerOntology:Positron_emission_tomography', 'concept': 'Positron emission tomography', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (682, 685), 'mention': 'PET', 'identifier': 'AlzheimerOntology:Positron_emission_tomography', 'concept': 'Positron emission tomography', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (691, 701), 'mention': 'biomarkers', 'identifier': 'AlzheimerOntology:procedures_using_biomarkers', 'concept': 'thing related to procedure using biomarkers', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (691, 701), 'mention': 'biomarkers', 'identifier': 'NDDUO:biomarker', 'concept': 'biomarker', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (720, 729), 'mention': 'cognitive', 'identifier': 'AlzheimerOntology:Cognitive_Tests', 'concept': 'Cognitive Test', 'type': '', 'annotator': 'NIO'}
# --------
# ...
# --------
# {'span': (12, 19), 'mention': 'disease', 'identifier': 'obo:OGMS_0000031', 'concept': 'disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (12, 19), 'mention': 'disease', 'identifier': 'NDDUO:disease', 'concept': 'disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (20, 24), 'mention': 'drug', 'identifier': 'NDDUO:drug', 'concept': 'drug', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (107, 126), 'mention': "Alzheimer's disease", 'identifier': 'AlzheimerOntology:Subtypes', 'concept': 'Alzheimer disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (107, 118), 'mention': "Alzheimer's", 'identifier': 'AlzheimerOntology:Subtypes', 'concept': 'Alzheimer disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (107, 116), 'mention': 'Alzheimer', 'identifier': 'AlzheimerOntology:Subtypes', 'concept': 'Alzheimer disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (119, 126), 'mention': 'disease', 'identifier': 'obo:OGMS_0000031', 'concept': 'disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (119, 126), 'mention': 'disease', 'identifier': 'NDDUO:disease', 'concept': 'disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (128, 130), 'mention': 'AD', 'identifier': 'AlzheimerOntology:Subtypes', 'concept': 'Alzheimer disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (154, 158), 'mention': 'rate', 'identifier': 'NDDUO:rate', 'concept': 'rate', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (164, 174), 'mention': 'treatments', 'identifier': 'AlzheimerOntology:Intervention', 'concept': 'Intervention', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (164, 174), 'mention': 'treatments', 'identifier': 'NDDUO:Intervention', 'concept': 'Thing related to intervention', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (230, 235), 'mention': 'drugs', 'identifier': 'NDDUO:drug', 'concept': 'drug', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (239, 254), 'mention': 'clinical trials', 'identifier': 'NDDUO:Clinical_trial', 'concept': 'thing related to clinical trial', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (239, 247), 'mention': 'clinical', 'identifier': 'NDDUO:Clinical', 'concept': 'Clinical thing', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (263, 272), 'mention': 'treatment', 'identifier': 'AlzheimerOntology:Intervention', 'concept': 'Intervention', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (263, 272), 'mention': 'treatment', 'identifier': 'NDDUO:Intervention', 'concept': 'Thing related to intervention', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (276, 278), 'mention': 'AD', 'identifier': 'AlzheimerOntology:Subtypes', 'concept': 'Alzheimer disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (349, 364), 'mention': 'clinical trials', 'identifier': 'NDDUO:Clinical_trial', 'concept': 'thing related to clinical trial', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (349, 357), 'mention': 'clinical', 'identifier': 'NDDUO:Clinical', 'concept': 'Clinical thing', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (377, 382), 'mention': 'drugs', 'identifier': 'NDDUO:drug', 'concept': 'drug', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (466, 468), 'mention': 'AD', 'identifier': 'AlzheimerOntology:Subtypes', 'concept': 'Alzheimer disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (473, 483), 'mention': 'treatments', 'identifier': 'AlzheimerOntology:Intervention', 'concept': 'Intervention', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (473, 483), 'mention': 'treatments', 'identifier': 'NDDUO:Intervention', 'concept': 'Thing related to intervention', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (487, 494), 'mention': 'Phase 3', 'identifier': 'NDDUO:phase_3', 'concept': 'phase 3', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (509, 516), 'mention': 'Phase 2', 'identifier': 'NDDUO:phase_2', 'concept': 'phase 2', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (528, 535), 'mention': 'Phase 1', 'identifier': 'NDDUO:phase_1', 'concept': 'phase 1', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (553, 558), 'mention': 'drugs', 'identifier': 'NDDUO:drug', 'concept': 'drug', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (610, 612), 'mention': 'AD', 'identifier': 'AlzheimerOntology:Subtypes', 'concept': 'Alzheimer disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (632, 639), 'mention': 'disease', 'identifier': 'obo:OGMS_0000031', 'concept': 'disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (632, 639), 'mention': 'disease', 'identifier': 'NDDUO:disease', 'concept': 'disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (673, 682), 'mention': 'cognitive', 'identifier': 'AlzheimerOntology:Cognitive_Tests', 'concept': 'Cognitive Test', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (714, 719), 'mention': 'drugs', 'identifier': 'NDDUO:drug', 'concept': 'drug', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (746, 771), 'mention': 'neuropsychiatric symptoms', 'identifier': 'AlzheimerOntology:Neuropsychiatric_symptoms', 'concept': 'Neuropsychiatric symptom', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (746, 771), 'mention': 'neuropsychiatric symptoms', 'identifier': 'AlzheimerOntology:psychological_symptom', 'concept': 'psychological symptom', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (763, 771), 'mention': 'symptoms', 'identifier': 'NDDUO:Symptoms', 'concept': 'Symptom or sign', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (837, 846), 'mention': 'processes', 'identifier': 'obo:BFO_0000015', 'concept': 'process', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (837, 846), 'mention': 'processes', 'identifier': 'span:Process', 'concept': 'process', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (851, 855), 'mention': 'more', 'identifier': 'AlzheimerOntology:Memory_orientation_screening_test', 'concept': 'Memory Orientation Screening Test', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (869, 879), 'mention': 'biomarkers', 'identifier': 'AlzheimerOntology:procedures_using_biomarkers', 'concept': 'thing related to procedure using biomarkers', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (869, 879), 'mention': 'biomarkers', 'identifier': 'NDDUO:biomarker', 'concept': 'biomarker', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (884, 888), 'mention': 'more', 'identifier': 'AlzheimerOntology:Memory_orientation_screening_test', 'concept': 'Memory Orientation Screening Test', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (981, 990), 'mention': 'treatment', 'identifier': 'AlzheimerOntology:Intervention', 'concept': 'Intervention', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (981, 990), 'mention': 'treatment', 'identifier': 'NDDUO:Intervention', 'concept': 'Thing related to intervention', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (994, 996), 'mention': 'AD', 'identifier': 'AlzheimerOntology:Subtypes', 'concept': 'Alzheimer disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (4, 6), 'mention': 'AD', 'identifier': 'AlzheimerOntology:Subtypes', 'concept': 'Alzheimer disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (7, 10), 'mention': 'tau', 'identifier': 'AlzheimerOntology:t_tau', 'concept': 't-tau', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (11, 15), 'mention': 'core', 'identifier': 'obo:IAO_0000224', 'concept': 'core', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (70, 73), 'mention': 'tau', 'identifier': 'AlzheimerOntology:t_tau', 'concept': 't-tau', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (77, 86), 'mention': 'filaments', 'identifier': 'AlzheimerOntology:Filaments', 'concept': 'Filament', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (87, 90), 'mention': 'Tau', 'identifier': 'AlzheimerOntology:t_tau', 'concept': 't-tau', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (140, 159), 'mention': "Alzheimer's disease", 'identifier': 'AlzheimerOntology:Subtypes', 'concept': 'Alzheimer disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (140, 151), 'mention': "Alzheimer's", 'identifier': 'AlzheimerOntology:Subtypes', 'concept': 'Alzheimer disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (140, 149), 'mention': 'Alzheimer', 'identifier': 'AlzheimerOntology:Subtypes', 'concept': 'Alzheimer disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (152, 159), 'mention': 'disease', 'identifier': 'obo:OGMS_0000031', 'concept': 'disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (152, 159), 'mention': 'disease', 'identifier': 'NDDUO:disease', 'concept': 'disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (161, 163), 'mention': 'AD', 'identifier': 'AlzheimerOntology:Subtypes', 'concept': 'Alzheimer disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (169, 174), 'mention': 'other', 'identifier': 'obo:IAO_0000230', 'concept': 'other', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (175, 186), 'mention': 'tauopathies', 'identifier': 'obo:ND_0000151', 'concept': 'tauopathy', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (175, 186), 'mention': 'tauopathies', 'identifier': 'AlzheimerOntology:tauopathy', 'concept': 'tauopathy', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (212, 215), 'mention': 'tau', 'identifier': 'AlzheimerOntology:t_tau', 'concept': 't-tau', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (216, 227), 'mention': 'aggregation', 'identifier': 'NDDUO:Cluster', 'concept': 'Cluster', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (287, 290), 'mention': 'tau', 'identifier': 'AlzheimerOntology:t_tau', 'concept': 't-tau', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (291, 299), 'mention': 'filament', 'identifier': 'AlzheimerOntology:Filaments', 'concept': 'Filament', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (300, 305), 'mention': 'cores', 'identifier': 'obo:IAO_0000224', 'concept': 'core', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (358, 360), 'mention': 'AD', 'identifier': 'AlzheimerOntology:Subtypes', 'concept': 'Alzheimer disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (361, 364), 'mention': 'tau', 'identifier': 'AlzheimerOntology:t_tau', 'concept': 't-tau', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (365, 369), 'mention': 'core', 'identifier': 'obo:IAO_0000224', 'concept': 'core', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (464, 474), 'mention': 'antibodies', 'identifier': 'AlzheimerOntology:antibody', 'concept': 'antibody', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (493, 495), 'mention': 'AD', 'identifier': 'AlzheimerOntology:Subtypes', 'concept': 'Alzheimer disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (496, 499), 'mention': 'tau', 'identifier': 'AlzheimerOntology:t_tau', 'concept': 't-tau', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (500, 504), 'mention': 'core', 'identifier': 'obo:IAO_0000224', 'concept': 'core', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (505, 514), 'mention': 'filaments', 'identifier': 'AlzheimerOntology:Filaments', 'concept': 'Filament', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (525, 527), 'mention': 'AD', 'identifier': 'AlzheimerOntology:Subtypes', 'concept': 'Alzheimer disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (528, 541), 'mention': 'tau pathology', 'identifier': 'AlzheimerOntology:tauopathy', 'concept': 'tauopathy', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (528, 531), 'mention': 'tau', 'identifier': 'AlzheimerOntology:t_tau', 'concept': 't-tau', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (547, 549), 'mention': 'AD', 'identifier': 'AlzheimerOntology:Subtypes', 'concept': 'Alzheimer disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (550, 553), 'mention': 'tau', 'identifier': 'AlzheimerOntology:t_tau', 'concept': 't-tau', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (554, 558), 'mention': 'core', 'identifier': 'obo:IAO_0000224', 'concept': 'core', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (571, 582), 'mention': 'aggregation', 'identifier': 'NDDUO:Cluster', 'concept': 'Cluster', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (608, 611), 'mention': 'tau', 'identifier': 'AlzheimerOntology:t_tau', 'concept': 't-tau', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (674, 677), 'mention': 'tau', 'identifier': 'AlzheimerOntology:t_tau', 'concept': 't-tau', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (689, 694), 'mention': 'brain', 'identifier': 'obo:FMA_50801', 'concept': 'Brain', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (689, 694), 'mention': 'brain', 'identifier': 'AlzheimerOntology:brain', 'concept': 'brain', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (722, 741), 'mention': 'cerebrospinal fluid', 'identifier': 'AlzheimerOntology:cerebrospinal_fluid', 'concept': 'cerebrospinal fluid', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (743, 746), 'mention': 'CSF', 'identifier': 'AlzheimerOntology:Cerebospinal_Fluid', 'concept': 'protein circulating in Cerebospinal Fluid', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (743, 746), 'mention': 'CSF', 'identifier': 'AlzheimerOntology:Cerebospinal_fluid_test', 'concept': 'Cerebospinal fluid test', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (743, 746), 'mention': 'CSF', 'identifier': 'AlzheimerOntology:cerebrospinal_fluid', 'concept': 'cerebrospinal fluid', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (743, 746), 'mention': 'CSF', 'identifier': 'AlzheimerOntology:macrophage_colony_stimulating_factor', 'concept': 'macrophage colony stimulating factor', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (767, 769), 'mention': 'AD', 'identifier': 'AlzheimerOntology:Subtypes', 'concept': 'Alzheimer disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (835, 840), 'mention': 'assay', 'identifier': 'obo:OBI_0000070', 'concept': 'assay', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (868, 876), 'mention': 'filament', 'identifier': 'AlzheimerOntology:Filaments', 'concept': 'Filament', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (877, 882), 'mention': 'cores', 'identifier': 'obo:IAO_0000224', 'concept': 'core', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (886, 911), 'mention': 'corticobasal degeneration', 'identifier': 'obo:ND_0000169', 'concept': 'corticobasal degeneration', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (929, 936), 'mention': 'disease', 'identifier': 'obo:OGMS_0000031', 'concept': 'disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (929, 936), 'mention': 'disease', 'identifier': 'NDDUO:disease', 'concept': 'disease', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (967, 976), 'mention': 'filaments', 'identifier': 'AlzheimerOntology:Filaments', 'concept': 'Filament', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (1023, 1031), 'mention': 'document', 'identifier': 'obo:IAO_0000310', 'concept': 'document', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (1047, 1055), 'mention': 'modeling', 'identifier': 'obo:NBO_0000215', 'concept': 'observational learning', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (1047, 1055), 'mention': 'modeling', 'identifier': 'NDDUO:model', 'concept': 'model', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (1056, 1059), 'mention': 'tau', 'identifier': 'AlzheimerOntology:t_tau', 'concept': 't-tau', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (1060, 1071), 'mention': 'aggregation', 'identifier': 'NDDUO:Cluster', 'concept': 'Cluster', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (1135, 1138), 'mention': 'tau', 'identifier': 'AlzheimerOntology:t_tau', 'concept': 't-tau', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (1156, 1165), 'mention': 'biomarker', 'identifier': 'AlzheimerOntology:procedures_using_biomarkers', 'concept': 'thing related to procedure using biomarkers', 'type': '', 'annotator': 'NIO'}
# --------
# {'span': (1156, 1165), 'mention': 'biomarker', 'identifier': 'NDDUO:biomarker', 'concept': 'biomarker', 'type': '', 'annotator': 'NIO'}
# --------

# %%
# docs

# %%
# docs_text

# %%
docs_text
# Out:
# [{'title': 'NLM_31721178',
#   'text': "Tau (297-391) forms filaments that structurally mimic the core of paired helical filaments in Alzheimer's disease brain.The constituent paired helical filaments (PHFs) in neurofibrillary tangles are insoluble intracellular deposits central to the development of Alzheimer's disease (AD) and other tauopathies. Full-length tau requires the addition of anionic cofactors such as heparin to enhance assembly. We have shown that a fragment from the proteolytically stable core of the PHF, tau 297-391 known as 'dGAE', spontaneously forms cross-β-containing PHFs and straight filaments under physiological conditions. Here, we have analysed and compared the structures of the filaments formed by dGAE in\xa0vitro with those deposited in the brains of individuals diagnosed with AD. We show that dGAE forms PHFs that share a macromolecular structure similar to those found in brain tissue. Thus, dGAEs may serve as a model system for studying core domain assembly and for screening for inhibitors of tau aggregation.",
#   'ents': [{'span': (0, 3),
#     'mention': 'Tau',
#     'identifier': 'AlzheimerOntology:t_tau',
#     'concept': 't-tau',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (20, 29),
#     'mention': 'filaments',
#     'identifier': 'AlzheimerOntology:Filaments',
#     'concept': 'Filament',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (58, 62),
#     'mention': 'core',
#     'identifier': 'obo:IAO_0000224',
#     'concept': 'core',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (81, 90),
#     'mention': 'filaments',
#     'identifier': 'AlzheimerOntology:Filaments',
#     'concept': 'Filament',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (94, 113),
#     'mention': "Alzheimer's disease",
#     'identifier': 'AlzheimerOntology:Subtypes',
#     'concept': 'Alzheimer disease',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (94, 105),
#     'mention': "Alzheimer's",
#     'identifier': 'AlzheimerOntology:Subtypes',
#     'concept': 'Alzheimer disease',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (94, 103),
#     'mention': 'Alzheimer',
#     'identifier': 'AlzheimerOntology:Subtypes',
#     'concept': 'Alzheimer disease',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (106, 113),
#     'mention': 'disease',
#     'identifier': 'obo:OGMS_0000031',
#     'concept': 'disease',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (106, 113),
#     'mention': 'disease',
#     'identifier': 'NDDUO:disease',
#     'concept': 'disease',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (114, 119),
#     'mention': 'brain',
#     'identifier': 'obo:FMA_50801',
#     'concept': 'Brain',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (114, 119),
#     'mention': 'brain',
#     'identifier': 'AlzheimerOntology:brain',
#     'concept': 'brain',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (151, 160),
#     'mention': 'filaments',
#     'identifier': 'AlzheimerOntology:Filaments',
#     'concept': 'Filament',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (171, 194),
#     'mention': 'neurofibrillary tangles',
#     'identifier': 'AlzheimerOntology:neurofibrillary_tangle',
#     'concept': 'neurofibrillary tangle',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (187, 194),
#     'mention': 'tangles',
#     'identifier': 'AlzheimerOntology:Tangles',
#     'concept': 'Tangle',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (262, 281),
#     'mention': "Alzheimer's disease",
#     'identifier': 'AlzheimerOntology:Subtypes',
#     'concept': 'Alzheimer disease',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (262, 273),
#     'mention': "Alzheimer's",
#     'identifier': 'AlzheimerOntology:Subtypes',
#     'concept': 'Alzheimer disease',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (262, 271),
#     'mention': 'Alzheimer',
#     'identifier': 'AlzheimerOntology:Subtypes',
#     'concept': 'Alzheimer disease',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (274, 281),
#     'mention': 'disease',
#     'identifier': 'obo:OGMS_0000031',
#     'concept': 'disease',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (274, 281),
#     'mention': 'disease',
#     'identifier': 'NDDUO:disease',
#     'concept': 'disease',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (283, 285),
#     'mention': 'AD',
#     'identifier': 'AlzheimerOntology:Subtypes',
#     'concept': 'Alzheimer disease',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (291, 296),
#     'mention': 'other',
#     'identifier': 'obo:IAO_0000230',
#     'concept': 'other',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (297, 308),
#     'mention': 'tauopathies',
#     'identifier': 'obo:ND_0000151',
#     'concept': 'tauopathy',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (297, 308),
#     'mention': 'tauopathies',
#     'identifier': 'AlzheimerOntology:tauopathy',
#     'concept': 'tauopathy',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (322, 325),
#     'mention': 'tau',
#     'identifier': 'AlzheimerOntology:t_tau',
#     'concept': 't-tau',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (468, 472),
#     'mention': 'core',
#     'identifier': 'obo:IAO_0000224',
#     'concept': 'core',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (485, 488),
#     'mention': 'tau',
#     'identifier': 'AlzheimerOntology:t_tau',
#     'concept': 't-tau',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (571, 580),
#     'mention': 'filaments',
#     'identifier': 'AlzheimerOntology:Filaments',
#     'concept': 'Filament',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (671, 680),
#     'mention': 'filaments',
#     'identifier': 'AlzheimerOntology:Filaments',
#     'concept': 'Filament',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (733, 739),
#     'mention': 'brains',
#     'identifier': 'obo:FMA_50801',
#     'concept': 'Brain',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (733, 739),
#     'mention': 'brains',
#     'identifier': 'AlzheimerOntology:brain',
#     'concept': 'brain',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (770, 772),
#     'mention': 'AD',
#     'identifier': 'AlzheimerOntology:Subtypes',
#     'concept': 'Alzheimer disease',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (867, 879),
#     'mention': 'brain tissue',
#     'identifier': 'AlzheimerOntology:brain_tissue',
#     'concept': 'brain tissue',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (867, 872),
#     'mention': 'brain',
#     'identifier': 'obo:FMA_50801',
#     'concept': 'Brain',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (867, 872),
#     'mention': 'brain',
#     'identifier': 'AlzheimerOntology:brain',
#     'concept': 'brain',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (908, 913),
#     'mention': 'model',
#     'identifier': 'obo:NBO_0000215',
#     'concept': 'observational learning',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (908, 913),
#     'mention': 'model',
#     'identifier': 'NDDUO:model',
#     'concept': 'model',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (925, 933),
#     'mention': 'studying',
#     'identifier': 'NDDUO:Study_type',
#     'concept': 'clinical trial study',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (934, 938),
#     'mention': 'core',
#     'identifier': 'obo:IAO_0000224',
#     'concept': 'core',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (963, 972),
#     'mention': 'screening',
#     'identifier': 'NDDUO:Screening',
#     'concept': 'Screening',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (977, 987),
#     'mention': 'inhibitors',
#     'identifier': 'NDDUO:inhibitor',
#     'concept': 'inhibitor',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (991, 994),
#     'mention': 'tau',
#     'identifier': 'AlzheimerOntology:t_tau',
#     'concept': 't-tau',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (995, 1006),
#     'mention': 'aggregation',
#     'identifier': 'NDDUO:Cluster',
#     'concept': 'Cluster',
#     'type': '',
#     'annotator': 'NIO'}]},
#  {'title': 'CCC_000653155500009',
#   'text': "An excellent electrochemical aptasensor for amyloid-beta oligomers based on a triple-helix aptamer switch via target-triggered signal transduction DNA displacement events.An excellent aptasensor for electrochemical detection of amyloid-beta oligomers (A beta Os) at trace levels was fabricated based on a triple-helix aptamer switch (THAS) via target-triggered signal transduction DNA displacement events. Specifically, a single-stranded anti-A beta O aptamer (Apt) carrying two symmetrical arm segments was first attached via Au-S binding to an Au electrode. Gold nanoparticle (GNP)-tagged signal transduction probes (GNP-STPs) were simultaneously hybridized with the two arm segments of the Apt, and a rigid THAS was formed on the Au electrode. Compared to the conventional hybrid, the number of GNPs on the Au electrode increased significantly with the THAS, effectively improving the stability of the Apt to avoid lodging. Trithiocyanuric acid (TA) was utilized to further gather the GNPs and form network-like TA/GNPs. As a result, the differential pulse voltammetry (DPV) response of GNPs was clearly enhanced. When A beta Os were present, target-triggered signal transduction DNA displacement events were carried out from THAS via the reaction of the Apt with the A beta Os, which caused the GNP-STP to dissociate from the Au electrode, and thus a significant reduction in the DPV response was observed. The assay was able to sensitively detect trace A beta Os by monitoring the A beta O-controlled DPV response change. It exhibited a wide linear range from 1 fM to 10 pM with a low detection limit of 0.5 fM, and was successfully employed for the determination of A beta Os in 20 serum samples, with good recovery. Moreover, the developed assay can provide a sensitive and selective platform for many studies or investigations related to Alzheimer's disease (AD) monitoring and treatment.",
#   'ents': [{'span': (44, 56),
#     'mention': 'amyloid-beta',
#     'identifier': 'AlzheimerOntology:amyloid_beta_protein',
#     'concept': 'amyloid beta protein',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (44, 51),
#     'mention': 'amyloid',
#     'identifier': 'AlzheimerOntology:amyloid_beta_protein',
#     'concept': 'amyloid beta protein',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (228, 240),
#     'mention': 'amyloid-beta',
#     'identifier': 'AlzheimerOntology:amyloid_beta_protein',
#     'concept': 'amyloid beta protein',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (228, 235),
#     'mention': 'amyloid',
#     'identifier': 'AlzheimerOntology:amyloid_beta_protein',
#     'concept': 'amyloid beta protein',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (1010, 1014),
#     'mention': 'like',
#     'identifier': 'obo:NBO_0000282',
#     'concept': 'liking',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (1415, 1420),
#     'mention': 'assay',
#     'identifier': 'obo:OBI_0000070',
#     'concept': 'assay',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (1694, 1701),
#     'mention': 'samples',
#     'identifier': 'NDDUO:Sampling',
#     'concept': 'Sampling',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (1747, 1752),
#     'mention': 'assay',
#     'identifier': 'obo:OBI_0000070',
#     'concept': 'assay',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (1804, 1808),
#     'mention': 'many',
#     'identifier': 'AlzheimerOntology:Memory_orientation_screening_test',
#     'concept': 'Memory Orientation Screening Test',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (1809, 1816),
#     'mention': 'studies',
#     'identifier': 'NDDUO:Study_type',
#     'concept': 'clinical trial study',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (1846, 1865),
#     'mention': "Alzheimer's disease",
#     'identifier': 'AlzheimerOntology:Subtypes',
#     'concept': 'Alzheimer disease',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (1846, 1857),
#     'mention': "Alzheimer's",
#     'identifier': 'AlzheimerOntology:Subtypes',
#     'concept': 'Alzheimer disease',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (1846, 1855),
#     'mention': 'Alzheimer',
#     'identifier': 'AlzheimerOntology:Subtypes',
#     'concept': 'Alzheimer disease',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (1858, 1865),
#     'mention': 'disease',
#     'identifier': 'obo:OGMS_0000031',
#     'concept': 'disease',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (1858, 1865),
#     'mention': 'disease',
#     'identifier': 'NDDUO:disease',
#     'concept': 'disease',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (1867, 1869),
#     'mention': 'AD',
#     'identifier': 'AlzheimerOntology:Subtypes',
#     'concept': 'Alzheimer disease',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (1886, 1895),
#     'mention': 'treatment',
#     'identifier': 'AlzheimerOntology:Intervention',
#     'concept': 'Intervention',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (1886, 1895),
#     'mention': 'treatment',
#     'identifier': 'NDDUO:Intervention',
#     'concept': 'Thing related to intervention',
#     'type': '',
#     'annotator': 'NIO'}]},
#  {'title': 'CCC_000637925000033',
#   'text': 'Glycoengineering artificial receptors for microglia to phagocytose A beta aggregates.Oligomeric and fibrillar amyloid-beta (A beta) are principally internalized via receptor-mediated endocytosis (RME) by microglia, the main scavenger of A beta in the brain. Nevertheless, the inflammatory cascade will be evoked after vast A beta aggregate binding to pattern recognition receptors on the cell membrane, which then significantly decreases the expression of these receptors and further deteriorate A beta deposition. This vicious circle will weaken the ability of microglia for A beta elimination. Herein, a combination of metabolic glycoengineering and self-triggered click chemistry is utilized to engineer microglial membranes with ThS as artificial A beta receptors to promote microglia to phagocytose A beta aggregates. Additionally, to circumvent the undesirable immune response during the process of the bioorthogonal chemistry reaction and A beta-microglial interaction, Mn-porphyrin metal-organic frameworks (Mn-MOFs) with superoxide dismutase (SOD) and catalase (CAT) mimic activity are employed to carry N-azidoacetylmannosamine (AcManNAz) and eradicate over-expressed reactive oxygen species (ROSs). The artificial A beta receptors independent of a signal pathway involved in immunomodulation as well as Mn-MOFs with antioxidant properties can synergistically promote the phagocytosis and clearance of A beta with significantly enhanced activity and negligible adverse effects. The present study will not only provide valuable insight into the rational design of the microglial surface engineering strategy via bioorthogonal chemistry, but also hold great potential for other disease intervention associated with receptor starvation.',
#   'ents': [{'span': (28, 37),
#     'mention': 'receptors',
#     'identifier': 'AlzheimerOntology:Receptors',
#     'concept': 'Receptor',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (42, 51),
#     'mention': 'microglia',
#     'identifier': 'AlzheimerOntology:Microglia',
#     'concept': 'Microglia',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (110, 122),
#     'mention': 'amyloid-beta',
#     'identifier': 'AlzheimerOntology:amyloid_beta_protein',
#     'concept': 'amyloid beta protein',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (110, 117),
#     'mention': 'amyloid',
#     'identifier': 'AlzheimerOntology:amyloid_beta_protein',
#     'concept': 'amyloid beta protein',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (165, 173),
#     'mention': 'receptor',
#     'identifier': 'AlzheimerOntology:Receptors',
#     'concept': 'Receptor',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (183, 194),
#     'mention': 'endocytosis',
#     'identifier': 'AlzheimerOntology:Endocytosis',
#     'concept': 'Endocytosis',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (204, 213),
#     'mention': 'microglia',
#     'identifier': 'AlzheimerOntology:Microglia',
#     'concept': 'Microglia',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (251, 256),
#     'mention': 'brain',
#     'identifier': 'obo:FMA_50801',
#     'concept': 'Brain',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (251, 256),
#     'mention': 'brain',
#     'identifier': 'AlzheimerOntology:brain',
#     'concept': 'brain',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (276, 296),
#     'mention': 'inflammatory cascade',
#     'identifier': 'AlzheimerOntology:inflammation',
#     'concept': 'inflammation',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (276, 288),
#     'mention': 'inflammatory',
#     'identifier': 'AlzheimerOntology:inflammation',
#     'concept': 'inflammation',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (371, 380),
#     'mention': 'receptors',
#     'identifier': 'AlzheimerOntology:Receptors',
#     'concept': 'Receptor',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (393, 401),
#     'mention': 'membrane',
#     'identifier': 'AlzheimerOntology:Membrane',
#     'concept': 'Membrane',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (462, 471),
#     'mention': 'receptors',
#     'identifier': 'AlzheimerOntology:Receptors',
#     'concept': 'Receptor',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (562, 571),
#     'mention': 'microglia',
#     'identifier': 'AlzheimerOntology:Microglia',
#     'concept': 'Microglia',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (718, 727),
#     'mention': 'membranes',
#     'identifier': 'AlzheimerOntology:Membrane',
#     'concept': 'Membrane',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (758, 767),
#     'mention': 'receptors',
#     'identifier': 'AlzheimerOntology:Receptors',
#     'concept': 'Receptor',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (779, 788),
#     'mention': 'microglia',
#     'identifier': 'AlzheimerOntology:Microglia',
#     'concept': 'Microglia',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (894, 901),
#     'mention': 'process',
#     'identifier': 'obo:BFO_0000015',
#     'concept': 'process',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (894, 901),
#     'mention': 'process',
#     'identifier': 'span:Process',
#     'concept': 'process',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (1187, 1193),
#     'mention': 'oxygen',
#     'identifier': 'AlzheimerOntology:oxygen',
#     'concept': 'oxygen',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (1232, 1241),
#     'mention': 'receptors',
#     'identifier': 'AlzheimerOntology:Receptors',
#     'concept': 'Receptor',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (1327, 1338),
#     'mention': 'antioxidant',
#     'identifier': 'AlzheimerOntology:antioxidant',
#     'concept': 'antioxidant',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (1382, 1394),
#     'mention': 'phagocytosis',
#     'identifier': 'AlzheimerOntology:phagocytosis',
#     'concept': 'phagocytosis',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (1500, 1505),
#     'mention': 'study',
#     'identifier': 'NDDUO:Study_type',
#     'concept': 'clinical trial study',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (1680, 1685),
#     'mention': 'other',
#     'identifier': 'obo:IAO_0000230',
#     'concept': 'other',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (1686, 1693),
#     'mention': 'disease',
#     'identifier': 'obo:OGMS_0000031',
#     'concept': 'disease',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (1686, 1693),
#     'mention': 'disease',
#     'identifier': 'NDDUO:disease',
#     'concept': 'disease',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (1694, 1706),
#     'mention': 'intervention',
#     'identifier': 'AlzheimerOntology:Intervention',
#     'concept': 'Intervention',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (1694, 1706),
#     'mention': 'intervention',
#     'identifier': 'NDDUO:Intervention',
#     'concept': 'Thing related to intervention',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (1723, 1731),
#     'mention': 'receptor',
#     'identifier': 'AlzheimerOntology:Receptors',
#     'concept': 'Receptor',
#     'type': '',
#     'annotator': 'NIO'}]},
#  {'title': 'NLM_34101788',
#   'text': "Platform Trials to Expedite Drug Development in Alzheimer's Disease: A Report from the EU/US CTAD Task Force.A diverse range of platforms has been established to increase the efficiency and speed of clinical trials for Alzheimer's disease (AD). These platforms enable parallel assessment of multiple therapeutics, treatment regimens, or participant groups; use uniform protocols and outcome measures; and may allow treatment arms to be added or dropped based on interim analyses of outcomes. The EU/US CTAD Task Force discussed the lessons learned from the Dominantly Inherited Alzheimer's Network Trials Unit (DIAN-TU) platform trial and the challenges addressed by other platform trials that have launched or are in the planning stages. The landscape of clinical trial platforms in the AD space includes those testing experimental therapies such as DIAN-TU, platforms designed to test multidomain interventions, and those designed to streamline trial recruitment by building trial-ready cohorts. The heterogeneity of the AD patient population, AD drugs, treatment regimens, and analytical methods complicates the design and execution of platform trials, yet Task Force members concluded that platform trials are essential to advance the search for effective AD treatments, including combination therapies.",
#   'ents': [{'span': (28, 32),
#     'mention': 'Drug',
#     'identifier': 'NDDUO:drug',
#     'concept': 'drug',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (48, 67),
#     'mention': "Alzheimer's Disease",
#     'identifier': 'AlzheimerOntology:Subtypes',
#     'concept': 'Alzheimer disease',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (48, 59),
#     'mention': "Alzheimer's",
#     'identifier': 'AlzheimerOntology:Subtypes',
#     'concept': 'Alzheimer disease',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (48, 57),
#     'mention': 'Alzheimer',
#     'identifier': 'AlzheimerOntology:Subtypes',
#     'concept': 'Alzheimer disease',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (60, 67),
#     'mention': 'Disease',
#     'identifier': 'obo:OGMS_0000031',
#     'concept': 'disease',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (60, 67),
#     'mention': 'Disease',
#     'identifier': 'NDDUO:disease',
#     'concept': 'disease',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (199, 214),
#     'mention': 'clinical trials',
#     'identifier': 'NDDUO:Clinical_trial',
#     'concept': 'thing related to clinical trial',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (199, 207),
#     'mention': 'clinical',
#     'identifier': 'NDDUO:Clinical',
#     'concept': 'Clinical thing',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (219, 238),
#     'mention': "Alzheimer's disease",
#     'identifier': 'AlzheimerOntology:Subtypes',
#     'concept': 'Alzheimer disease',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (219, 230),
#     'mention': "Alzheimer's",
#     'identifier': 'AlzheimerOntology:Subtypes',
#     'concept': 'Alzheimer disease',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (219, 228),
#     'mention': 'Alzheimer',
#     'identifier': 'AlzheimerOntology:Subtypes',
#     'concept': 'Alzheimer disease',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (231, 238),
#     'mention': 'disease',
#     'identifier': 'obo:OGMS_0000031',
#     'concept': 'disease',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (231, 238),
#     'mention': 'disease',
#     'identifier': 'NDDUO:disease',
#     'concept': 'disease',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (240, 242),
#     'mention': 'AD',
#     'identifier': 'AlzheimerOntology:Subtypes',
#     'concept': 'Alzheimer disease',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (314, 323),
#     'mention': 'treatment',
#     'identifier': 'AlzheimerOntology:Intervention',
#     'concept': 'Intervention',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (314, 323),
#     'mention': 'treatment',
#     'identifier': 'NDDUO:Intervention',
#     'concept': 'Thing related to intervention',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (349, 355),
#     'mention': 'groups',
#     'identifier': 'AlzheimerOntology:control_group_study_arm',
#     'concept': 'control group study arm',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (369, 378),
#     'mention': 'protocols',
#     'identifier': 'obo:OBI_0000272',
#     'concept': 'protocol',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (383, 399),
#     'mention': 'outcome measures',
#     'identifier': 'NDDUO:outcome_measure',
#     'concept': 'outcome measure',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (383, 390),
#     'mention': 'outcome',
#     'identifier': 'AlzheimerOntology:Outcome',
#     'concept': 'Outcome',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (383, 390),
#     'mention': 'outcome',
#     'identifier': 'NDDUO:Outcome',
#     'concept': 'Thing related to outcome',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (415, 424),
#     'mention': 'treatment',
#     'identifier': 'AlzheimerOntology:Intervention',
#     'concept': 'Intervention',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (415, 424),
#     'mention': 'treatment',
#     'identifier': 'NDDUO:Intervention',
#     'concept': 'Thing related to intervention',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (482, 490),
#     'mention': 'outcomes',
#     'identifier': 'AlzheimerOntology:Outcome',
#     'concept': 'Outcome',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (482, 490),
#     'mention': 'outcomes',
#     'identifier': 'NDDUO:Outcome',
#     'concept': 'Thing related to outcome',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (540, 547),
#     'mention': 'learned',
#     'identifier': 'obo:GO_0007612',
#     'concept': 'learning',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (578, 589),
#     'mention': "Alzheimer's",
#     'identifier': 'AlzheimerOntology:Subtypes',
#     'concept': 'Alzheimer disease',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (578, 587),
#     'mention': 'Alzheimer',
#     'identifier': 'AlzheimerOntology:Subtypes',
#     'concept': 'Alzheimer disease',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (667, 672),
#     'mention': 'other',
#     'identifier': 'obo:IAO_0000230',
#     'concept': 'other',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (722, 730),
#     'mention': 'planning',
#     'identifier': 'obo:MF_0000027',
#     'concept': 'planning',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (722, 730),
#     'mention': 'planning',
#     'identifier': 'obo:OBI_0000260',
#     'concept': 'plan',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (722, 730),
#     'mention': 'planning',
#     'identifier': 'obo:OBI_0000339',
#     'concept': 'planning',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (731, 737),
#     'mention': 'stages',
#     'identifier': 'NDDUO:Stages',
#     'concept': 'thing related to stage',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (756, 770),
#     'mention': 'clinical trial',
#     'identifier': 'NDDUO:Clinical_trial',
#     'concept': 'thing related to clinical trial',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (756, 764),
#     'mention': 'clinical',
#     'identifier': 'NDDUO:Clinical',
#     'concept': 'Clinical thing',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (788, 790),
#     'mention': 'AD',
#     'identifier': 'AlzheimerOntology:Subtypes',
#     'concept': 'Alzheimer disease',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (899, 912),
#     'mention': 'interventions',
#     'identifier': 'AlzheimerOntology:Intervention',
#     'concept': 'Intervention',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (899, 912),
#     'mention': 'interventions',
#     'identifier': 'NDDUO:Intervention',
#     'concept': 'Thing related to intervention',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (989, 996),
#     'mention': 'cohorts',
#     'identifier': 'NDDO:NDDO_00000107',
#     'concept': 'cohort',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (989, 996),
#     'mention': 'cohorts',
#     'identifier': 'AlzheimerOntology:Cohort_effect',
#     'concept': 'Cohort effect',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (1023, 1025),
#     'mention': 'AD',
#     'identifier': 'AlzheimerOntology:Subtypes',
#     'concept': 'Alzheimer disease',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (1034, 1044),
#     'mention': 'population',
#     'identifier': 'AlzheimerOntology:Populations',
#     'concept': 'Population',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (1046, 1048),
#     'mention': 'AD',
#     'identifier': 'AlzheimerOntology:Subtypes',
#     'concept': 'Alzheimer disease',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (1049, 1054),
#     'mention': 'drugs',
#     'identifier': 'NDDUO:drug',
#     'concept': 'drug',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (1056, 1065),
#     'mention': 'treatment',
#     'identifier': 'AlzheimerOntology:Intervention',
#     'concept': 'Intervention',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (1056, 1065),
#     'mention': 'treatment',
#     'identifier': 'NDDUO:Intervention',
#     'concept': 'Thing related to intervention',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (1260, 1262),
#     'mention': 'AD',
#     'identifier': 'AlzheimerOntology:Subtypes',
#     'concept': 'Alzheimer disease',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (1263, 1273),
#     'mention': 'treatments',
#     'identifier': 'AlzheimerOntology:Intervention',
#     'concept': 'Intervention',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (1263, 1273),
#     'mention': 'treatments',
#     'identifier': 'NDDUO:Intervention',
#     'concept': 'Thing related to intervention',
#     'type': '',
#     'annotator': 'NIO'}]},
#  {'title': 'NLM_33958804',
#   'text': "Neuronal ApoE upregulates MHC-I expression to drive selective neurodegeneration in Alzheimer's disease.Selective neurodegeneration is a critical causal factor in Alzheimer's disease (AD); however, the mechanisms that lead some neurons to perish, whereas others remain resilient, are unknown. We sought potential drivers of this selective vulnerability using single-nucleus RNA sequencing and discovered that ApoE expression level is a substantial driver of neuronal variability. Strikingly, neuronal expression of ApoE-which has a robust genetic linkage to AD-correlated strongly, on a cell-by-cell basis, with immune response pathways in neurons in the brains of wild-type mice, human ApoE knock-in mice and humans with or without AD. Elimination or over-expression of neuronal ApoE revealed a causal relationship among ApoE expression, neuronal MHC-I expression, tau pathology and neurodegeneration. Functional reduction of MHC-I ameliorated tau pathology in ApoE4-expressing primary neurons and in mouse hippocampi expressing pathological tau. These findings suggest a mechanism linking neuronal ApoE expression to MHC-I expression and, subsequently, to tau pathology and selective neurodegeneration.",
#   'ents': [{'span': (9, 13),
#     'mention': 'ApoE',
#     'identifier': 'AlzheimerOntology:APOE',
#     'concept': 'APOE',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (9, 13),
#     'mention': 'ApoE',
#     'identifier': 'AlzheimerOntology:ApoE_Protein',
#     'concept': 'ApoE Protein',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (83, 102),
#     'mention': "Alzheimer's disease",
#     'identifier': 'AlzheimerOntology:Subtypes',
#     'concept': 'Alzheimer disease',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (83, 94),
#     'mention': "Alzheimer's",
#     'identifier': 'AlzheimerOntology:Subtypes',
#     'concept': 'Alzheimer disease',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (83, 92),
#     'mention': 'Alzheimer',
#     'identifier': 'AlzheimerOntology:Subtypes',
#     'concept': 'Alzheimer disease',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (95, 102),
#     'mention': 'disease',
#     'identifier': 'obo:OGMS_0000031',
#     'concept': 'disease',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (95, 102),
#     'mention': 'disease',
#     'identifier': 'NDDUO:disease',
#     'concept': 'disease',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (162, 181),
#     'mention': "Alzheimer's disease",
#     'identifier': 'AlzheimerOntology:Subtypes',
#     'concept': 'Alzheimer disease',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (162, 173),
#     'mention': "Alzheimer's",
#     'identifier': 'AlzheimerOntology:Subtypes',
#     'concept': 'Alzheimer disease',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (162, 171),
#     'mention': 'Alzheimer',
#     'identifier': 'AlzheimerOntology:Subtypes',
#     'concept': 'Alzheimer disease',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (174, 181),
#     'mention': 'disease',
#     'identifier': 'obo:OGMS_0000031',
#     'concept': 'disease',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (174, 181),
#     'mention': 'disease',
#     'identifier': 'NDDUO:disease',
#     'concept': 'disease',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (183, 185),
#     'mention': 'AD',
#     'identifier': 'AlzheimerOntology:Subtypes',
#     'concept': 'Alzheimer disease',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (227, 234),
#     'mention': 'neurons',
#     'identifier': 'NDDUO:Neurons',
#     'concept': 'Neuron',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (254, 260),
#     'mention': 'others',
#     'identifier': 'obo:IAO_0000230',
#     'concept': 'other',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (365, 372),
#     'mention': 'nucleus',
#     'identifier': 'AlzheimerOntology:Nucleus',
#     'concept': 'Nucleus',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (373, 376),
#     'mention': 'RNA',
#     'identifier': 'AlzheimerOntology:RNA',
#     'concept': 'RNA',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (408, 412),
#     'mention': 'ApoE',
#     'identifier': 'AlzheimerOntology:APOE',
#     'concept': 'APOE',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (408, 412),
#     'mention': 'ApoE',
#     'identifier': 'AlzheimerOntology:ApoE_Protein',
#     'concept': 'ApoE Protein',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (514, 518),
#     'mention': 'ApoE',
#     'identifier': 'AlzheimerOntology:APOE',
#     'concept': 'APOE',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (514, 518),
#     'mention': 'ApoE',
#     'identifier': 'AlzheimerOntology:ApoE_Protein',
#     'concept': 'ApoE Protein',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (557, 559),
#     'mention': 'AD',
#     'identifier': 'AlzheimerOntology:Subtypes',
#     'concept': 'Alzheimer disease',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (639, 646),
#     'mention': 'neurons',
#     'identifier': 'NDDUO:Neurons',
#     'concept': 'Neuron',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (654, 660),
#     'mention': 'brains',
#     'identifier': 'obo:FMA_50801',
#     'concept': 'Brain',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (654, 660),
#     'mention': 'brains',
#     'identifier': 'AlzheimerOntology:brain',
#     'concept': 'brain',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (674, 678),
#     'mention': 'mice',
#     'identifier': 'NDDUO:Mouse_',
#     'concept': 'Mouse',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (686, 690),
#     'mention': 'ApoE',
#     'identifier': 'AlzheimerOntology:APOE',
#     'concept': 'APOE',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (686, 690),
#     'mention': 'ApoE',
#     'identifier': 'AlzheimerOntology:ApoE_Protein',
#     'concept': 'ApoE Protein',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (700, 704),
#     'mention': 'mice',
#     'identifier': 'NDDUO:Mouse_',
#     'concept': 'Mouse',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (732, 734),
#     'mention': 'AD',
#     'identifier': 'AlzheimerOntology:Subtypes',
#     'concept': 'Alzheimer disease',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (779, 783),
#     'mention': 'ApoE',
#     'identifier': 'AlzheimerOntology:APOE',
#     'concept': 'APOE',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (779, 783),
#     'mention': 'ApoE',
#     'identifier': 'AlzheimerOntology:ApoE_Protein',
#     'concept': 'ApoE Protein',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (821, 825),
#     'mention': 'ApoE',
#     'identifier': 'AlzheimerOntology:APOE',
#     'concept': 'APOE',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (821, 825),
#     'mention': 'ApoE',
#     'identifier': 'AlzheimerOntology:ApoE_Protein',
#     'concept': 'ApoE Protein',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (865, 878),
#     'mention': 'tau pathology',
#     'identifier': 'AlzheimerOntology:tauopathy',
#     'concept': 'tauopathy',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (865, 868),
#     'mention': 'tau',
#     'identifier': 'AlzheimerOntology:t_tau',
#     'concept': 't-tau',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (944, 957),
#     'mention': 'tau pathology',
#     'identifier': 'AlzheimerOntology:tauopathy',
#     'concept': 'tauopathy',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (944, 947),
#     'mention': 'tau',
#     'identifier': 'AlzheimerOntology:t_tau',
#     'concept': 't-tau',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (986, 993),
#     'mention': 'neurons',
#     'identifier': 'NDDUO:Neurons',
#     'concept': 'Neuron',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (1001, 1006),
#     'mention': 'mouse',
#     'identifier': 'NDDUO:Mouse_',
#     'concept': 'Mouse',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (1007, 1017),
#     'mention': 'hippocampi',
#     'identifier': 'obo:FMA_62493',
#     'concept': 'Hippocampus',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (1007, 1017),
#     'mention': 'hippocampi',
#     'identifier': 'AlzheimerOntology:Hippocampus',
#     'concept': 'Hippocampus',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (1042, 1045),
#     'mention': 'tau',
#     'identifier': 'AlzheimerOntology:t_tau',
#     'concept': 't-tau',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (1099, 1103),
#     'mention': 'ApoE',
#     'identifier': 'AlzheimerOntology:APOE',
#     'concept': 'APOE',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (1099, 1103),
#     'mention': 'ApoE',
#     'identifier': 'AlzheimerOntology:ApoE_Protein',
#     'concept': 'ApoE Protein',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (1157, 1170),
#     'mention': 'tau pathology',
#     'identifier': 'AlzheimerOntology:tauopathy',
#     'concept': 'tauopathy',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (1157, 1160),
#     'mention': 'tau',
#     'identifier': 'AlzheimerOntology:t_tau',
#     'concept': 't-tau',
#     'type': '',
#     'annotator': 'NIO'}]},
#  {'title': 'NLM_33988687',
#   'text': "Alzheimer mutant speeds APP transport.APPS198P segregates with rare familial forms of Alzheimer's disease and resides within exon 5, unlike 27 other mutations that reside in exons 16 or 17. In this issue, Zhang et al. (2021. J. Exp. Med.https://doi.org/10.1084/jem.20210313) show that the brains of APPS198P transgenic mice accumulate excess levels of Aβ. In cultured cells, APPS198P undergoes accelerated ER folding, leading to early arrival in late vesicular compartments, thereby enhancing generation of Aβ.",
#   'ents': [{'span': (0, 9),
#     'mention': 'Alzheimer',
#     'identifier': 'AlzheimerOntology:Subtypes',
#     'concept': 'Alzheimer disease',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (24, 27),
#     'mention': 'APP',
#     'identifier': 'AlzheimerOntology:APP',
#     'concept': 'APP',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (24, 27),
#     'mention': 'APP',
#     'identifier': 'AlzheimerOntology:amyloid_precursor_protein',
#     'concept': 'amyloid precursor protein',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (86, 105),
#     'mention': "Alzheimer's disease",
#     'identifier': 'AlzheimerOntology:Subtypes',
#     'concept': 'Alzheimer disease',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (86, 97),
#     'mention': "Alzheimer's",
#     'identifier': 'AlzheimerOntology:Subtypes',
#     'concept': 'Alzheimer disease',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (86, 95),
#     'mention': 'Alzheimer',
#     'identifier': 'AlzheimerOntology:Subtypes',
#     'concept': 'Alzheimer disease',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (98, 105),
#     'mention': 'disease',
#     'identifier': 'obo:OGMS_0000031',
#     'concept': 'disease',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (98, 105),
#     'mention': 'disease',
#     'identifier': 'NDDUO:disease',
#     'concept': 'disease',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (143, 148),
#     'mention': 'other',
#     'identifier': 'obo:IAO_0000230',
#     'concept': 'other',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (149, 158),
#     'mention': 'mutations',
#     'identifier': 'AlzheimerOntology:mutation',
#     'concept': 'mutation',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (289, 295),
#     'mention': 'brains',
#     'identifier': 'obo:FMA_50801',
#     'concept': 'Brain',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (289, 295),
#     'mention': 'brains',
#     'identifier': 'AlzheimerOntology:brain',
#     'concept': 'brain',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (319, 323),
#     'mention': 'mice',
#     'identifier': 'NDDUO:Mouse_',
#     'concept': 'Mouse',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (359, 373),
#     'mention': 'cultured cells',
#     'identifier': 'AlzheimerOntology:Cell_cultures',
#     'concept': 'Cell culture',
#     'type': '',
#     'annotator': 'NIO'}]},
#  {'title': 'CCC_000647663200001',
#   'text': 'Impairment of visual cortical plasticity by amyloid-beta species.Introduction: A variety of transgenic and knock-in mice that express mutant alleles of Amyloid precursor protein (APP) have been used to model the effects of amyloid-beta (A?) on circuit function in Alzheimer?s disease (AD); however phenotypes described in these mice may be affected by expression of mutant APP or proteolytic cleavage products independent of A?. In addition, the effects of mutant APP expression are attributed to elevated expression of the amyloidogenic, 42-amino acid-long species of A? (A?42) associated with amyloid plaque accumulation in AD, though elevated concentrations of A?40, an A? species produced with normal synaptic activity, may also affect neural function. Methods: To explore the effects of elevated expression of A? on synaptic function in vivo, we assessed visual system plasticity in transgenic mice that express and secrete A? throughout the brain in the absence of APP overexpression. Transgenic mice that express either A?40 or A?42 were assayed for their ability to appropriately demonstrate ocular dominance plasticity following monocular deprivation. Results: Using two complementary approaches to measure the plastic response to monocular deprivation, we find that male and female mice that express either 40- or 42-amino acid?long A? species demonstrate a plasticity defect comparable to that elicited in transgenic mice that express mutant alleles of APP and Presenilin 1 (APP/PS1 mice). Conclusions: These data support the hypothesis that mutant APP-driven plasticity impairment in mouse models of AD is mediated by production and accumulation of A?. Moreover, these findings suggest that soluble species of A? are capable of modulating synaptic plasticity, likely independent of any aggregation. These findings may have implications for the role of soluble species of A? in both development and disease settings.',
#   'ents': [{'span': (44, 56),
#     'mention': 'amyloid-beta',
#     'identifier': 'AlzheimerOntology:amyloid_beta_protein',
#     'concept': 'amyloid beta protein',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (44, 51),
#     'mention': 'amyloid',
#     'identifier': 'AlzheimerOntology:amyloid_beta_protein',
#     'concept': 'amyloid beta protein',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (116, 120),
#     'mention': 'mice',
#     'identifier': 'NDDUO:Mouse_',
#     'concept': 'Mouse',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (152, 177),
#     'mention': 'Amyloid precursor protein',
#     'identifier': 'AlzheimerOntology:amyloid_precursor_protein',
#     'concept': 'amyloid precursor protein',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (152, 159),
#     'mention': 'Amyloid',
#     'identifier': 'AlzheimerOntology:amyloid_beta_protein',
#     'concept': 'amyloid beta protein',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (170, 177),
#     'mention': 'protein',
#     'identifier': 'AlzheimerOntology:protein',
#     'concept': 'protein',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (179, 182),
#     'mention': 'APP',
#     'identifier': 'AlzheimerOntology:APP',
#     'concept': 'APP',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (179, 182),
#     'mention': 'APP',
#     'identifier': 'AlzheimerOntology:amyloid_precursor_protein',
#     'concept': 'amyloid precursor protein',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (202, 207),
#     'mention': 'model',
#     'identifier': 'obo:NBO_0000215',
#     'concept': 'observational learning',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (202, 207),
#     'mention': 'model',
#     'identifier': 'NDDUO:model',
#     'concept': 'model',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (223, 235),
#     'mention': 'amyloid-beta',
#     'identifier': 'AlzheimerOntology:amyloid_beta_protein',
#     'concept': 'amyloid beta protein',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (223, 230),
#     'mention': 'amyloid',
#     'identifier': 'AlzheimerOntology:amyloid_beta_protein',
#     'concept': 'amyloid beta protein',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (252, 260),
#     'mention': 'function',
#     'identifier': 'obo:BFO_0000034',
#     'concept': 'function',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (252, 260),
#     'mention': 'function',
#     'identifier': 'snap:Function',
#     'concept': 'function',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (264, 283),
#     'mention': 'Alzheimer?s disease',
#     'identifier': 'AlzheimerOntology:Subtypes',
#     'concept': 'Alzheimer disease',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (264, 275),
#     'mention': 'Alzheimer?s',
#     'identifier': 'AlzheimerOntology:Subtypes',
#     'concept': 'Alzheimer disease',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (264, 273),
#     'mention': 'Alzheimer',
#     'identifier': 'AlzheimerOntology:Subtypes',
#     'concept': 'Alzheimer disease',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (276, 283),
#     'mention': 'disease',
#     'identifier': 'obo:OGMS_0000031',
#     'concept': 'disease',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (276, 283),
#     'mention': 'disease',
#     'identifier': 'NDDUO:disease',
#     'concept': 'disease',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (285, 287),
#     'mention': 'AD',
#     'identifier': 'AlzheimerOntology:Subtypes',
#     'concept': 'Alzheimer disease',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (298, 308),
#     'mention': 'phenotypes',
#     'identifier': 'obo:OGMS_0000023',
#     'concept': 'phenotype',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (328, 332),
#     'mention': 'mice',
#     'identifier': 'NDDUO:Mouse_',
#     'concept': 'Mouse',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (373, 376),
#     'mention': 'APP',
#     'identifier': 'AlzheimerOntology:APP',
#     'concept': 'APP',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (373, 376),
#     'mention': 'APP',
#     'identifier': 'AlzheimerOntology:amyloid_precursor_protein',
#     'concept': 'amyloid precursor protein',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (464, 467),
#     'mention': 'APP',
#     'identifier': 'AlzheimerOntology:APP',
#     'concept': 'APP',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (464, 467),
#     'mention': 'APP',
#     'identifier': 'AlzheimerOntology:amyloid_precursor_protein',
#     'concept': 'amyloid precursor protein',
#     'type': '',
#     'annotator': 'NIO'},
# ...
#     'annotator': 'NIO'},
#    {'span': (276, 278),
#     'mention': 'AD',
#     'identifier': 'AlzheimerOntology:Subtypes',
#     'concept': 'Alzheimer disease',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (349, 364),
#     'mention': 'clinical trials',
#     'identifier': 'NDDUO:Clinical_trial',
#     'concept': 'thing related to clinical trial',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (349, 357),
#     'mention': 'clinical',
#     'identifier': 'NDDUO:Clinical',
#     'concept': 'Clinical thing',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (377, 382),
#     'mention': 'drugs',
#     'identifier': 'NDDUO:drug',
#     'concept': 'drug',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (466, 468),
#     'mention': 'AD',
#     'identifier': 'AlzheimerOntology:Subtypes',
#     'concept': 'Alzheimer disease',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (473, 483),
#     'mention': 'treatments',
#     'identifier': 'AlzheimerOntology:Intervention',
#     'concept': 'Intervention',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (473, 483),
#     'mention': 'treatments',
#     'identifier': 'NDDUO:Intervention',
#     'concept': 'Thing related to intervention',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (487, 494),
#     'mention': 'Phase 3',
#     'identifier': 'NDDUO:phase_3',
#     'concept': 'phase 3',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (509, 516),
#     'mention': 'Phase 2',
#     'identifier': 'NDDUO:phase_2',
#     'concept': 'phase 2',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (528, 535),
#     'mention': 'Phase 1',
#     'identifier': 'NDDUO:phase_1',
#     'concept': 'phase 1',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (553, 558),
#     'mention': 'drugs',
#     'identifier': 'NDDUO:drug',
#     'concept': 'drug',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (610, 612),
#     'mention': 'AD',
#     'identifier': 'AlzheimerOntology:Subtypes',
#     'concept': 'Alzheimer disease',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (632, 639),
#     'mention': 'disease',
#     'identifier': 'obo:OGMS_0000031',
#     'concept': 'disease',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (632, 639),
#     'mention': 'disease',
#     'identifier': 'NDDUO:disease',
#     'concept': 'disease',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (673, 682),
#     'mention': 'cognitive',
#     'identifier': 'AlzheimerOntology:Cognitive_Tests',
#     'concept': 'Cognitive Test',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (714, 719),
#     'mention': 'drugs',
#     'identifier': 'NDDUO:drug',
#     'concept': 'drug',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (746, 771),
#     'mention': 'neuropsychiatric symptoms',
#     'identifier': 'AlzheimerOntology:Neuropsychiatric_symptoms',
#     'concept': 'Neuropsychiatric symptom',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (746, 771),
#     'mention': 'neuropsychiatric symptoms',
#     'identifier': 'AlzheimerOntology:psychological_symptom',
#     'concept': 'psychological symptom',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (763, 771),
#     'mention': 'symptoms',
#     'identifier': 'NDDUO:Symptoms',
#     'concept': 'Symptom or sign',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (837, 846),
#     'mention': 'processes',
#     'identifier': 'obo:BFO_0000015',
#     'concept': 'process',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (837, 846),
#     'mention': 'processes',
#     'identifier': 'span:Process',
#     'concept': 'process',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (851, 855),
#     'mention': 'more',
#     'identifier': 'AlzheimerOntology:Memory_orientation_screening_test',
#     'concept': 'Memory Orientation Screening Test',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (869, 879),
#     'mention': 'biomarkers',
#     'identifier': 'AlzheimerOntology:procedures_using_biomarkers',
#     'concept': 'thing related to procedure using biomarkers',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (869, 879),
#     'mention': 'biomarkers',
#     'identifier': 'NDDUO:biomarker',
#     'concept': 'biomarker',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (884, 888),
#     'mention': 'more',
#     'identifier': 'AlzheimerOntology:Memory_orientation_screening_test',
#     'concept': 'Memory Orientation Screening Test',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (981, 990),
#     'mention': 'treatment',
#     'identifier': 'AlzheimerOntology:Intervention',
#     'concept': 'Intervention',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (981, 990),
#     'mention': 'treatment',
#     'identifier': 'NDDUO:Intervention',
#     'concept': 'Thing related to intervention',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (994, 996),
#     'mention': 'AD',
#     'identifier': 'AlzheimerOntology:Subtypes',
#     'concept': 'Alzheimer disease',
#     'type': '',
#     'annotator': 'NIO'}]},
#  {'title': 'NLM_33730588',
#   'text': "The AD tau core spontaneously self-assembles and recruits full-length tau to filaments.Tau accumulation is a major pathological hallmark of Alzheimer's disease (AD) and other tauopathies, but the mechanism(s) of tau aggregation remains unclear. Taking advantage of the identification of tau filament cores by cryoelectron microscopy, we demonstrate that the AD tau core possesses the intrinsic ability to spontaneously aggregate in the absence of an inducer, with antibodies generated against AD tau core filaments detecting AD tau pathology. The AD tau core also drives aggregation of full-length wild-type tau, increases seeding potential, and templates abnormal forms of tau present in brain homogenates and antemortem cerebrospinal fluid (CSF) from patients with AD in an ultrasensitive real-time quaking-induced conversion (QuIC) assay. Finally, we show that the filament cores in corticobasal degeneration (CBD) and Pick's disease (PiD) similarly assemble into filaments under physiological conditions. These results document an approach to modeling tau aggregation and have significant implications for in\xa0vivo investigation of tau transmission and biomarker development.",
#   'ents': [{'span': (4, 6),
#     'mention': 'AD',
#     'identifier': 'AlzheimerOntology:Subtypes',
#     'concept': 'Alzheimer disease',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (7, 10),
#     'mention': 'tau',
#     'identifier': 'AlzheimerOntology:t_tau',
#     'concept': 't-tau',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (11, 15),
#     'mention': 'core',
#     'identifier': 'obo:IAO_0000224',
#     'concept': 'core',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (70, 73),
#     'mention': 'tau',
#     'identifier': 'AlzheimerOntology:t_tau',
#     'concept': 't-tau',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (77, 86),
#     'mention': 'filaments',
#     'identifier': 'AlzheimerOntology:Filaments',
#     'concept': 'Filament',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (87, 90),
#     'mention': 'Tau',
#     'identifier': 'AlzheimerOntology:t_tau',
#     'concept': 't-tau',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (140, 159),
#     'mention': "Alzheimer's disease",
#     'identifier': 'AlzheimerOntology:Subtypes',
#     'concept': 'Alzheimer disease',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (140, 151),
#     'mention': "Alzheimer's",
#     'identifier': 'AlzheimerOntology:Subtypes',
#     'concept': 'Alzheimer disease',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (140, 149),
#     'mention': 'Alzheimer',
#     'identifier': 'AlzheimerOntology:Subtypes',
#     'concept': 'Alzheimer disease',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (152, 159),
#     'mention': 'disease',
#     'identifier': 'obo:OGMS_0000031',
#     'concept': 'disease',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (152, 159),
#     'mention': 'disease',
#     'identifier': 'NDDUO:disease',
#     'concept': 'disease',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (161, 163),
#     'mention': 'AD',
#     'identifier': 'AlzheimerOntology:Subtypes',
#     'concept': 'Alzheimer disease',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (169, 174),
#     'mention': 'other',
#     'identifier': 'obo:IAO_0000230',
#     'concept': 'other',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (175, 186),
#     'mention': 'tauopathies',
#     'identifier': 'obo:ND_0000151',
#     'concept': 'tauopathy',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (175, 186),
#     'mention': 'tauopathies',
#     'identifier': 'AlzheimerOntology:tauopathy',
#     'concept': 'tauopathy',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (212, 215),
#     'mention': 'tau',
#     'identifier': 'AlzheimerOntology:t_tau',
#     'concept': 't-tau',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (216, 227),
#     'mention': 'aggregation',
#     'identifier': 'NDDUO:Cluster',
#     'concept': 'Cluster',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (287, 290),
#     'mention': 'tau',
#     'identifier': 'AlzheimerOntology:t_tau',
#     'concept': 't-tau',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (291, 299),
#     'mention': 'filament',
#     'identifier': 'AlzheimerOntology:Filaments',
#     'concept': 'Filament',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (300, 305),
#     'mention': 'cores',
#     'identifier': 'obo:IAO_0000224',
#     'concept': 'core',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (358, 360),
#     'mention': 'AD',
#     'identifier': 'AlzheimerOntology:Subtypes',
#     'concept': 'Alzheimer disease',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (361, 364),
#     'mention': 'tau',
#     'identifier': 'AlzheimerOntology:t_tau',
#     'concept': 't-tau',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (365, 369),
#     'mention': 'core',
#     'identifier': 'obo:IAO_0000224',
#     'concept': 'core',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (464, 474),
#     'mention': 'antibodies',
#     'identifier': 'AlzheimerOntology:antibody',
#     'concept': 'antibody',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (493, 495),
#     'mention': 'AD',
#     'identifier': 'AlzheimerOntology:Subtypes',
#     'concept': 'Alzheimer disease',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (496, 499),
#     'mention': 'tau',
#     'identifier': 'AlzheimerOntology:t_tau',
#     'concept': 't-tau',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (500, 504),
#     'mention': 'core',
#     'identifier': 'obo:IAO_0000224',
#     'concept': 'core',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (505, 514),
#     'mention': 'filaments',
#     'identifier': 'AlzheimerOntology:Filaments',
#     'concept': 'Filament',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (525, 527),
#     'mention': 'AD',
#     'identifier': 'AlzheimerOntology:Subtypes',
#     'concept': 'Alzheimer disease',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (528, 541),
#     'mention': 'tau pathology',
#     'identifier': 'AlzheimerOntology:tauopathy',
#     'concept': 'tauopathy',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (528, 531),
#     'mention': 'tau',
#     'identifier': 'AlzheimerOntology:t_tau',
#     'concept': 't-tau',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (547, 549),
#     'mention': 'AD',
#     'identifier': 'AlzheimerOntology:Subtypes',
#     'concept': 'Alzheimer disease',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (550, 553),
#     'mention': 'tau',
#     'identifier': 'AlzheimerOntology:t_tau',
#     'concept': 't-tau',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (554, 558),
#     'mention': 'core',
#     'identifier': 'obo:IAO_0000224',
#     'concept': 'core',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (571, 582),
#     'mention': 'aggregation',
#     'identifier': 'NDDUO:Cluster',
#     'concept': 'Cluster',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (608, 611),
#     'mention': 'tau',
#     'identifier': 'AlzheimerOntology:t_tau',
#     'concept': 't-tau',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (674, 677),
#     'mention': 'tau',
#     'identifier': 'AlzheimerOntology:t_tau',
#     'concept': 't-tau',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (689, 694),
#     'mention': 'brain',
#     'identifier': 'obo:FMA_50801',
#     'concept': 'Brain',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (689, 694),
#     'mention': 'brain',
#     'identifier': 'AlzheimerOntology:brain',
#     'concept': 'brain',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (722, 741),
#     'mention': 'cerebrospinal fluid',
#     'identifier': 'AlzheimerOntology:cerebrospinal_fluid',
#     'concept': 'cerebrospinal fluid',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (743, 746),
#     'mention': 'CSF',
#     'identifier': 'AlzheimerOntology:Cerebospinal_Fluid',
#     'concept': 'protein circulating in Cerebospinal Fluid',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (743, 746),
#     'mention': 'CSF',
#     'identifier': 'AlzheimerOntology:Cerebospinal_fluid_test',
#     'concept': 'Cerebospinal fluid test',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (743, 746),
#     'mention': 'CSF',
#     'identifier': 'AlzheimerOntology:cerebrospinal_fluid',
#     'concept': 'cerebrospinal fluid',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (743, 746),
#     'mention': 'CSF',
#     'identifier': 'AlzheimerOntology:macrophage_colony_stimulating_factor',
#     'concept': 'macrophage colony stimulating factor',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (767, 769),
#     'mention': 'AD',
#     'identifier': 'AlzheimerOntology:Subtypes',
#     'concept': 'Alzheimer disease',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (835, 840),
#     'mention': 'assay',
#     'identifier': 'obo:OBI_0000070',
#     'concept': 'assay',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (868, 876),
#     'mention': 'filament',
#     'identifier': 'AlzheimerOntology:Filaments',
#     'concept': 'Filament',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (877, 882),
#     'mention': 'cores',
#     'identifier': 'obo:IAO_0000224',
#     'concept': 'core',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (886, 911),
#     'mention': 'corticobasal degeneration',
#     'identifier': 'obo:ND_0000169',
#     'concept': 'corticobasal degeneration',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (929, 936),
#     'mention': 'disease',
#     'identifier': 'obo:OGMS_0000031',
#     'concept': 'disease',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (929, 936),
#     'mention': 'disease',
#     'identifier': 'NDDUO:disease',
#     'concept': 'disease',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (967, 976),
#     'mention': 'filaments',
#     'identifier': 'AlzheimerOntology:Filaments',
#     'concept': 'Filament',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (1023, 1031),
#     'mention': 'document',
#     'identifier': 'obo:IAO_0000310',
#     'concept': 'document',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (1047, 1055),
#     'mention': 'modeling',
#     'identifier': 'obo:NBO_0000215',
#     'concept': 'observational learning',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (1047, 1055),
#     'mention': 'modeling',
#     'identifier': 'NDDUO:model',
#     'concept': 'model',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (1056, 1059),
#     'mention': 'tau',
#     'identifier': 'AlzheimerOntology:t_tau',
#     'concept': 't-tau',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (1060, 1071),
#     'mention': 'aggregation',
#     'identifier': 'NDDUO:Cluster',
#     'concept': 'Cluster',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (1135, 1138),
#     'mention': 'tau',
#     'identifier': 'AlzheimerOntology:t_tau',
#     'concept': 't-tau',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (1156, 1165),
#     'mention': 'biomarker',
#     'identifier': 'AlzheimerOntology:procedures_using_biomarkers',
#     'concept': 'thing related to procedure using biomarkers',
#     'type': '',
#     'annotator': 'NIO'},
#    {'span': (1156, 1165),
#     'mention': 'biomarker',
#     'identifier': 'NDDUO:biomarker',
#     'concept': 'biomarker',
#     'type': '',
#     'annotator': 'NIO'}]}]

# %%
def write_to_json(path, doc, span_raw):
    """write the annotations to the json format
    inputs:
        path: the path to the output json file
        doc: the file to be written to the json format
        span_raw: the file name of the raw text spans
    output: a json file written in the output path
    """
    options = jsbeautifier.default_options()
    options.indent_size = 8
    
    sorted_doc = sorted(doc, key=lambda d: d['title']) 
    json_object = jsbeautifier.beautify(json.dumps(sorted_doc), options)

    with open(path+span_raw.split(".")[0]+'.json', 'w') as fp:
        fp.write(json_object)

# %%
result_path = "/Users/yidesdo21/Projects/outputs/10_ptc_ten_recent/json/"

# %%
write_to_json(result_path, docs_text, output_file)

# %%
# options = jsbeautifier.default_options()
# options.indent_size = 8

# %%
# # export docs_text to json: either 1) write a json object outside of the with open... by using json.dumps
# #                       or 2) use with open ... and write json.dump within the with open
# # docs_text has article, mentioned entity, mentioned id, canonical, and entity text span
# # result_path = "/Users/yidesdo21/Projects/outputs/03_annotation_with_articles/json_with_entity/"
# result_path = "/Users/yidesdo21/Projects/outputs/10_ptc_ten_recent/json/"
# json_object = jsbeautifier.beautify(json.dumps(docs_text), options)

# with open(result_path+output_file.split(".")[0]+'.json', 'w') as fp:
#     fp.write(json_object)

# %%
output_file
# Out:
# 'nio_ten_recent_spans_nested_case.txt'

# %% [markdown]
# ### Results from the NIO annotator

# %%
# need to use docs, rather than docs_text 
displacy.render(docs, style="ent", manual=True, options={"colors":{}})
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">NLM_31721178</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tau
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem"></span>
# </mark>
#  (297-391) forms
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     filaments
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem"></span>
# </mark>
#  that structurally mimic the
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     core
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem"></span>
# </mark>
#  of paired helical
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     filaments
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem"></span>
# </mark>
#  in
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Alzheimer's disease
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem"></span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     brain
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem"></span>
# </mark>
# .The constituent paired helical
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     filaments
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem"></span>
# </mark>
#  (PHFs) in
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     neurofibrillary tangles
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem"></span>
# </mark>
#  are insoluble intracellular deposits central to the development of
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Alzheimer's disease
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem"></span>
# </mark>
#  (
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AD
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem"></span>
# </mark>
# ) and
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     other
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem"></span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     tauopathies
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem"></span>
# </mark>
# . Full-length
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     tau
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem"></span>
# </mark>
#  requires the addition of anionic cofactors such as heparin to enhance assembly. We have shown that a fragment from the proteolytically stable
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     core
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem"></span>
# </mark>
#  of the PHF,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     tau
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem"></span>
# </mark>
#  297-391 known as 'dGAE', spontaneously forms cross-β-containing PHFs and straight
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     filaments
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem"></span>
# </mark>
#  under physiological conditions. Here, we have analysed and compared the structures of the
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     filaments
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem"></span>
# </mark>
#  formed by dGAE in vitro with those deposited in the
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     brains
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem"></span>
# </mark>
#  of individuals diagnosed with
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AD
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem"></span>
# </mark>
# . We show that dGAE forms PHFs that share a macromolecular structure similar to those found in
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     brain tissue
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem"></span>
# </mark>
# . Thus, dGAEs may serve as a
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     model
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem"></span>
# </mark>
#  system for
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     studying
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem"></span>
# </mark>
#
# <m

# %% [markdown]
# ### The second part for the PTC annotations
# - visusalize the PTC annotations removing the nested annotations in disPlacy
# - output the full PTC annotations (including the nested ones) in the json format

# %%
# goal: visualize the text span with the annotations by using spaCy visualizer
# create the list of dictionaries as the input for spaCy visualizer
# ex = [{"text": "But Google is starting from behind.",
#        "ents": [{"start": 4, "end": 10, "label": "ORG"}],
#        "title": "Test"}]
# html = displacy.render(ex, style="ent", manual=True, options={"colors":{"ORG":"yellow"}})

# %%
# ptc annotations: 
# 34060233|t|[Title]
# 34060233|a|[Abstract]
# 34060233	4	8	BIN1	Gene	274
# 34060233	9	17	rs744373	SNP	rs744373

# %%
ptc_path = "/Users/yidesdo21/Projects/ptc/Code.Python/output/"
ptc_file = "ten_recent.PubTator"

# %%
with open(ptc_path+ptc_file) as f:
    ptc_output = f.read().splitlines()

# %%
ptc_outputs = list()  # turn one abstract into one list 
ptc_abs = list()

for i in range(len(ptc_output)):
    line = ptc_output[i]
    ptc_abs.append(line)
    
    if len(line) == 0:    # start another article
        ptc_outputs.append(ptc_abs)
        ptc_abs = list()

ptc_outputs = ptc_outputs[:-1]   # the last element is empty

# %% [markdown]
# #### create a map to link the identifiers to the ontological concepts —
# - genes/proteins → NCBI Gene identifiers,
# - Genetic variants → dbSNP RS identifiers,
# - Species → NCBI taxonomy identifiers,
# - Disease → MeSH identifiers, Chemicals → MeSH identifiers,
# - cell lines → Cellosaurus

# %%
# titles

# %%
# ptc_output

# %%
ptc_docs = list()
ptc_docs_text = list()  # for the json
ptc_cnt = len(ptc_outputs)

for i in range(ptc_cnt):   # iterate over each abstract 
    one_abs = ptc_outputs[i]
    abs_dict = dict()
    abs_dict_text = dict()  # for the json
    text = ""
    ents = list()
    ents_text = list()  # for the json
    
    
    for line in one_abs:   # iterate over each line in the abstract
        line_split = line.split("|")
        if len(line_split) > 1:  # either the title line or the abstract line
            abs_dict["title"] = titles.get(line_split[0])
            abs_dict_text["title"] = titles.get(line_split[0])
            
#             print((line_split[0]))
            
            if line_split[1] == "t":
                text += line_split[2]
            elif line_split[1] == "a":
                text += "."  # can't add a space because of the PTC annotations, the slicing will be wrong
                text += line_split[2]
                abs_dict["text"] = text
                abs_dict_text["text"] = text
    
        span_split = line.split("\t")
        ent = dict()
        ent_text = dict()   # for the json
        
        if len(span_split) > 1:  # the text span lines 
            start, end, label = span_split[1], span_split[2], span_split[3]
            ent["start"] = int(start)
            ent["end"] = int(end)
            ent["label"] = span_split[4]  # for illustrations
#             ent["label"] = label
            ents.append(ent)
    
            ent_text["span"] = int(start), int(end)
            ent_text["mention"] = label

#             print(span_split)
            
            if len(span_split) > 5:
                ent_text["identifier"] = span_split[5]    # the mention after grounding: ontological identifier
            else:
                ent_text["identifier"] = "none"
                
            ent_text["concept"] = ""         # not included in the PTC output, have to link to the ontologies
            ent_text["type"] = span_split[4]
            ent_text["annotator"] = "PTC"
            ents_text.append(ent_text)  
    
        if len(line) == 0:  # end of this abstract
            abs_dict["ents"] = ents
            ptc_docs.append(abs_dict)
            abs_dict_text["ents"] = ents_text
            ptc_docs_text.append(abs_dict_text)

# %%
len(ptc_docs_text)
# Out:
# 10

# %%
ptc_docs_text
# Out:
# [{'title': 'NLM_34060233',
#   'text': "The BIN1 rs744373 Alzheimer's disease risk SNP is associated with faster Aβ-associated tau accumulation and cognitive decline.INTRODUCTION: The BIN1 rs744373 single nucleotide polymorphism (SNP) is a key genetic risk locus for Alzheimer's disease (AD) associated with tau pathology. Because tau typically accumulates in response to amyloid beta (Aβ), we tested whether BIN1 rs744373 accelerates Aβ-related tau accumulation. METHODS: We included two samples (Alzheimer's Disease Neuroimaging Initiative [ADNI], n\xa0=\xa0153; Biomarkers for Identifying Neurodegenerative Disorders Early and Reliably [BioFINDER], n\xa0=\xa063) with longitudinal (18) F-Flortaucipir positron emission tomography (PET), Aβ biomarkers, and longitudinal cognitive assessments. We assessed whether BIN1 rs744373 was associated with faster tau-PET accumulation at a given level of Aβ and whether faster BIN1 rs744373-associated tau-PET accumulation mediated cognitive decline. RESULTS: BIN1 rs744373 risk-allele carriers showed faster global tau-PET accumulation (ADNI/BioFINDER, P\xa0<\xa0.001/P\xa0<\xa0.001). We found significant Aβ by rs744373 interactions on global tau-PET change (ADNI: β/standard error [SE]\xa0=\xa00.42/0.14, P\xa0=\xa00.002; BioFINDER: β/SE\xa0=\xa0-0.35/0.15, P\xa0=\xa0.021), BIN1 risk-allele carriers showed accelerated tau-PET accumulation at higher Aβ levels. In ADNI, rs744373 effects on cognitive decline were mediated by faster global tau-PET accumulation (β/SE\xa0=\xa00.20/0.07, P\xa0=\xa0.005). DISCUSSION: BIN1-associated AD risk is potentially driven by accelerated tau accumulation in the face of Aβ.",
#   'ents': [{'span': (4, 8),
#     'mention': 'BIN1',
#     'identifier': '274',
#     'concept': '',
#     'type': 'Gene',
#     'annotator': 'PTC'},
#    {'span': (9, 17),
#     'mention': 'rs744373',
#     'identifier': 'rs744373',
#     'concept': '',
#     'type': 'SNP',
#     'annotator': 'PTC'},
#    {'span': (18, 37),
#     'mention': "Alzheimer's disease",
#     'identifier': 'MESH:D000544',
#     'concept': '',
#     'type': 'Disease',
#     'annotator': 'PTC'},
#    {'span': (43, 46),
#     'mention': 'SNP',
#     'identifier': 'none',
#     'concept': '',
#     'type': 'Disease',
#     'annotator': 'PTC'},
#    {'span': (144, 148),
#     'mention': 'BIN1',
#     'identifier': '274',
#     'concept': '',
#     'type': 'Gene',
#     'annotator': 'PTC'},
#    {'span': (149, 157),
#     'mention': 'rs744373',
#     'identifier': 'rs744373',
#     'concept': '',
#     'type': 'SNP',
#     'annotator': 'PTC'},
#    {'span': (190, 193),
#     'mention': 'SNP',
#     'identifier': 'none',
#     'concept': '',
#     'type': 'Disease',
#     'annotator': 'PTC'},
#    {'span': (227, 246),
#     'mention': "Alzheimer's disease",
#     'identifier': 'MESH:D000544',
#     'concept': '',
#     'type': 'Disease',
#     'annotator': 'PTC'},
#    {'span': (248, 250),
#     'mention': 'AD',
#     'identifier': 'MESH:D000544',
#     'concept': '',
#     'type': 'Disease',
#     'annotator': 'PTC'},
#    {'span': (332, 339),
#     'mention': 'amyloid',
#     'identifier': 'MESH:D016229',
#     'concept': '',
#     'type': 'Chemical',
#     'annotator': 'PTC'},
#    {'span': (369, 373),
#     'mention': 'BIN1',
#     'identifier': '274',
#     'concept': '',
#     'type': 'Gene',
#     'annotator': 'PTC'},
#    {'span': (374, 382),
#     'mention': 'rs744373',
#     'identifier': 'rs744373',
#     'concept': '',
#     'type': 'SNP',
#     'annotator': 'PTC'},
#    {'span': (546, 573),
#     'mention': 'Neurodegenerative Disorders',
#     'identifier': 'MESH:D019636',
#     'concept': '',
#     'type': 'Disease',
#     'annotator': 'PTC'},
#    {'span': (619, 631),
#     'mention': 'longitudinal',
#     'identifier': 'MESH:D017887',
#     'concept': '',
#     'type': 'Disease',
#     'annotator': 'PTC'},
#    {'span': (637, 660),
#     'mention': 'F-Flortaucipir positron',
#     'identifier': 'MESH:D005461',
#     'concept': '',
#     'type': 'Chemical',
#     'annotator': 'PTC'},
#    {'span': (707, 729),
#     'mention': 'longitudinal cognitive',
#     'identifier': 'MESH:D003072',
#     'concept': '',
#     'type': 'Disease',
#     'annotator': 'PTC'},
#    {'span': (763, 767),
#     'mention': 'BIN1',
#     'identifier': '274',
#     'concept': '',
#     'type': 'Gene',
#     'annotator': 'PTC'},
#    {'span': (768, 776),
#     'mention': 'rs744373',
#     'identifier': 'rs744373',
#     'concept': '',
#     'type': 'SNP',
#     'annotator': 'PTC'},
#    {'span': (867, 871),
#     'mention': 'BIN1',
#     'identifier': '274',
#     'concept': '',
#     'type': 'Gene',
#     'annotator': 'PTC'},
#    {'span': (872, 880),
#     'mention': 'rs744373',
#     'identifier': 'rs744373',
#     'concept': '',
#     'type': 'SNP',
#     'annotator': 'PTC'},
#    {'span': (950, 954),
#     'mention': 'BIN1',
#     'identifier': '274',
#     'concept': '',
#     'type': 'Gene',
#     'annotator': 'PTC'},
#    {'span': (955, 963),
#     'mention': 'rs744373',
#     'identifier': 'rs744373',
#     'concept': '',
#     'type': 'SNP',
#     'annotator': 'PTC'},
#    {'span': (1091, 1099),
#     'mention': 'rs744373',
#     'identifier': 'rs744373',
#     'concept': '',
#     'type': 'SNP',
#     'annotator': 'PTC'},
#    {'span': (1232, 1236),
#     'mention': 'BIN1',
#     'identifier': '274',
#     'concept': '',
#     'type': 'Gene',
#     'annotator': 'PTC'},
#    {'span': (1328, 1336),
#     'mention': 'rs744373',
#     'identifier': 'rs744373',
#     'concept': '',
#     'type': 'SNP',
#     'annotator': 'PTC'},
#    {'span': (1460, 1464),
#     'mention': 'BIN1',
#     'identifier': '274',
#     'concept': '',
#     'type': 'Gene',
#     'annotator': 'PTC'},
#    {'span': (1476, 1478),
#     'mention': 'AD',
#     'identifier': 'MESH:D000544',
#     'concept': '',
#     'type': 'Disease',
#     'annotator': 'PTC'}]},
#  {'title': 'NLM_34095440',
#   'text': "Alzheimer's disease drug development pipeline: 2021.INTRODUCTION: The number of individuals worldwide with Alzheimer's disease (AD) is growing at a rapid rate. New treatments are urgently needed. We review the current pipeline of drugs in clinical trials for the treatment of AD. METHODS: We interrogated ClinicalTrials.gov, the federal registry of clinical trials to identify drugs in trials. RESULTS: There are 126 agents in 152 trials assessing new therapies for AD: 28 treatments in Phase 3 trials, 74 in Phase 2, and 24 in Phase 1. The majority of drugs in trials (82.5%) target the underlying biology of AD with the intent of disease modification; 10.3% are putative cognitive enhancing agents; and 7.1% are drugs being developed to reduce neuropsychiatric symptoms. DISCUSSION: This pipeline analysis shows that target biological processes are more diversified, biomarkers are more regularly used, and repurposed agents are being explored to determine their utility for the treatment of AD.",
#   'ents': [{'span': (0, 19),
#     'mention': "Alzheimer's disease",
#     'identifier': 'MESH:D000544',
#     'concept': '',
#     'type': 'Disease',
#     'annotator': 'PTC'},
#    {'span': (107, 126),
#     'mention': "Alzheimer's disease",
#     'identifier': 'MESH:D000544',
#     'concept': '',
#     'type': 'Disease',
#     'annotator': 'PTC'},
#    {'span': (128, 130),
#     'mention': 'AD',
#     'identifier': 'MESH:D000544',
#     'concept': '',
#     'type': 'Disease',
#     'annotator': 'PTC'},
#    {'span': (276, 278),
#     'mention': 'AD',
#     'identifier': 'MESH:D000544',
#     'concept': '',
#     'type': 'Disease',
#     'annotator': 'PTC'},
#    {'span': (466, 468),
#     'mention': 'AD',
#     'identifier': 'MESH:D000544',
#     'concept': '',
#     'type': 'Disease',
#     'annotator': 'PTC'},
#    {'span': (610, 612),
#     'mention': 'AD',
#     'identifier': 'MESH:D000544',
#     'concept': '',
#     'type': 'Disease',
#     'annotator': 'PTC'},
#    {'span': (994, 996),
#     'mention': 'AD',
#     'identifier': 'MESH:D000544',
#     'concept': '',
#     'type': 'Disease',
#     'annotator': 'PTC'}]},
#  {'title': 'NLM_34101788',
#   'text': "Platform Trials to Expedite Drug Development in Alzheimer's Disease: A Report from the EU/US CTAD Task Force.A diverse range of platforms has been established to increase the efficiency and speed of clinical trials for Alzheimer's disease (AD). These platforms enable parallel assessment of multiple therapeutics, treatment regimens, or participant groups; use uniform protocols and outcome measures; and may allow treatment arms to be added or dropped based on interim analyses of outcomes. The EU/US CTAD Task Force discussed the lessons learned from the Dominantly Inherited Alzheimer's Network Trials Unit (DIAN-TU) platform trial and the challenges addressed by other platform trials that have launched or are in the planning stages. The landscape of clinical trial platforms in the AD space includes those testing experimental therapies such as DIAN-TU, platforms designed to test multidomain interventions, and those designed to streamline trial recruitment by building trial-ready cohorts. The heterogeneity of the AD patient population, AD drugs, treatment regimens, and analytical methods complicates the design and execution of platform trials, yet Task Force members concluded that platform trials are essential to advance the search for effective AD treatments, including combination therapies.",
#   'ents': [{'span': (219, 238),
#     'mention': "Alzheimer's disease",
#     'identifier': 'MESH:D000544',
#     'concept': '',
#     'type': 'Disease',
#     'annotator': 'PTC'},
#    {'span': (240, 242),
#     'mention': 'AD',
#     'identifier': 'MESH:D000544',
#     'concept': '',
#     'type': 'Disease',
#     'annotator': 'PTC'},
#    {'span': (337, 348),
#     'mention': 'participant',
#     'identifier': '9606',
#     'concept': '',
#     'type': 'Species',
#     'annotator': 'PTC'},
#    {'span': (578, 587),
#     'mention': 'Alzheimer',
#     'identifier': 'MESH:D000544',
#     'concept': '',
#     'type': 'Disease',
#     'annotator': 'PTC'},
#    {'span': (611, 618),
#     'mention': 'DIAN-TU',
#     'identifier': 'MESH:C559645',
#     'concept': '',
#     'type': 'Chemical',
#     'annotator': 'PTC'},
#    {'span': (788, 790),
#     'mention': 'AD',
#     'identifier': 'MESH:D000544',
#     'concept': '',
#     'type': 'Disease',
#     'annotator': 'PTC'},
#    {'span': (851, 858),
#     'mention': 'DIAN-TU',
#     'identifier': 'MESH:C559645',
#     'concept': '',
#     'type': 'Chemical',
#     'annotator': 'PTC'},
#    {'span': (1023, 1025),
#     'mention': 'AD',
#     'identifier': 'MESH:D000544',
#     'concept': '',
#     'type': 'Disease',
#     'annotator': 'PTC'},
#    {'span': (1026, 1033),
#     'mention': 'patient',
#     'identifier': '9606',
#     'concept': '',
#     'type': 'Species',
#     'annotator': 'PTC'},
#    {'span': (1046, 1048),
#     'mention': 'AD',
#     'identifier': 'MESH:D000544',
#     'concept': '',
#     'type': 'Disease',
#     'annotator': 'PTC'},
#    {'span': (1260, 1262),
#     'mention': 'AD',
#     'identifier': 'MESH:D000544',
#     'concept': '',
#     'type': 'Disease',
#     'annotator': 'PTC'}]},
#  {'title': 'NLM_33730588',
#   'text': "The AD tau core spontaneously self-assembles and recruits full-length tau to filaments.Tau accumulation is a major pathological hallmark of Alzheimer's disease (AD) and other tauopathies, but the mechanism(s) of tau aggregation remains unclear. Taking advantage of the identification of tau filament cores by cryoelectron microscopy, we demonstrate that the AD tau core possesses the intrinsic ability to spontaneously aggregate in the absence of an inducer, with antibodies generated against AD tau core filaments detecting AD tau pathology. The AD tau core also drives aggregation of full-length wild-type tau, increases seeding potential, and templates abnormal forms of tau present in brain homogenates and antemortem cerebrospinal fluid (CSF) from patients with AD in an ultrasensitive real-time quaking-induced conversion (QuIC) assay. Finally, we show that the filament cores in corticobasal degeneration (CBD) and Pick's disease (PiD) similarly assemble into filaments under physiological conditions. These results document an approach to modeling tau aggregation and have significant implications for in\xa0vivo investigation of tau transmission and biomarker development.",
#   'ents': [{'span': (128, 159),
#     'mention': "hallmark of Alzheimer's disease",
#     'identifier': 'MESH:D000544',
#     'concept': '',
#     'type': 'Disease',
#     'annotator': 'PTC'},
#    {'span': (175, 186),
#     'mention': 'tauopathies',
#     'identifier': 'MESH:D024801',
#     'concept': '',
#     'type': 'Disease',
#     'annotator': 'PTC'},
#    {'span': (212, 227),
#     'mention': 'tau aggregation',
#     'identifier': 'MESH:C536599',
#     'concept': '',
#     'type': 'Disease',
#     'annotator': 'PTC'},
#    {'span': (753, 761),
#     'mention': 'patients',
#     'identifier': '9606',
#     'concept': '',
#     'type': 'Species',
#     'annotator': 'PTC'},
#    {'span': (922, 936),
#     'mention': "Pick's disease",
#     'identifier': 'MESH:D020774',
#     'concept': '',
#     'type': 'Disease',
#     'annotator': 'PTC'},
#    {'span': (1056, 1071),
#     'mention': 'tau aggregation',
#     'identifier': 'MESH:C536599',
#     'concept': '',
#     'type': 'Disease',
#     'annotator': 'PTC'}]},
#  {'title': 'NLM_33988687',
#   'text': "Alzheimer mutant speeds APP transport.APPS198P segregates with rare familial forms of Alzheimer's disease and resides within exon 5, unlike 27 other mutations that reside in exons 16 or 17. In this issue, Zhang et al. (2021. J. Exp. Med.https://doi.org/10.1084/jem.20210313) show that the brains of APPS198P transgenic mice accumulate excess levels of Aβ. In cultured cells, APPS198P undergoes accelerated ER folding, leading to early arrival in late vesicular compartments, thereby enhancing generation of Aβ.",
#   'ents': [{'span': (0, 9),
#     'mention': 'Alzheimer',
#     'identifier': 'MESH:D000544',
#     'concept': '',
#     'type': 'Disease',
#     'annotator': 'PTC'},
#    {'span': (86, 105),
#     'mention': "Alzheimer's disease",
#     'identifier': 'MESH:D000544',
#     'concept': '',
#     'type': 'Disease',
#     'annotator': 'PTC'},
#    {'span': (308, 323),
#     'mention': 'transgenic mice',
#     'identifier': '10090',
#     'concept': '',
#     'type': 'Species',
#     'annotator': 'PTC'}]},
#  {'title': 'NLM_33958804',
#   'text': "Neuronal ApoE upregulates MHC-I expression to drive selective neurodegeneration in Alzheimer's disease.Selective neurodegeneration is a critical causal factor in Alzheimer's disease (AD); however, the mechanisms that lead some neurons to perish, whereas others remain resilient, are unknown. We sought potential drivers of this selective vulnerability using single-nucleus RNA sequencing and discovered that ApoE expression level is a substantial driver of neuronal variability. Strikingly, neuronal expression of ApoE-which has a robust genetic linkage to AD-correlated strongly, on a cell-by-cell basis, with immune response pathways in neurons in the brains of wild-type mice, human ApoE knock-in mice and humans with or without AD. Elimination or over-expression of neuronal ApoE revealed a causal relationship among ApoE expression, neuronal MHC-I expression, tau pathology and neurodegeneration. Functional reduction of MHC-I ameliorated tau pathology in ApoE4-expressing primary neurons and in mouse hippocampi expressing pathological tau. These findings suggest a mechanism linking neuronal ApoE expression to MHC-I expression and, subsequently, to tau pathology and selective neurodegeneration.",
#   'ents': [{'span': (9, 13),
#     'mention': 'ApoE',
#     'identifier': '11816',
#     'concept': '',
#     'type': 'Gene',
#     'annotator': 'PTC'},
#    {'span': (62, 79),
#     'mention': 'neurodegeneration',
#     'identifier': 'MESH:D019636',
#     'concept': '',
#     'type': 'Disease',
#     'annotator': 'PTC'},
#    {'span': (83, 102),
#     'mention': "Alzheimer's disease",
#     'identifier': 'MESH:D000544',
#     'concept': '',
#     'type': 'Disease',
#     'annotator': 'PTC'},
#    {'span': (113, 130),
#     'mention': 'neurodegeneration',
#     'identifier': 'MESH:D019636',
#     'concept': '',
#     'type': 'Disease',
#     'annotator': 'PTC'},
#    {'span': (162, 181),
#     'mention': "Alzheimer's disease",
#     'identifier': 'MESH:D000544',
#     'concept': '',
#     'type': 'Disease',
#     'annotator': 'PTC'},
#    {'span': (183, 185),
#     'mention': 'AD',
#     'identifier': 'MESH:D000544',
#     'concept': '',
#     'type': 'Disease',
#     'annotator': 'PTC'},
#    {'span': (408, 412),
#     'mention': 'ApoE',
#     'identifier': '11816',
#     'concept': '',
#     'type': 'Gene',
#     'annotator': 'PTC'},
#    {'span': (514, 518),
#     'mention': 'ApoE',
#     'identifier': '11816',
#     'concept': '',
#     'type': 'Gene',
#     'annotator': 'PTC'},
#    {'span': (557, 559),
#     'mention': 'AD',
#     'identifier': 'MESH:D000544',
#     'concept': '',
#     'type': 'Disease',
#     'annotator': 'PTC'},
#    {'span': (674, 678),
#     'mention': 'mice',
#     'identifier': '10090',
#     'concept': '',
#     'type': 'Species',
#     'annotator': 'PTC'},
#    {'span': (680, 685),
#     'mention': 'human',
#     'identifier': '9606',
#     'concept': '',
#     'type': 'Species',
#     'annotator': 'PTC'},
#    {'span': (686, 690),
#     'mention': 'ApoE',
#     'identifier': '348',
#     'concept': '',
#     'type': 'Gene',
#     'annotator': 'PTC'},
#    {'span': (700, 704),
#     'mention': 'mice',
#     'identifier': '10090',
#     'concept': '',
#     'type': 'Species',
#     'annotator': 'PTC'},
#    {'span': (709, 715),
#     'mention': 'humans',
#     'identifier': '9606',
#     'concept': '',
#     'type': 'Species',
#     'annotator': 'PTC'},
#    {'span': (732, 734),
#     'mention': 'AD',
#     'identifier': 'MESH:D000544',
#     'concept': '',
#     'type': 'Disease',
#     'annotator': 'PTC'},
#    {'span': (779, 783),
#     'mention': 'ApoE',
#     'identifier': '348',
#     'concept': '',
#     'type': 'Gene',
#     'annotator': 'PTC'},
#    {'span': (821, 825),
#     'mention': 'ApoE',
#     'identifier': '348',
#     'concept': '',
#     'type': 'Gene',
#     'annotator': 'PTC'},
#    {'span': (883, 900),
#     'mention': 'neurodegeneration',
#     'identifier': 'MESH:D019636',
#     'concept': '',
#     'type': 'Disease',
#     'annotator': 'PTC'},
#    {'span': (1001, 1006),
#     'mention': 'mouse',
#     'identifier': '10090',
#     'concept': '',
#     'type': 'Species',
#     'annotator': 'PTC'},
#    {'span': (1099, 1103),
#     'mention': 'ApoE',
#     'identifier': '11816',
#     'concept': '',
#     'type': 'Gene',
#     'annotator': 'PTC'},
#    {'span': (1185, 1202),
#     'mention': 'neurodegeneration',
#     'identifier': 'MESH:D019636',
#     'concept': '',
#     'type': 'Disease',
#     'annotator': 'PTC'}]},
#  {'title': 'NLM_31721178',
#   'text': "Tau (297-391) forms filaments that structurally mimic the core of paired helical filaments in Alzheimer's disease brain.The constituent paired helical filaments (PHFs) in neurofibrillary tangles are insoluble intracellular deposits central to the development of Alzheimer's disease (AD) and other tauopathies. Full-length tau requires the addition of anionic cofactors such as heparin to enhance assembly. We have shown that a fragment from the proteolytically stable core of the PHF, tau 297-391 known as 'dGAE', spontaneously forms cross-β-containing PHFs and straight filaments under physiological conditions. Here, we have analysed and compared the structures of the filaments formed by dGAE in\xa0vitro with those deposited in the brains of individuals diagnosed with AD. We show that dGAE forms PHFs that share a macromolecular structure similar to those found in brain tissue. Thus, dGAEs may serve as a model system for studying core domain assembly and for screening for inhibitors of tau aggregation.",
#   'ents': [{'span': (94, 113),
#     'mention': "Alzheimer's disease",
#     'identifier': 'MESH:D000544',
#     'concept': '',
#     'type': 'Disease',
#     'annotator': 'PTC'},
#    {'span': (262, 281),
#     'mention': "Alzheimer's disease",
#     'identifier': 'MESH:D000544',
#     'concept': '',
#     'type': 'Disease',
#     'annotator': 'PTC'},
#    {'span': (283, 285),
#     'mention': 'AD',
#     'identifier': 'MESH:D000544',
#     'concept': '',
#     'type': 'Disease',
#     'annotator': 'PTC'},
#    {'span': (297, 308),
#     'mention': 'tauopathies',
#     'identifier': 'MESH:D024801',
#     'concept': '',
#     'type': 'Disease',
#     'annotator': 'PTC'},
#    {'span': (377, 384),
#     'mention': 'heparin',
#     'identifier': 'MESH:D006493',
#     'concept': '',
#     'type': 'Chemical',
#     'annotator': 'PTC'},
#    {'span': (770, 772),
#     'mention': 'AD',
#     'identifier': 'MESH:D000544',
#     'concept': '',
#     'type': 'Disease',
#     'annotator': 'PTC'},
#    {'span': (991, 1006),
#     'mention': 'tau aggregation',
#     'identifier': 'MESH:C536599',
#     'concept': '',
#     'type': 'Disease',
#     'annotator': 'PTC'}]},
#  {'title': 'CCC_000637925000033',
#   'text': 'Glycoengineering artificial receptors for microglia to phagocytose A beta aggregates.Oligomeric and fibrillar amyloid-beta (A beta) are principally internalized via receptor-mediated endocytosis (RME) by microglia, the main scavenger of A beta in the brain. Nevertheless, the inflammatory cascade will be evoked after vast A beta aggregate binding to pattern recognition receptors on the cell membrane, which then significantly decreases the expression of these receptors and further deteriorate A beta deposition. This vicious circle will weaken the ability of microglia for A beta elimination. Herein, a combination of metabolic glycoengineering and self-triggered click chemistry is utilized to engineer microglial membranes with ThS as artificial A beta receptors to promote microglia to phagocytose A beta aggregates. Additionally, to circumvent the undesirable immune response during the process of the bioorthogonal chemistry reaction and A beta-microglial interaction, Mn-porphyrin metal-organic frameworks (Mn-MOFs) with superoxide dismutase (SOD) and catalase (CAT) mimic activity are employed to carry N-azidoacetylmannosamine (AcManNAz) and eradicate over-expressed reactive oxygen species (ROSs). The artificial A beta receptors independent of a signal pathway involved in immunomodulation as well as Mn-MOFs with antioxidant properties can synergistically promote the phagocytosis and clearance of A beta with significantly enhanced activity and negligible adverse effects. The present study will not only provide valuable insight into the rational design of the microglial surface engineering strategy via bioorthogonal chemistry, but also hold great potential for other disease intervention associated with receptor starvation.',
#   'ents': [{'span': (67, 73),
#     'mention': 'A beta',
#     'identifier': '351',
#     'concept': '',
#     'type': 'Gene',
#     'annotator': 'PTC'},
#    {'span': (110, 122),
#     'mention': 'amyloid-beta',
#     'identifier': 'MESH:D016229',
#     'concept': '',
#     'type': 'Chemical',
#     'annotator': 'PTC'},
#    {'span': (124, 130),
#     'mention': 'A beta',
#     'identifier': '351',
#     'concept': '',
#     'type': 'Gene',
#     'annotator': 'PTC'},
#    {'span': (196, 199),
#     'mention': 'RME',
#     'identifier': 'none',
#     'concept': '',
#     'type': 'Chemical',
#     'annotator': 'PTC'},
#    {'span': (237, 243),
#     'mention': 'A beta',
#     'identifier': '351',
#     'concept': '',
#     'type': 'Gene',
#     'annotator': 'PTC'},
#    {'span': (323, 329),
#     'mention': 'A beta',
#     'identifier': '351',
#     'concept': '',
#     'type': 'Gene',
#     'annotator': 'PTC'},
#    {'span': (496, 502),
#     'mention': 'A beta',
#     'identifier': '351',
#     'concept': '',
#     'type': 'Gene',
#     'annotator': 'PTC'},
#    {'span': (576, 582),
#     'mention': 'A beta',
#     'identifier': '351',
#     'concept': '',
#     'type': 'Gene',
#     'annotator': 'PTC'},
#    {'span': (751, 757),
#     'mention': 'A beta',
#     'identifier': '351',
#     'concept': '',
#     'type': 'Gene',
#     'annotator': 'PTC'},
#    {'span': (804, 810),
#     'mention': 'A beta',
#     'identifier': '351',
#     'concept': '',
#     'type': 'Gene',
#     'annotator': 'PTC'},
#    {'span': (946, 952),
#     'mention': 'A beta',
#     'identifier': '351',
#     'concept': '',
#     'type': 'Gene',
#     'annotator': 'PTC'},
#    {'span': (977, 989),
#     'mention': 'Mn-porphyrin',
#     'identifier': 'MESH:D008345',
#     'concept': '',
#     'type': 'Chemical',
#     'annotator': 'PTC'},
#    {'span': (1016, 1023),
#     'mention': 'Mn-MOFs',
#     'identifier': 'MESH:D008345',
#     'concept': '',
#     'type': 'Chemical',
#     'annotator': 'PTC'},
#    {'span': (1030, 1050),
#     'mention': 'superoxide dismutase',
#     'identifier': '6647',
#     'concept': '',
#     'type': 'Gene',
#     'annotator': 'PTC'},
#    {'span': (1052, 1055),
#     'mention': 'SOD',
#     'identifier': '6647',
#     'concept': '',
#     'type': 'Gene',
#     'annotator': 'PTC'},
#    {'span': (1061, 1069),
#     'mention': 'catalase',
#     'identifier': '847',
#     'concept': '',
#     'type': 'Gene',
#     'annotator': 'PTC'},
#    {'span': (1071, 1074),
#     'mention': 'CAT',
#     'identifier': '847',
#     'concept': '',
#     'type': 'Gene',
#     'annotator': 'PTC'},
#    {'span': (1113, 1137),
#     'mention': 'N-azidoacetylmannosamine',
#     'identifier': 'MESH:C405953',
#     'concept': '',
#     'type': 'Chemical',
#     'annotator': 'PTC'},
#    {'span': (1187, 1193),
#     'mention': 'oxygen',
#     'identifier': 'MESH:D010100',
#     'concept': '',
#     'type': 'Chemical',
#     'annotator': 'PTC'},
#    {'span': (1225, 1231),
#     'mention': 'A beta',
#     'identifier': '351',
#     'concept': '',
#     'type': 'Gene',
#     'annotator': 'PTC'},
#    {'span': (1412, 1418),
#     'mention': 'A beta',
#     'identifier': '351',
#     'concept': '',
#     'type': 'Gene',
#     'annotator': 'PTC'}]},
#  {'title': 'CCC_000647663200001',
#   'text': 'Impairment of visual cortical plasticity by amyloid-beta species.Introduction: A variety of transgenic and knock-in mice that express mutant alleles of Amyloid precursor protein (APP) have been used to model the effects of amyloid-beta (A?) on circuit function in Alzheimer?s disease (AD); however phenotypes described in these mice may be affected by expression of mutant APP or proteolytic cleavage products independent of A?. In addition, the effects of mutant APP expression are attributed to elevated expression of the amyloidogenic, 42-amino acid-long species of A? (A?42) associated with amyloid plaque accumulation in AD, though elevated concentrations of A?40, an A? species produced with normal synaptic activity, may also affect neural function. Methods: To explore the effects of elevated expression of A? on synaptic function in vivo, we assessed visual system plasticity in transgenic mice that express and secrete A? throughout the brain in the absence of APP overexpression. Transgenic mice that express either A?40 or A?42 were assayed for their ability to appropriately demonstrate ocular dominance plasticity following monocular deprivation. Results: Using two complementary approaches to measure the plastic response to monocular deprivation, we find that male and female mice that express either 40- or 42-amino acid?long A? species demonstrate a plasticity defect comparable to that elicited in transgenic mice that express mutant alleles of APP and Presenilin 1 (APP/PS1 mice). Conclusions: These data support the hypothesis that mutant APP-driven plasticity impairment in mouse models of AD is mediated by production and accumulation of A?. Moreover, these findings suggest that soluble species of A? are capable of modulating synaptic plasticity, likely independent of any aggregation. These findings may have implications for the role of soluble species of A? in both development and disease settings.',
#   'ents': [{'span': (0, 40),
#     'mention': 'Impairment of visual cortical plasticity',
#     'identifier': 'MESH:D014786',
#     'concept': '',
#     'type': 'Disease',
#     'annotator': 'PTC'},
#    {'span': (44, 51),
#     'mention': 'amyloid',
#     'identifier': 'MESH:D016229',
#     'concept': '',
#     'type': 'Chemical',
#     'annotator': 'PTC'},
#    {'span': (116, 120),
#     'mention': 'mice',
#     'identifier': '10090',
#     'concept': '',
#     'type': 'Species',
#     'annotator': 'PTC'},
#    {'span': (152, 177),
#     'mention': 'Amyloid precursor protein',
#     'identifier': '11820',
#     'concept': '',
#     'type': 'Gene',
#     'annotator': 'PTC'},
#    {'span': (223, 235),
#     'mention': 'amyloid-beta',
#     'identifier': 'MESH:D016229',
#     'concept': '',
#     'type': 'Chemical',
#     'annotator': 'PTC'},
#    {'span': (264, 273),
#     'mention': 'Alzheimer',
#     'identifier': 'MESH:D000544',
#     'concept': '',
#     'type': 'Disease',
#     'annotator': 'PTC'},
#    {'span': (274, 283),
#     'mention': 's disease',
#     'identifier': 'MESH:D010300',
#     'concept': '',
#     'type': 'Disease',
#     'annotator': 'PTC'},
#    {'span': (285, 287),
#     'mention': 'AD',
#     'identifier': 'MESH:D000544',
#     'concept': '',
#     'type': 'Disease',
#     'annotator': 'PTC'},
#    {'span': (328, 332),
#     'mention': 'mice',
#     'identifier': '10090',
#     'concept': '',
#     'type': 'Species',
#     'annotator': 'PTC'},
#    {'span': (524, 537),
#     'mention': 'amyloidogenic',
#     'identifier': 'MESH:C468911',
#     'concept': '',
#     'type': 'Chemical',
#     'annotator': 'PTC'},
#    {'span': (539, 552),
#     'mention': '42-amino acid',
#     'identifier': 'MESH:C011973',
#     'concept': '',
#     'type': 'Chemical',
#     'annotator': 'PTC'},
#    {'span': (595, 602),
#     'mention': 'amyloid',
#     'identifier': 'MESH:D016229',
#     'concept': '',
#     'type': 'Chemical',
#     'annotator': 'PTC'},
#    {'span': (626, 628),
#     'mention': 'AD',
#     'identifier': 'MESH:D000544',
#     'concept': '',
#     'type': 'Disease',
#     'annotator': 'PTC'},
#    {'span': (888, 903),
#     'mention': 'transgenic mice',
#     'identifier': '10090',
#     'concept': '',
#     'type': 'Species',
#     'annotator': 'PTC'},
#    {'span': (991, 1006),
#     'mention': 'Transgenic mice',
#     'identifier': '10090',
#     'concept': '',
#     'type': 'Species',
#     'annotator': 'PTC'},
#    {'span': (1292, 1296),
#     'mention': 'mice',
#     'identifier': '10090',
#     'concept': '',
#     'type': 'Species',
#     'annotator': 'PTC'},
#    {'span': (1324, 1337),
#     'mention': '42-amino acid',
#     'identifier': 'MESH:C011973',
#     'concept': '',
#     'type': 'Chemical',
#     'annotator': 'PTC'},
#    {'span': (1417, 1432),
#     'mention': 'transgenic mice',
#     'identifier': '10090',
#     'concept': '',
#     'type': 'Species',
#     'annotator': 'PTC'},
#    {'span': (1472, 1484),
#     'mention': 'Presenilin 1',
#     'identifier': '19164',
#     'concept': '',
#     'type': 'Gene',
#     'annotator': 'PTC'},
#    {'span': (1490, 1493),
#     'mention': 'PS1',
#     'identifier': '19164',
#     'concept': '',
#     'type': 'Gene',
#     'annotator': 'PTC'},
#    {'span': (1494, 1498),
#     'mention': 'mice',
#     'identifier': '10090',
#     'concept': '',
#     'type': 'Species',
#     'annotator': 'PTC'},
#    {'span': (1596, 1601),
#     'mention': 'mouse',
#     'identifier': '10090',
#     'concept': '',
#     'type': 'Species',
#     'annotator': 'PTC'},
#    {'span': (1612, 1614),
#     'mention': 'AD',
#     'identifier': 'MESH:D000544',
#     'concept': '',
#     'type': 'Disease',
#     'annotator': 'PTC'}]},
#  {'title': 'CCC_000653155500009',
#   'text': "An excellent electrochemical aptasensor for amyloid-beta oligomers based on a triple-helix aptamer switch via target-triggered signal transduction DNA displacement events.An excellent aptasensor for electrochemical detection of amyloid-beta oligomers (A beta Os) at trace levels was fabricated based on a triple-helix aptamer switch (THAS) via target-triggered signal transduction DNA displacement events. Specifically, a single-stranded anti-A beta O aptamer (Apt) carrying two symmetrical arm segments was first attached via Au-S binding to an Au electrode. Gold nanoparticle (GNP)-tagged signal transduction probes (GNP-STPs) were simultaneously hybridized with the two arm segments of the Apt, and a rigid THAS was formed on the Au electrode. Compared to the conventional hybrid, the number of GNPs on the Au electrode increased significantly with the THAS, effectively improving the stability of the Apt to avoid lodging. Trithiocyanuric acid (TA) was utilized to further gather the GNPs and form network-like TA/GNPs. As a result, the differential pulse voltammetry (DPV) response of GNPs was clearly enhanced. When A beta Os were present, target-triggered signal transduction DNA displacement events were carried out from THAS via the reaction of the Apt with the A beta Os, which caused the GNP-STP to dissociate from the Au electrode, and thus a significant reduction in the DPV response was observed. The assay was able to sensitively detect trace A beta Os by monitoring the A beta O-controlled DPV response change. It exhibited a wide linear range from 1 fM to 10 pM with a low detection limit of 0.5 fM, and was successfully employed for the determination of A beta Os in 20 serum samples, with good recovery. Moreover, the developed assay can provide a sensitive and selective platform for many studies or investigations related to Alzheimer's disease (AD) monitoring and treatment.",
#   'ents': [{'span': (44, 51),
#     'mention': 'amyloid',
#     'identifier': 'MESH:D016229',
#     'concept': '',
#     'type': 'Chemical',
#     'annotator': 'PTC'},
#    {'span': (228, 235),
#     'mention': 'amyloid',
#     'identifier': 'MESH:D016229',
#     'concept': '',
#     'type': 'Chemical',
#     'annotator': 'PTC'},
#    {'span': (927, 947),
#     'mention': 'Trithiocyanuric acid',
#     'identifier': 'MESH:C039408',
#     'concept': '',
#     'type': 'Chemical',
#     'annotator': 'PTC'},
#    {'span': (949, 951),
#     'mention': 'TA',
#     'identifier': 'MESH:C011126',
#     'concept': '',
#     'type': 'Chemical',
#     'annotator': 'PTC'},
#    {'span': (1015, 1017),
#     'mention': 'TA',
#     'identifier': 'MESH:C011126',
#     'concept': '',
#     'type': 'Chemical',
#     'annotator': 'PTC'},
#    {'span': (1122, 1128),
#     'mention': 'A beta',
#     'identifier': '351',
#     'concept': '',
#     'type': 'Gene',
#     'annotator': 'PTC'},
#    {'span': (1271, 1277),
#     'mention': 'A beta',
#     'identifier': '351',
#     'concept': '',
#     'type': 'Gene',
#     'annotator': 'PTC'},
#    {'span': (1458, 1464),
#     'mention': 'A beta',
#     'identifier': '351',
#     'concept': '',
#     'type': 'Gene',
#     'annotator': 'PTC'},
#    {'span': (1486, 1492),
#     'mention': 'A beta',
#     'identifier': '351',
#     'concept': '',
#     'type': 'Gene',
#     'annotator': 'PTC'},
#    {'span': (1672, 1678),
#     'mention': 'A beta',
#     'identifier': '351',
#     'concept': '',
#     'type': 'Gene',
#     'annotator': 'PTC'},
#    {'span': (1846, 1865),
#     'mention': "Alzheimer's disease",
#     'identifier': 'MESH:D000544',
#     'concept': '',
#     'type': 'Disease',
#     'annotator': 'PTC'},
#    {'span': (1867, 1869),
#     'mention': 'AD',
#     'identifier': 'MESH:D000544',
#     'concept': '',
#     'type': 'Disease',
#     'annotator': 'PTC'}]}]

# %%
len(ptc_docs)
# Out:
# 10

# %%
write_to_json(result_path, ptc_docs_text, output_file.replace("nio","ptc"))

# %%
output_file.replace("nio","ptc")
# Out:
# 'ptc_ten_recent_spans_nested_case.txt'

# %%
displacy.render(ptc_docs, style="ent", manual=True, 
                options={"colors":{"GENE":"aqua", "DISEASE":"pink", "CHEMICAL":"violet",
                                   "SNP":"moccasin", "SPECIES":"lightgreen"}})
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">NLM_34060233</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">The
# <mark class="entity" style="background: aqua; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     BIN1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">Gene</span>
# </mark>
#
# <mark class="entity" style="background: moccasin; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     rs744373
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">SNP</span>
# </mark>
#
# <mark class="entity" style="background: pink; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Alzheimer's disease
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">Disease</span>
# </mark>
#  risk
# <mark class="entity" style="background: pink; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     SNP
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">Disease</span>
# </mark>
#  is associated with faster Aβ-associated tau accumulation and cognitive decline.INTRODUCTION: The
# <mark class="entity" style="background: aqua; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     BIN1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">Gene</span>
# </mark>
#
# <mark class="entity" style="background: moccasin; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     rs744373
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">SNP</span>
# </mark>
#  single nucleotide polymorphism (
# <mark class="entity" style="background: pink; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     SNP
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">Disease</span>
# </mark>
# ) is a key genetic risk locus for
# <mark class="entity" style="background: pink; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Alzheimer's disease
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">Disease</span>
# </mark>
#  (
# <mark class="entity" style="background: pink; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AD
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">Disease</span>
# </mark>
# ) associated with tau pathology. Because tau typically accumulates in response to
# <mark class="entity" style="background: violet; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     amyloid
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">Chemical</span>
# </mark>
#  beta (Aβ), we tested whether
# <mark class="entity" style="background: aqua; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     BIN1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">Gene</span>
# </mark>
#
# <mark class="entity" style="background: moccasin; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     rs744373
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">SNP</span>
# </mark>
#  accelerates Aβ-related tau accumulation. METHODS: We included two samples (Alzheimer's Disease Neuroimaging Initiative [ADNI], n = 153; Biomarkers for Identifying
# <mark class="entity" style="background: pink; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Neurodegenerative Disorders
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">Disease</span>
# </mark>
#  Early and Reliably [BioFINDER], n = 63) with
# <mark class="entity" style="background: pink; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     longitudinal
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">Disease</span>
# </mark>
#  (18)
# <mark class="entity" style="background: violet; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     F-Flortaucipir positron
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">Chemical</span>
# </mark>
#  emission tomography (PET), Aβ biomarkers, and
# <mark class="entity" style="background: pink; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     longitudinal cognitive
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">Disease</span>
# </mark>
#  assessments. We assessed whether
# <mark class="entity" style="background: aqua; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     BIN1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">Gene</span>
# </mark>
#
# <mark class="entity" style="background: moccasin; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     rs744373
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">SNP</span>
# </mark>
#  was associated with faster tau-PET accumulation at a given level of Aβ and whether faster
# <mark class="entity" style="background: aqua; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     BIN1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">Gene</span>
# </mark>
#
# <mark class="entity" style="background: moccasin; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     rs744373
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">SNP</span>
# </mark>
# -associated tau-PET accumulation mediated cognitive decline. RESULTS:
# <mark class="entity" style="background: aqua; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     BIN1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">Gene</span>
# </mark>
#
# <mark class="entity" style="background: moccasin; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     rs744373
#     <span style=

# %% [markdown]
# ### combine the annotation spans from NIO and PTC
# - leave the duplications there
# - filtering duplications: when the text spans are the same, the grounding will be the PTC's. We are not removing the duplications for the same starting index but different ending indices. We are not removing the duplications for the mentions with different grounded results (different identifiers or different ontological concepts).

# %% [markdown]
# #### the combined annotations without filtering duplications

# %%
# NIO annotations - docs_text
# PTC annotations - ptc_docs_text

a = defaultdict(list) 

for elem in ptc_docs_text:
    a[(elem['title'],elem['text'])].extend(elem['ents'])

for elem in docs_text:
    a[(elem['title'],elem['text'])].extend(elem['ents'])

Output = [{"title":x[0], 'text':x[1], "ents": sorted(y, key=lambda x: x['span'])} for x, y in a.items()]

# %%
len(Output)
# Out:
# 10

# %%
Output[0]
# Out:
# {'title': 'NLM_34060233',
#  'text': "The BIN1 rs744373 Alzheimer's disease risk SNP is associated with faster Aβ-associated tau accumulation and cognitive decline.INTRODUCTION: The BIN1 rs744373 single nucleotide polymorphism (SNP) is a key genetic risk locus for Alzheimer's disease (AD) associated with tau pathology. Because tau typically accumulates in response to amyloid beta (Aβ), we tested whether BIN1 rs744373 accelerates Aβ-related tau accumulation. METHODS: We included two samples (Alzheimer's Disease Neuroimaging Initiative [ADNI], n\xa0=\xa0153; Biomarkers for Identifying Neurodegenerative Disorders Early and Reliably [BioFINDER], n\xa0=\xa063) with longitudinal (18) F-Flortaucipir positron emission tomography (PET), Aβ biomarkers, and longitudinal cognitive assessments. We assessed whether BIN1 rs744373 was associated with faster tau-PET accumulation at a given level of Aβ and whether faster BIN1 rs744373-associated tau-PET accumulation mediated cognitive decline. RESULTS: BIN1 rs744373 risk-allele carriers showed faster global tau-PET accumulation (ADNI/BioFINDER, P\xa0<\xa0.001/P\xa0<\xa0.001). We found significant Aβ by rs744373 interactions on global tau-PET change (ADNI: β/standard error [SE]\xa0=\xa00.42/0.14, P\xa0=\xa00.002; BioFINDER: β/SE\xa0=\xa0-0.35/0.15, P\xa0=\xa0.021), BIN1 risk-allele carriers showed accelerated tau-PET accumulation at higher Aβ levels. In ADNI, rs744373 effects on cognitive decline were mediated by faster global tau-PET accumulation (β/SE\xa0=\xa00.20/0.07, P\xa0=\xa0.005). DISCUSSION: BIN1-associated AD risk is potentially driven by accelerated tau accumulation in the face of Aβ.",
#  'ents': [{'span': (4, 8),
#    'mention': 'BIN1',
#    'identifier': '274',
#    'concept': '',
#    'type': 'Gene',
#    'annotator': 'PTC'},
#   {'span': (4, 8),
#    'mention': 'BIN1',
#    'identifier': 'AlzheimerOntology:BIN1',
#    'concept': 'BIN1',
#    'type': '',
#    'annotator': 'NIO'},
#   {'span': (9, 17),
#    'mention': 'rs744373',
#    'identifier': 'rs744373',
#    'concept': '',
#    'type': 'SNP',
#    'annotator': 'PTC'},
#   {'span': (18, 27),
#    'mention': 'Alzheimer',
#    'identifier': 'AlzheimerOntology:Subtypes',
#    'concept': 'Alzheimer disease',
#    'type': '',
#    'annotator': 'NIO'},
#   {'span': (18, 29),
#    'mention': "Alzheimer's",
#    'identifier': 'AlzheimerOntology:Subtypes',
#    'concept': 'Alzheimer disease',
#    'type': '',
#    'annotator': 'NIO'},
#   {'span': (18, 37),
#    'mention': "Alzheimer's disease",
#    'identifier': 'MESH:D000544',
#    'concept': '',
#    'type': 'Disease',
#    'annotator': 'PTC'},
#   {'span': (18, 37),
#    'mention': "Alzheimer's disease",
#    'identifier': 'AlzheimerOntology:Subtypes',
#    'concept': 'Alzheimer disease',
#    'type': '',
#    'annotator': 'NIO'},
#   {'span': (30, 37),
#    'mention': 'disease',
#    'identifier': 'obo:OGMS_0000031',
#    'concept': 'disease',
#    'type': '',
#    'annotator': 'NIO'},
#   {'span': (30, 37),
#    'mention': 'disease',
#    'identifier': 'NDDUO:disease',
#    'concept': 'disease',
#    'type': '',
#    'annotator': 'NIO'},
#   {'span': (38, 42),
#    'mention': 'risk',
#    'identifier': 'NDDUO:Risk_factor',
#    'concept': 'Risk factor',
#    'type': '',
#    'annotator': 'NIO'},
#   {'span': (43, 46),
#    'mention': 'SNP',
#    'identifier': 'none',
#    'concept': '',
#    'type': 'Disease',
#    'annotator': 'PTC'},
#   {'span': (87, 90),
#    'mention': 'tau',
#    'identifier': 'AlzheimerOntology:t_tau',
#    'concept': 't-tau',
#    'type': '',
#    'annotator': 'NIO'},
#   {'span': (108, 117),
#    'mention': 'cognitive',
#    'identifier': 'AlzheimerOntology:Cognitive_Tests',
#    'concept': 'Cognitive Test',
#    'type': '',
#    'annotator': 'NIO'},
#   {'span': (108, 125),
#    'mention': 'cognitive decline',
#    'identifier': 'AlzheimerOntology:Moderate_cognitive_Decline',
#    'concept': 'Moderate cognitive Decline',
#    'type': '',
#    'annotator': 'NIO'},
#   {'span': (108, 125),
#    'mention': 'cognitive decline',
#    'identifier': 'AlzheimerOntology:mental_disorder',
#    'concept': 'mental disorder',
#    'type': '',
#    'annotator': 'NIO'},
#   {'span': (144, 148),
#    'mention': 'BIN1',
#    'identifier': '274',
#    'concept': '',
#    'type': 'Gene',
#    'annotator': 'PTC'},
#   {'span': (144, 148),
#    'mention': 'BIN1',
#    'identifier': 'AlzheimerOntology:BIN1',
#    'concept': 'BIN1',
#    'type': '',
#    'annotator': 'NIO'},
#   {'span': (149, 157),
#    'mention': 'rs744373',
#    'identifier': 'rs744373',
#    'concept': '',
#    'type': 'SNP',
#    'annotator': 'PTC'},
#   {'span': (190, 193),
#    'mention': 'SNP',
#    'identifier': 'none',
#    'concept': '',
#    'type': 'Disease',
#    'annotator': 'PTC'},
#   {'span': (212, 216),
#    'mention': 'risk',
#    'identifier': 'NDDUO:Risk_factor',
#    'concept': 'Risk factor',
#    'type': '',
#    'annotator': 'NIO'},
#   {'span': (227, 236),
#    'mention': 'Alzheimer',
#    'identifier': 'AlzheimerOntology:Subtypes',
#    'concept': 'Alzheimer disease',
#    'type': '',
#    'annotator': 'NIO'},
#   {'span': (227, 238),
#    'mention': "Alzheimer's",
#    'identifier': 'AlzheimerOntology:Subtypes',
#    'concept': 'Alzheimer disease',
#    'type': '',
#    'annotator': 'NIO'},
#   {'span': (227, 246),
#    'mention': "Alzheimer's disease",
#    'identifier': 'MESH:D000544',
#    'concept': '',
#    'type': 'Disease',
#    'annotator': 'PTC'},
#   {'span': (227, 246),
#    'mention': "Alzheimer's disease",
#    'identifier': 'AlzheimerOntology:Subtypes',
#    'concept': 'Alzheimer disease',
#    'type': '',
#    'annotator': 'NIO'},
#   {'span': (239, 246),
#    'mention': 'disease',
#    'identifier': 'obo:OGMS_0000031',
#    'concept': 'disease',
#    'type': '',
#    'annotator': 'NIO'},
#   {'span': (239, 246),
#    'mention': 'disease',
#    'identifier': 'NDDUO:disease',
#    'concept': 'disease',
#    'type': '',
#    'annotator': 'NIO'},
#   {'span': (248, 250),
#    'mention': 'AD',
#    'identifier': 'MESH:D000544',
#    'concept': '',
#    'type': 'Disease',
#    'annotator': 'PTC'},
#   {'span': (248, 250),
#    'mention': 'AD',
#    'identifier': 'AlzheimerOntology:Subtypes',
#    'concept': 'Alzheimer disease',
#    'type': '',
#    'annotator': 'NIO'},
#   {'span': (268, 271),
#    'mention': 'tau',
#    'identifier': 'AlzheimerOntology:t_tau',
#    'concept': 't-tau',
#    'type': '',
#    'annotator': 'NIO'},
#   {'span': (268, 281),
#    'mention': 'tau pathology',
#    'identifier': 'AlzheimerOntology:tauopathy',
#    'concept': 'tauopathy',
#    'type': '',
#    'annotator': 'NIO'},
#   {'span': (291, 294),
#    'mention': 'tau',
#    'identifier': 'AlzheimerOntology:t_tau',
#    'concept': 't-tau',
#    'type': '',
#    'annotator': 'NIO'},
#   {'span': (332, 339),
#    'mention': 'amyloid',
#    'identifier': 'MESH:D016229',
#    'concept': '',
#    'type': 'Chemical',
#    'annotator': 'PTC'},
#   {'span': (332, 339),
#    'mention': 'amyloid',
#    'identifier': 'AlzheimerOntology:amyloid_beta_protein',
#    'concept': 'amyloid beta protein',
#    'type': '',
#    'annotator': 'NIO'},
#   {'span': (332, 344),
#    'mention': 'amyloid beta',
#    'identifier': 'AlzheimerOntology:amyloid_beta_protein',
#    'concept': 'amyloid beta protein',
#    'type': '',
#    'annotator': 'NIO'},
#   {'span': (369, 373),
#    'mention': 'BIN1',
#    'identifier': '274',
#    'concept': '',
#    'type': 'Gene',
#    'annotator': 'PTC'},
#   {'span': (369, 373),
#    'mention': 'BIN1',
#    'identifier': 'AlzheimerOntology:BIN1',
#    'concept': 'BIN1',
#    'type': '',
#    'annotator': 'NIO'},
#   {'span': (374, 382),
#    'mention': 'rs744373',
#    'identifier': 'rs744373',
#    'concept': '',
#    'type': 'SNP',
#    'annotator': 'PTC'},
#   {'span': (406, 409),
#    'mention': 'tau',
#    'identifier': 'AlzheimerOntology:t_tau',
#    'concept': 't-tau',
#    'type': '',
#    'annotator': 'NIO'},
#   {'span': (449, 456),
#    'mention': 'samples',
#    'identifier': 'NDDUO:Sampling',
#    'concept': 'Sampling',
#    'type': '',
#    'annotator': 'NIO'},
#   {'span': (458, 467),
#    'mention': 'Alzheimer',
#    'identifier': 'AlzheimerOntology:Subtypes',
#    'concept': 'Alzheimer disease',
#    'type': '',
#    'annotator': 'NIO'},
#   {'span': (458, 469),
#    'mention': "Alzheimer's",
#    'identifier': 'AlzheimerOntology:Subtypes',
#    'concept': 'Alzheimer disease',
#    'type': '',
#    'annotator': 'NIO'},
#   {'span': (458, 477),
#    'mention': "Alzheimer's Disease",
#    'identifier': 'AlzheimerOntology:Subtypes',
#    'concept': 'Alzheimer disease',
#    'type': '',
#    'annotator': 'NIO'},
#   {'span': (458, 501),
#    'mention': "Alzheimer's Disease Neuroimaging Initiative",
#    'identifier': 'AlzheimerOntology:neuroimaging',
#    'concept': 'neuroimaging',
#    'type': '',
#    'annotator': 'NIO'},
#   {'span': (470, 477),
#    'mention': 'Disease',
#    'identifier': 'obo:OGMS_0000031',
#    'concept': 'disease',
#    'type': '',
#    'annotator': 'NIO'},
#   {'span': (470, 477),
#    'mention': 'Disease',
#    'identifier': 'NDDUO:disease',
#    'concept': 'disease',
#    'type': '',
#    'annotator': 'NIO'},
#   {'span': (478, 490),
#    'mention': 'Neuroimaging',
#    'identifier': 'AlzheimerOntology:neuroimaging',
#    'concept': 'neuroimaging',
#    'type': '',
#    'annotator': 'NIO'},
#   {'span': (503, 507),
#    'mention': 'ADNI',
#    'identifier': 'AlzheimerOntology:neuroimaging',
#    'concept': 'neuroimaging',
#    'type': '',
#    'annotator': 'NIO'},
#   {'span': (519, 529),
#    'mention': 'Biomarkers',
#    'identifier': 'AlzheimerOntology:procedures_using_biomarkers',
#    'concept': 'thing related to procedure using biomarkers',
#    'type': '',
#    'annotator': 'NIO'},
#   {'span': (519, 529),
#    'mention': 'Biomarkers',
#    'identifier': 'NDDUO:biomarker',
#    'concept': 'biomarker',
#    'type': '',
#    'annotator': 'NIO'},
#   {'span': (546, 573),
#    'mention': 'Neurodegenerative Disorders',
#    'identifier': 'MESH:D019636',
#    'concept': '',
#    'type': 'Disease',
#    'annotator': 'PTC'},
#   {'span': (546, 573),
#    'mention': 'Neurodegenerative Disorders',
#    'identifier': 'NDDUO:disorder',
#    'concept': 'disorder',
#    'type': '',
#    'annotator': 'NIO'},
#   {'span': (546, 573),
#    'mention': 'Neurodegenerative Disorders',
#    'identifier': 'NDDUO:neurodegenerative_disease',
#    'concept': 'neurodegenerative disease',
#    'type': '',
#    'annotator': 'NIO'},
#   {'span': (564, 573),
#    'mention': 'Disorders',
#    'identifier': 'NDDUO:disorder',
#    'concept': 'disorder',
#    'type': '',
#    'annotator': 'NIO'},
#   {'span': (619, 631),
#    'mention': 'longitudinal',
#    'identifier': 'MESH:D017887',
#    'concept': '',
#    'type': 'Disease',
#    'annotator': 'PTC'},
#   {'span': (637, 660),
#    'mention': 'F-Flortaucipir positron',
#    'identifier': 'MESH:D005461',
#    'concept': '',
#    'type': 'Chemical',
#    'annotator': 'PTC'},
#   {'span': (652, 680),
#    'mention': 'positron emission tomography',
#    'identifier': 'AlzheimerOntology:Positron_emission_tomography',
#    'concept': 'Positron emission tomography',
#    'type': '',
#    'annotator': 'NIO'},
#   {'span': (682, 685),
#    'mention': 'PET',
#    'identifier': 'AlzheimerOntology:Positron_emission_tomography',
#    'concept': 'Positron emission tomography',
#    'type': '',
#    'annotator': 'NIO'},
#   {'span': (691, 701),
#    'mention': 'biomarkers',
#    'identifier': 'AlzheimerOntology:procedures_using_biomarkers',
#    'concept': 'thing related to procedure using biomarkers',
#    'type': '',
#    'annotator': 'NIO'},
#   {'span': (691, 701),
#    'mention': 'biomarkers',
#    'identifier': 'NDDUO:biomarker',
#    'concept': 'biomarker',
#    'type': '',
#    'annotator': 'NIO'},
#   {'span': (707, 729),
#    'mention': 'longitudinal cognitive',
#    'identifier': 'MESH:D003072',
#    'concept': '',
#    'type': 'Disease',
#    'annotator': 'PTC'},
#   {'span': (720, 729),
#    'mention': 'cognitive',
#    'identifier': 'AlzheimerOntology:Cognitive_Tests',
#    'concept': 'Cognitive Test',
#    'type': '',
#    'annotator': 'NIO'},
#   {'span': (763, 767),
#    'mention': 'BIN1',
#    'identifier': '274',
#    'concept': '',
#    'type': 'Gene',
#    'annotator': 'PTC'},
#   {'span': (763, 767),
#    'mention': 'BIN1',
#    'identifier': 'AlzheimerOntology:BIN1',
#    'concept': 'BIN1',
#    'type': '',
#    'annotator': 'NIO'},
#   {'span': (768, 776),
#    'mention': 'rs744373',
#    'identifier': 'rs744373',
#    'concept': '',
#    'type': 'SNP',
#    'annotator': 'PTC'},
#   {'span': (804, 807),
#    'mention': 'tau',
#    'identifier': 'AlzheimerOntology:t_tau',
#    'concept': 't-tau',
#    'type': '',
#    'annotator': 'NIO'},
#   {'span': (808, 811),
#    'mention': 'PET',
#    'identifier': 'AlzheimerOntology:Positron_emission_tomography',
#    'concept': 'Positron emission tomography',
#    'type': '',
#    'annotator': 'NIO'},
#   {'span': (867, 871),
#    'mention': 'BIN1',
#    'identifier': '274',
#    'concept': '',
#    'type': 'Gene',
#    'annotator': 'PTC'},
#   {'span': (867, 871),
#    'mention': 'BIN1',
#    'identifier': 'AlzheimerOntology:BIN1',
#    'concept': 'BIN1',
#    'type': '',
#    'annotator': 'NIO'},
#   {'span': (872, 880),
#    'mention': 'rs744373',
#    'identifier': 'rs744373',
#    'concept': '',
#    'type': 'SNP',
#    'annotator': 'PTC'},
#   {'span': (892, 895),
#    'mention': 'tau',
#    'identifier': 'AlzheimerOntology:t_tau',
#    'concept': 't-tau',
#    'type': '',
#    'annotator': 'NIO'},
#   {'span': (896, 899),
#    'mention': 'PET',
#    'identifier': 'AlzheimerOntology:Positron_emission_tomography',
#    'concept': 'Positron emission tomography',
#    'type': '',
#    'annotator': 'NIO'},
#   {'span': (922, 931),
#    'mention': 'cognitive',
#    'identifier': 'AlzheimerOntology:Cognitive_Tests',
#    'concept': 'Cognitive Test',
#    'type': '',
#    'annotator': 'NIO'},
#   {'span': (922, 939),
#    'mention': 'cognitive decline',
#    'identifier': 'AlzheimerOntology:Moderate_cognitive_Decline',
#    'concept': 'Moderate cognitive Decline',
#    'type': '',
#    'annotator': 'NIO'},
#   {'span': (922, 939),
#    'mention': 'cognitive decline',
#    'identifier': 'AlzheimerOntology:mental_disorder',
#    'concept': 'mental disorder',
#    'type': '',
#    'annotator': 'NIO'},
#   {'span': (950, 954),
#    'mention': 'BIN1',
#    'identifier': '274',
#    'concept': '',
#    'type': 'Gene',
#    'annotator': 'PTC'},
#   {'span': (950, 954),
#    'mention': 'BIN1',
#    'identifier': 'AlzheimerOntology:BIN1',
#    'concept': 'BIN1',
#    'type': '',
#    'annotator': 'NIO'},
#   {'span': (955, 963),
#    'mention': 'rs744373',
#    'identifier': 'rs744373',
#    'concept': '',
#    'type': 'SNP',
#    'annotator': 'PTC'},
#   {'span': (964, 968),
#    'mention': 'risk',
#    'identifier': 'NDDUO:Risk_factor',
#    'concept': 'Risk factor',
#    'type': '',
#    'annotator': 'NIO'},
#   {'span': (1006, 1009),
#    'mention': 'tau',
#    'identifier': 'AlzheimerOntology:t_tau',
#    'concept': 't-tau',
#    'type': '',
#    'annotator': 'NIO'},
#   {'span': (1010, 1013),
#    'mention': 'PET',
#    'identifier': 'AlzheimerOntology:Positron_emission_tomography',
#    'concept': 'Positron emission tomography',
#    'type': '',
#    'annotator': 'NIO'},
#   {'span': (1028, 1032),
#    'mention': 'ADNI',
#    'identifier': 'AlzheimerOntology:neuroimaging',
#    'concept': 'neuroimaging',
#    'type': '',
#    'annotator': 'NIO'},
#   {'span': (1091, 1099),
#    'mention': 'rs744373',
#    'identifier': 'rs744373',
#    'concept': '',
#    'type': 'SNP',
#    'annotator': 'PTC'},
#   {'span': (1123, 1126),
#    'mention': 'tau',
#    'identifier': 'AlzheimerOntology:t_tau',
#    'concept': 't-tau',
#    'type': '',
#    'annotator': 'NIO'},
#   {'span': (1127, 1130),
#    'mention': 'PET',
#    'identifier': 'AlzheimerOntology:Positron_emission_tomography',
#    'concept': 'Positron emission tomography',
#    'type': '',
#    'annotator': 'NIO'},
#   {'span': (1139, 1143),
#    'mention': 'ADNI',
#    'identifier': 'AlzheimerOntology:neuroimaging',
#    'concept': 'neuroimaging',
#    'type': '',
#    'annotator': 'NIO'},
#   {'span': (1232, 1236),
#    'mention': 'BIN1',
#    'identifier': '274',
#    'concept': '',
#    'type': 'Gene',
#    'annotator': 'PTC'},
#   {'span': (1232, 1236),
#    'mention': 'BIN1',
#    'identifier': 'AlzheimerOntology:BIN1',
#    'concept': 'BIN1',
#    'type': '',
#    'annotator': 'NIO'},
#   {'span': (1237, 1241),
#    'mention': 'risk',
#    'identifier': 'NDDUO:Risk_factor',
#    'concept': 'Risk factor',
#    'type': '',
#    'annotator': 'NIO'},
#   {'span': (1277, 1280),
#    'mention': 'tau',
#    'identifier': 'AlzheimerOntology:t_tau',
#    'concept': 't-tau',
#    'type': '',
#    'annotator': 'NIO'},
#   {'span': (1281, 1284),
#    'mention': 'PET',
#    'identifier': 'AlzheimerOntology:Positron_emission_tomography',
#    'concept': 'Positron emission tomography',
#    'type': '',
#    'annotator': 'NIO'},
#   {'span': (1322, 1326),
#    'mention': 'ADNI',
#    'identifier': 'AlzheimerOntology:neuroimaging',
#    'concept': 'neuroimaging',
#    'type': '',
#    'annotator': 'NIO'},
#   {'span': (1328, 1336),
#    'mention': 'rs744373',
#    'identifier': 'rs744373',
#    'concept': '',
#    'type': 'SNP',
#    'annotator': 'PTC'},
#   {'span': (1348, 1357),
#    'mention': 'cognitive',
#    'identifier': 'AlzheimerOntology:Cognitive_Tests',
#    'concept': 'Cognitive Test',
#    'type': '',
#    'annotator': 'NIO'},
#   {'span': (1348, 1365),
#    'mention': 'cognitive decline',
#    'identifier': 'AlzheimerOntology:Moderate_cognitive_Decline',
#    'concept': 'Moderate cognitive Decline',
#    'type': '',
#    'annotator': 'NIO'},
#   {'span': (1348, 1365),
#    'mention': 'cognitive decline',
#    'identifier': 'AlzheimerOntology:mental_disorder',
#    'concept': 'mental disorder',
#    'type': '',
#    'annotator': 'NIO'},
#   {'span': (1397, 1400),
#    'mention': 'tau',
#    'identifier': 'AlzheimerOntology:t_tau',
#    'concept': 't-tau',
#    'type': '',
#    'annotator': 'NIO'},
#   {'span': (1401, 1404),
#    'mention': 'PET',
#    'identifier': 'AlzheimerOntology:Positron_emission_tomography',
#    'concept': 'Positron emission tomography',
#    'type': '',
#    'annotator': 'NIO'},
#   {'span': (1460, 1464),
#    'mention': 'BIN1',
#    'identifier': '274',
#    'concept': '',
#    'type': 'Gene',
#    'annotator': 'PTC'},
#   {'span': (1460, 1464),
#    'mention': 'BIN1',
#    'identifier': 'AlzheimerOntology:BIN1',
#    'concept': 'BIN1',
#    'type': '',
#    'annotator': 'NIO'},
#   {'span': (1476, 1478),
#    'mention': 'AD',
#    'identifier': 'MESH:D000544',
#    'concept': '',
#    'type': 'Disease',
#    'annotator': 'PTC'},
#   {'span': (1476, 1478),
#    'mention': 'AD',
#    'identifier': 'AlzheimerOntology:Subtypes',
#    'concept': 'Alzheimer disease',
#    'type': '',
#    'annotator': 'NIO'},
#   {'span': (1479, 1483),
#    'mention': 'risk',
#    'identifier': 'NDDUO:Risk_factor',
#    'concept': 'Risk factor',
#    'type': '',
#    'annotator': 'NIO'},
#   {'span': (1521, 1524),
#    'mention': 'tau',
#    'identifier': 'AlzheimerOntology:t_tau',
#    'concept': 't-tau',
#    'type': '',
#    'annotator': 'NIO'}]}

# %%
result_path
# Out:
# '/Users/yidesdo21/Projects/outputs/10_ptc_ten_recent/json/'

# %%
write_to_json(result_path, Output, output_file.replace("nio","combined"))

# %% [markdown]
# #### the combined annotations after filtering duplications

# %%
filtered_output = list()

for i in Output:
    filtered_dict = dict()
    ents = i["ents"]
    filtered_ents = list()
    start_end_set = set()
    filtered_dict["title"], filtered_dict["text"] = i["title"],i["text"]
    
    for ent in ents:
        start,end,label = ent["start"],ent["end"],ent["label"]
        span = (start,end)
        if span in start_end_set:
            continue
        else:
            start_end_set.add(span)
            filtered_ents.append(ent)
    
    filtered_dict["ents"] = filtered_ents
    filtered_output.append(filtered_dict)

# %%
filtered_output
# Out:
# [{'title': 'NLM_34060233',
#   'text': "The BIN1 rs744373 Alzheimer's disease risk SNP is associated with faster Aβ-associated tau accumulation and cognitive decline.INTRODUCTION: The BIN1 rs744373 single nucleotide polymorphism (SNP) is a key genetic risk locus for Alzheimer's disease (AD) associated with tau pathology. Because tau typically accumulates in response to amyloid beta (Aβ), we tested whether BIN1 rs744373 accelerates Aβ-related tau accumulation. METHODS: We included two samples (Alzheimer's Disease Neuroimaging Initiative [ADNI], n\xa0=\xa0153; Biomarkers for Identifying Neurodegenerative Disorders Early and Reliably [BioFINDER], n\xa0=\xa063) with longitudinal (18) F-Flortaucipir positron emission tomography (PET), Aβ biomarkers, and longitudinal cognitive assessments. We assessed whether BIN1 rs744373 was associated with faster tau-PET accumulation at a given level of Aβ and whether faster BIN1 rs744373-associated tau-PET accumulation mediated cognitive decline. RESULTS: BIN1 rs744373 risk-allele carriers showed faster global tau-PET accumulation (ADNI/BioFINDER, P\xa0<\xa0.001/P\xa0<\xa0.001). We found significant Aβ by rs744373 interactions on global tau-PET change (ADNI: β/standard error [SE]\xa0=\xa00.42/0.14, P\xa0=\xa00.002; BioFINDER: β/SE\xa0=\xa0-0.35/0.15, P\xa0=\xa0.021), BIN1 risk-allele carriers showed accelerated tau-PET accumulation at higher Aβ levels. In ADNI, rs744373 effects on cognitive decline were mediated by faster global tau-PET accumulation (β/SE\xa0=\xa00.20/0.07, P\xa0=\xa0.005). DISCUSSION: BIN1-associated AD risk is potentially driven by accelerated tau accumulation in the face of Aβ.",
#   'ents': [{'start': 4, 'end': 8, 'label': 'Gene'},
#    {'start': 9, 'end': 17, 'label': 'SNP'},
#    {'start': 18, 'end': 37, 'label': 'Disease'},
#    {'start': 38, 'end': 42, 'label': ''},
#    {'start': 43, 'end': 46, 'label': 'Disease'},
#    {'start': 87, 'end': 90, 'label': ''},
#    {'start': 108, 'end': 125, 'label': ''},
#    {'start': 144, 'end': 148, 'label': 'Gene'},
#    {'start': 149, 'end': 157, 'label': 'SNP'},
#    {'start': 190, 'end': 193, 'label': 'Disease'},
#    {'start': 212, 'end': 216, 'label': ''},
#    {'start': 227, 'end': 246, 'label': 'Disease'},
#    {'start': 248, 'end': 250, 'label': 'Disease'},
#    {'start': 268, 'end': 281, 'label': ''},
#    {'start': 291, 'end': 294, 'label': ''},
#    {'start': 332, 'end': 339, 'label': 'Chemical'},
#    {'start': 332, 'end': 344, 'label': ''},
#    {'start': 369, 'end': 373, 'label': 'Gene'},
#    {'start': 374, 'end': 382, 'label': 'SNP'},
#    {'start': 406, 'end': 409, 'label': ''},
#    {'start': 449, 'end': 456, 'label': ''},
#    {'start': 458, 'end': 501, 'label': ''},
#    {'start': 503, 'end': 507, 'label': ''},
#    {'start': 519, 'end': 529, 'label': ''},
#    {'start': 546, 'end': 573, 'label': 'Disease'},
#    {'start': 619, 'end': 631, 'label': 'Disease'},
#    {'start': 637, 'end': 660, 'label': 'Chemical'},
#    {'start': 652, 'end': 680, 'label': ''},
#    {'start': 682, 'end': 685, 'label': ''},
#    {'start': 691, 'end': 701, 'label': ''},
#    {'start': 707, 'end': 729, 'label': 'Disease'},
#    {'start': 720, 'end': 729, 'label': ''},
#    {'start': 763, 'end': 767, 'label': 'Gene'},
#    {'start': 768, 'end': 776, 'label': 'SNP'},
#    {'start': 804, 'end': 807, 'label': ''},
#    {'start': 808, 'end': 811, 'label': ''},
#    {'start': 867, 'end': 871, 'label': 'Gene'},
#    {'start': 872, 'end': 880, 'label': 'SNP'},
#    {'start': 892, 'end': 895, 'label': ''},
#    {'start': 896, 'end': 899, 'label': ''},
#    {'start': 922, 'end': 939, 'label': ''},
#    {'start': 950, 'end': 954, 'label': 'Gene'},
#    {'start': 955, 'end': 963, 'label': 'SNP'},
#    {'start': 964, 'end': 968, 'label': ''},
#    {'start': 1006, 'end': 1009, 'label': ''},
#    {'start': 1010, 'end': 1013, 'label': ''},
#    {'start': 1028, 'end': 1032, 'label': ''},
#    {'start': 1091, 'end': 1099, 'label': 'SNP'},
#    {'start': 1123, 'end': 1126, 'label': ''},
#    {'start': 1127, 'end': 1130, 'label': ''},
#    {'start': 1139, 'end': 1143, 'label': ''},
#    {'start': 1232, 'end': 1236, 'label': 'Gene'},
#    {'start': 1237, 'end': 1241, 'label': ''},
#    {'start': 1277, 'end': 1280, 'label': ''},
#    {'start': 1281, 'end': 1284, 'label': ''},
#    {'start': 1322, 'end': 1326, 'label': ''},
#    {'start': 1328, 'end': 1336, 'label': 'SNP'},
#    {'start': 1348, 'end': 1365, 'label': ''},
#    {'start': 1397, 'end': 1400, 'label': ''},
#    {'start': 1401, 'end': 1404, 'label': ''},
#    {'start': 1460, 'end': 1464, 'label': 'Gene'},
#    {'start': 1476, 'end': 1478, 'label': 'Disease'},
#    {'start': 1479, 'end': 1483, 'label': ''},
#    {'start': 1521, 'end': 1524, 'label': ''}]},
#  {'title': 'NLM_34095440',
#   'text': "Alzheimer's disease drug development pipeline: 2021.INTRODUCTION: The number of individuals worldwide with Alzheimer's disease (AD) is growing at a rapid rate. New treatments are urgently needed. We review the current pipeline of drugs in clinical trials for the treatment of AD. METHODS: We interrogated ClinicalTrials.gov, the federal registry of clinical trials to identify drugs in trials. RESULTS: There are 126 agents in 152 trials assessing new therapies for AD: 28 treatments in Phase 3 trials, 74 in Phase 2, and 24 in Phase 1. The majority of drugs in trials (82.5%) target the underlying biology of AD with the intent of disease modification; 10.3% are putative cognitive enhancing agents; and 7.1% are drugs being developed to reduce neuropsychiatric symptoms. DISCUSSION: This pipeline analysis shows that target biological processes are more diversified, biomarkers are more regularly used, and repurposed agents are being explored to determine their utility for the treatment of AD.",
#   'ents': [{'start': 0, 'end': 19, 'label': 'Disease'},
#    {'start': 20, 'end': 24, 'label': ''},
#    {'start': 107, 'end': 126, 'label': 'Disease'},
#    {'start': 128, 'end': 130, 'label': 'Disease'},
#    {'start': 154, 'end': 158, 'label': ''},
#    {'start': 164, 'end': 174, 'label': ''},
#    {'start': 230, 'end': 235, 'label': ''},
#    {'start': 239, 'end': 254, 'label': ''},
#    {'start': 263, 'end': 272, 'label': ''},
#    {'start': 276, 'end': 278, 'label': 'Disease'},
#    {'start': 349, 'end': 364, 'label': ''},
#    {'start': 377, 'end': 382, 'label': ''},
#    {'start': 466, 'end': 468, 'label': 'Disease'},
#    {'start': 473, 'end': 483, 'label': ''},
#    {'start': 487, 'end': 494, 'label': ''},
#    {'start': 509, 'end': 516, 'label': ''},
#    {'start': 528, 'end': 535, 'label': ''},
#    {'start': 553, 'end': 558, 'label': ''},
#    {'start': 610, 'end': 612, 'label': 'Disease'},
#    {'start': 632, 'end': 639, 'label': ''},
#    {'start': 673, 'end': 682, 'label': ''},
#    {'start': 714, 'end': 719, 'label': ''},
#    {'start': 746, 'end': 771, 'label': ''},
#    {'start': 837, 'end': 846, 'label': ''},
#    {'start': 851, 'end': 855, 'label': ''},
#    {'start': 869, 'end': 879, 'label': ''},
#    {'start': 884, 'end': 888, 'label': ''},
#    {'start': 981, 'end': 990, 'label': ''},
#    {'start': 994, 'end': 996, 'label': 'Disease'}]},
#  {'title': 'NLM_34101788',
#   'text': "Platform Trials to Expedite Drug Development in Alzheimer's Disease: A Report from the EU/US CTAD Task Force.A diverse range of platforms has been established to increase the efficiency and speed of clinical trials for Alzheimer's disease (AD). These platforms enable parallel assessment of multiple therapeutics, treatment regimens, or participant groups; use uniform protocols and outcome measures; and may allow treatment arms to be added or dropped based on interim analyses of outcomes. The EU/US CTAD Task Force discussed the lessons learned from the Dominantly Inherited Alzheimer's Network Trials Unit (DIAN-TU) platform trial and the challenges addressed by other platform trials that have launched or are in the planning stages. The landscape of clinical trial platforms in the AD space includes those testing experimental therapies such as DIAN-TU, platforms designed to test multidomain interventions, and those designed to streamline trial recruitment by building trial-ready cohorts. The heterogeneity of the AD patient population, AD drugs, treatment regimens, and analytical methods complicates the design and execution of platform trials, yet Task Force members concluded that platform trials are essential to advance the search for effective AD treatments, including combination therapies.",
#   'ents': [{'start': 28, 'end': 32, 'label': ''},
#    {'start': 48, 'end': 67, 'label': ''},
#    {'start': 199, 'end': 214, 'label': ''},
#    {'start': 219, 'end': 238, 'label': 'Disease'},
#    {'start': 240, 'end': 242, 'label': 'Disease'},
#    {'start': 314, 'end': 323, 'label': ''},
#    {'start': 337, 'end': 348, 'label': 'Species'},
#    {'start': 349, 'end': 355, 'label': ''},
#    {'start': 369, 'end': 378, 'label': ''},
#    {'start': 383, 'end': 399, 'label': ''},
#    {'start': 415, 'end': 424, 'label': ''},
#    {'start': 482, 'end': 490, 'label': ''},
#    {'start': 540, 'end': 547, 'label': ''},
#    {'start': 578, 'end': 587, 'label': 'Disease'},
#    {'start': 578, 'end': 589, 'label': ''},
#    {'start': 611, 'end': 618, 'label': 'Chemical'},
#    {'start': 667, 'end': 672, 'label': ''},
#    {'start': 722, 'end': 730, 'label': ''},
#    {'start': 731, 'end': 737, 'label': ''},
#    {'start': 756, 'end': 770, 'label': ''},
#    {'start': 788, 'end': 790, 'label': 'Disease'},
#    {'start': 851, 'end': 858, 'label': 'Chemical'},
#    {'start': 899, 'end': 912, 'label': ''},
#    {'start': 989, 'end': 996, 'label': ''},
#    {'start': 1023, 'end': 1025, 'label': 'Disease'},
#    {'start': 1026, 'end': 1033, 'label': 'Species'},
#    {'start': 1034, 'end': 1044, 'label': ''},
#    {'start': 1046, 'end': 1048, 'label': 'Disease'},
#    {'start': 1049, 'end': 1054, 'label': ''},
#    {'start': 1056, 'end': 1065, 'label': ''},
#    {'start': 1260, 'end': 1262, 'label': 'Disease'},
#    {'start': 1263, 'end': 1273, 'label': ''}]},
#  {'title': 'NLM_33730588',
#   'text': "The AD tau core spontaneously self-assembles and recruits full-length tau to filaments.Tau accumulation is a major pathological hallmark of Alzheimer's disease (AD) and other tauopathies, but the mechanism(s) of tau aggregation remains unclear. Taking advantage of the identification of tau filament cores by cryoelectron microscopy, we demonstrate that the AD tau core possesses the intrinsic ability to spontaneously aggregate in the absence of an inducer, with antibodies generated against AD tau core filaments detecting AD tau pathology. The AD tau core also drives aggregation of full-length wild-type tau, increases seeding potential, and templates abnormal forms of tau present in brain homogenates and antemortem cerebrospinal fluid (CSF) from patients with AD in an ultrasensitive real-time quaking-induced conversion (QuIC) assay. Finally, we show that the filament cores in corticobasal degeneration (CBD) and Pick's disease (PiD) similarly assemble into filaments under physiological conditions. These results document an approach to modeling tau aggregation and have significant implications for in\xa0vivo investigation of tau transmission and biomarker development.",
#   'ents': [{'start': 4, 'end': 6, 'label': ''},
#    {'start': 7, 'end': 10, 'label': ''},
#    {'start': 11, 'end': 15, 'label': ''},
#    {'start': 70, 'end': 73, 'label': ''},
#    {'start': 77, 'end': 86, 'label': ''},
#    {'start': 87, 'end': 90, 'label': ''},
#    {'start': 128, 'end': 159, 'label': 'Disease'},
#    {'start': 140, 'end': 159, 'label': ''},
#    {'start': 161, 'end': 163, 'label': ''},
#    {'start': 169, 'end': 174, 'label': ''},
#    {'start': 175, 'end': 186, 'label': 'Disease'},
#    {'start': 212, 'end': 227, 'label': 'Disease'},
#    {'start': 212, 'end': 215, 'label': ''},
#    {'start': 216, 'end': 227, 'label': ''},
#    {'start': 287, 'end': 290, 'label': ''},
#    {'start': 291, 'end': 299, 'label': ''},
#    {'start': 300, 'end': 305, 'label': ''},
#    {'start': 358, 'end': 360, 'label': ''},
#    {'start': 361, 'end': 364, 'label': ''},
#    {'start': 365, 'end': 369, 'label': ''},
#    {'start': 464, 'end': 474, 'label': ''},
#    {'start': 493, 'end': 495, 'label': ''},
#    {'start': 496, 'end': 499, 'label': ''},
#    {'start': 500, 'end': 504, 'label': ''},
#    {'start': 505, 'end': 514, 'label': ''},
#    {'start': 525, 'end': 527, 'label': ''},
#    {'start': 528, 'end': 541, 'label': ''},
#    {'start': 547, 'end': 549, 'label': ''},
#    {'start': 550, 'end': 553, 'label': ''},
#    {'start': 554, 'end': 558, 'label': ''},
#    {'start': 571, 'end': 582, 'label': ''},
#    {'start': 608, 'end': 611, 'label': ''},
#    {'start': 674, 'end': 677, 'label': ''},
#    {'start': 689, 'end': 694, 'label': ''},
#    {'start': 722, 'end': 741, 'label': ''},
#    {'start': 743, 'end': 746, 'label': ''},
#    {'start': 753, 'end': 761, 'label': 'Species'},
#    {'start': 767, 'end': 769, 'label': ''},
#    {'start': 835, 'end': 840, 'label': ''},
#    {'start': 868, 'end': 876, 'label': ''},
#    {'start': 877, 'end': 882, 'label': ''},
#    {'start': 886, 'end': 911, 'label': ''},
#    {'start': 922, 'end': 936, 'label': 'Disease'},
#    {'start': 929, 'end': 936, 'label': ''},
#    {'start': 967, 'end': 976, 'label': ''},
#    {'start': 1023, 'end': 1031, 'label': ''},
#    {'start': 1047, 'end': 1055, 'label': ''},
#    {'start': 1056, 'end': 1071, 'label': 'Disease'},
#    {'start': 1056, 'end': 1059, 'label': ''},
#    {'start': 1060, 'end': 1071, 'label': ''},
#    {'start': 1135, 'end': 1138, 'label': ''},
#    {'start': 1156, 'end': 1165, 'label': ''}]},
#  {'title': 'NLM_33988687',
#   'text': "Alzheimer mutant speeds APP transport.APPS198P segregates with rare familial forms of Alzheimer's disease and resides within exon 5, unlike 27 other mutations that reside in exons 16 or 17. In this issue, Zhang et al. (2021. J. Exp. Med.https://doi.org/10.1084/jem.20210313) show that the brains of APPS198P transgenic mice accumulate excess levels of Aβ. In cultured cells, APPS198P undergoes accelerated ER folding, leading to early arrival in late vesicular compartments, thereby enhancing generation of Aβ.",
#   'ents': [{'start': 0, 'end': 9, 'label': 'Disease'},
#    {'start': 24, 'end': 27, 'label': ''},
#    {'start': 86, 'end': 105, 'label': 'Disease'},
#    {'start': 143, 'end': 148, 'label': ''},
#    {'start': 149, 'end': 158, 'label': ''},
#    {'start': 289, 'end': 295, 'label': ''},
#    {'start': 308, 'end': 323, 'label': 'Species'},
#    {'start': 319, 'end': 323, 'label': ''},
#    {'start': 359, 'end': 373, 'label': ''}]},
#  {'title': 'NLM_33958804',
#   'text': "Neuronal ApoE upregulates MHC-I expression to drive selective neurodegeneration in Alzheimer's disease.Selective neurodegeneration is a critical causal factor in Alzheimer's disease (AD); however, the mechanisms that lead some neurons to perish, whereas others remain resilient, are unknown. We sought potential drivers of this selective vulnerability using single-nucleus RNA sequencing and discovered that ApoE expression level is a substantial driver of neuronal variability. Strikingly, neuronal expression of ApoE-which has a robust genetic linkage to AD-correlated strongly, on a cell-by-cell basis, with immune response pathways in neurons in the brains of wild-type mice, human ApoE knock-in mice and humans with or without AD. Elimination or over-expression of neuronal ApoE revealed a causal relationship among ApoE expression, neuronal MHC-I expression, tau pathology and neurodegeneration. Functional reduction of MHC-I ameliorated tau pathology in ApoE4-expressing primary neurons and in mouse hippocampi expressing pathological tau. These findings suggest a mechanism linking neuronal ApoE expression to MHC-I expression and, subsequently, to tau pathology and selective neurodegeneration.",
#   'ents': [{'start': 9, 'end': 13, 'label': 'Gene'},
#    {'start': 62, 'end': 79, 'label': 'Disease'},
#    {'start': 83, 'end': 102, 'label': 'Disease'},
#    {'start': 113, 'end': 130, 'label': 'Disease'},
#    {'start': 162, 'end': 181, 'label': 'Disease'},
#    {'start': 183, 'end': 185, 'label': 'Disease'},
#    {'start': 227, 'end': 234, 'label': ''},
#    {'start': 254, 'end': 260, 'label': ''},
#    {'start': 365, 'end': 372, 'label': ''},
#    {'start': 373, 'end': 376, 'label': ''},
#    {'start': 408, 'end': 412, 'label': 'Gene'},
#    {'start': 514, 'end': 518, 'label': 'Gene'},
#    {'start': 557, 'end': 559, 'label': 'Disease'},
#    {'start': 639, 'end': 646, 'label': ''},
#    {'start': 654, 'end': 660, 'label': ''},
#    {'start': 674, 'end': 678, 'label': 'Species'},
#    {'start': 680, 'end': 685, 'label': 'Species'},
#    {'start': 686, 'end': 690, 'label': 'Gene'},
#    {'start': 700, 'end': 704, 'label': 'Species'},
#    {'start': 709, 'end': 715, 'label': 'Species'},
#    {'start': 732, 'end': 734, 'label': 'Disease'},
#    {'start': 779, 'end': 783, 'label': 'Gene'},
#    {'start': 821, 'end': 825, 'label': 'Gene'},
#    {'start': 865, 'end': 878, 'label': ''},
#    {'start': 883, 'end': 900, 'label': 'Disease'},
#    {'start': 944, 'end': 957, 'label': ''},
#    {'start': 961, 'end': 966, 'label': ''},
#    {'start': 986, 'end': 993, 'label': ''},
#    {'start': 1001, 'end': 1006, 'label': 'Species'},
#    {'start': 1007, 'end': 1017, 'label': ''},
#    {'start': 1042, 'end': 1045, 'label': ''},
#    {'start': 1099, 'end': 1103, 'label': 'Gene'},
#    {'start': 1157, 'end': 1170, 'label': ''},
#    {'start': 1185, 'end': 1202, 'label': 'Disease'}]},
#  {'title': 'NLM_31721178',
#   'text': "Tau (297-391) forms filaments that structurally mimic the core of paired helical filaments in Alzheimer's disease brain.The constituent paired helical filaments (PHFs) in neurofibrillary tangles are insoluble intracellular deposits central to the development of Alzheimer's disease (AD) and other tauopathies. Full-length tau requires the addition of anionic cofactors such as heparin to enhance assembly. We have shown that a fragment from the proteolytically stable core of the PHF, tau 297-391 known as 'dGAE', spontaneously forms cross-β-containing PHFs and straight filaments under physiological conditions. Here, we have analysed and compared the structures of the filaments formed by dGAE in\xa0vitro with those deposited in the brains of individuals diagnosed with AD. We show that dGAE forms PHFs that share a macromolecular structure similar to those found in brain tissue. Thus, dGAEs may serve as a model system for studying core domain assembly and for screening for inhibitors of tau aggregation.",
#   'ents': [{'start': 0, 'end': 3, 'label': ''},
#    {'start': 20, 'end': 29, 'label': ''},
#    {'start': 58, 'end': 62, 'label': ''},
#    {'start': 81, 'end': 90, 'label': ''},
#    {'start': 94, 'end': 113, 'label': 'Disease'},
#    {'start': 114, 'end': 119, 'label': ''},
#    {'start': 151, 'end': 160, 'label': ''},
#    {'start': 171, 'end': 194, 'label': ''},
#    {'start': 262, 'end': 281, 'label': 'Disease'},
#    {'start': 283, 'end': 285, 'label': 'Disease'},
#    {'start': 291, 'end': 296, 'label': ''},
#    {'start': 297, 'end': 308, 'label': 'Disease'},
#    {'start': 322, 'end': 325, 'label': ''},
#    {'start': 377, 'end': 384, 'label': 'Chemical'},
#    {'start': 468, 'end': 472, 'label': ''},
#    {'start': 485, 'end': 488, 'label': ''},
#    {'start': 571, 'end': 580, 'label': ''},
#    {'start': 671, 'end': 680, 'label': ''},
#    {'start': 733, 'end': 739, 'label': ''},
#    {'start': 770, 'end': 772, 'label': 'Disease'},
#    {'start': 867, 'end': 879, 'label': ''},
#    {'start': 908, 'end': 913, 'label': ''},
#    {'start': 925, 'end': 933, 'label': ''},
#    {'start': 934, 'end': 938, 'label': ''},
#    {'start': 963, 'end': 972, 'label': ''},
#    {'start': 977, 'end': 987, 'label': ''},
#    {'start': 991, 'end': 1006, 'label': 'Disease'},
#    {'start': 991, 'end': 994, 'label': ''},
#    {'start': 995, 'end': 1006, 'label': ''}]},
#  {'title': 'CCC_000637925000033',
#   'text': 'Glycoengineering artificial receptors for microglia to phagocytose A beta aggregates.Oligomeric and fibrillar amyloid-beta (A beta) are principally internalized via receptor-mediated endocytosis (RME) by microglia, the main scavenger of A beta in the brain. Nevertheless, the inflammatory cascade will be evoked after vast A beta aggregate binding to pattern recognition receptors on the cell membrane, which then significantly decreases the expression of these receptors and further deteriorate A beta deposition. This vicious circle will weaken the ability of microglia for A beta elimination. Herein, a combination of metabolic glycoengineering and self-triggered click chemistry is utilized to engineer microglial membranes with ThS as artificial A beta receptors to promote microglia to phagocytose A beta aggregates. Additionally, to circumvent the undesirable immune response during the process of the bioorthogonal chemistry reaction and A beta-microglial interaction, Mn-porphyrin metal-organic frameworks (Mn-MOFs) with superoxide dismutase (SOD) and catalase (CAT) mimic activity are employed to carry N-azidoacetylmannosamine (AcManNAz) and eradicate over-expressed reactive oxygen species (ROSs). The artificial A beta receptors independent of a signal pathway involved in immunomodulation as well as Mn-MOFs with antioxidant properties can synergistically promote the phagocytosis and clearance of A beta with significantly enhanced activity and negligible adverse effects. The present study will not only provide valuable insight into the rational design of the microglial surface engineering strategy via bioorthogonal chemistry, but also hold great potential for other disease intervention associated with receptor starvation.',
#   'ents': [{'start': 28, 'end': 37, 'label': ''},
#    {'start': 42, 'end': 51, 'label': ''},
#    {'start': 67, 'end': 73, 'label': 'Gene'},
#    {'start': 110, 'end': 122, 'label': 'Chemical'},
#    {'start': 124, 'end': 130, 'label': 'Gene'},
#    {'start': 165, 'end': 173, 'label': ''},
#    {'start': 183, 'end': 194, 'label': ''},
#    {'start': 196, 'end': 199, 'label': 'Chemical'},
#    {'start': 204, 'end': 213, 'label': ''},
#    {'start': 237, 'end': 243, 'label': 'Gene'},
#    {'start': 251, 'end': 256, 'label': ''},
#    {'start': 276, 'end': 296, 'label': ''},
#    {'start': 323, 'end': 329, 'label': 'Gene'},
#    {'start': 371, 'end': 380, 'label': ''},
#    {'start': 393, 'end': 401, 'label': ''},
#    {'start': 462, 'end': 471, 'label': ''},
#    {'start': 496, 'end': 502, 'label': 'Gene'},
#    {'start': 562, 'end': 571, 'label': ''},
#    {'start': 576, 'end': 582, 'label': 'Gene'},
#    {'start': 718, 'end': 727, 'label': ''},
#    {'start': 751, 'end': 757, 'label': 'Gene'},
#    {'start': 758, 'end': 767, 'label': ''},
#    {'start': 779, 'end': 788, 'label': ''},
#    {'start': 804, 'end': 810, 'label': 'Gene'},
#    {'start': 894, 'end': 901, 'label': ''},
#    {'start': 946, 'end': 952, 'label': 'Gene'},
#    {'start': 977, 'end': 989, 'label': 'Chemical'},
#    {'start': 1016, 'end': 1023, 'label': 'Chemical'},
#    {'start': 1030, 'end': 1050, 'label': 'Gene'},
#    {'start': 1052, 'end': 1055, 'label': 'Gene'},
#    {'start': 1061, 'end': 1069, 'label': 'Gene'},
#    {'start': 1071, 'end': 1074, 'label': 'Gene'},
#    {'start': 1113, 'end': 1137, 'label': 'Chemical'},
#    {'start': 1187, 'end': 1193, 'label': 'Chemical'},
#    {'start': 1225, 'end': 1231, 'label': 'Gene'},
#    {'start': 1232, 'end': 1241, 'label': ''},
#    {'start': 1327, 'end': 1338, 'label': ''},
#    {'start': 1382, 'end': 1394, 'label': ''},
#    {'start': 1412, 'end': 1418, 'label': 'Gene'},
#    {'start': 1500, 'end': 1505, 'label': ''},
#    {'start': 1680, 'end': 1685, 'label': ''},
#    {'start': 1686, 'end': 1693, 'label': ''},
#    {'start': 1694, 'end': 1706, 'label': ''},
#    {'start': 1723, 'end': 1731, 'label': ''}]},
#  {'title': 'CCC_000647663200001',
#   'text': 'Impairment of visual cortical plasticity by amyloid-beta species.Introduction: A variety of transgenic and knock-in mice that express mutant alleles of Amyloid precursor protein (APP) have been used to model the effects of amyloid-beta (A?) on circuit function in Alzheimer?s disease (AD); however phenotypes described in these mice may be affected by expression of mutant APP or proteolytic cleavage products independent of A?. In addition, the effects of mutant APP expression are attributed to elevated expression of the amyloidogenic, 42-amino acid-long species of A? (A?42) associated with amyloid plaque accumulation in AD, though elevated concentrations of A?40, an A? species produced with normal synaptic activity, may also affect neural function. Methods: To explore the effects of elevated expression of A? on synaptic function in vivo, we assessed visual system plasticity in transgenic mice that express and secrete A? throughout the brain in the absence of APP overexpression. Transgenic mice that express either A?40 or A?42 were assayed for their ability to appropriately demonstrate ocular dominance plasticity following monocular deprivation. Results: Using two complementary approaches to measure the plastic response to monocular deprivation, we find that male and female mice that express either 40- or 42-amino acid?long A? species demonstrate a plasticity defect comparable to that elicited in transgenic mice that express mutant alleles of APP and Presenilin 1 (APP/PS1 mice). Conclusions: These data support the hypothesis that mutant APP-driven plasticity impairment in mouse models of AD is mediated by production and accumulation of A?. Moreover, these findings suggest that soluble species of A? are capable of modulating synaptic plasticity, likely independent of any aggregation. These findings may have implications for the role of soluble species of A? in both development and disease settings.',
#   'ents': [{'start': 0, 'end': 40, 'label': 'Disease'},
#    {'start': 44, 'end': 51, 'label': 'Chemical'},
#    {'start': 44, 'end': 56, 'label': ''},
#    {'start': 116, 'end': 120, 'label': 'Species'},
#    {'start': 152, 'end': 177, 'label': 'Gene'},
#    {'start': 179, 'end': 182, 'label': ''},
#    {'start': 202, 'end': 207, 'label': ''},
#    {'start': 223, 'end': 235, 'label': 'Chemical'},
#    {'start': 252, 'end': 260, 'label': ''},
#    {'start': 264, 'end': 273, 'label': 'Disease'},
#    {'start': 264, 'end': 283, 'label': ''},
#    {'start': 274, 'end': 283, 'label': 'Disease'},
#    {'start': 285, 'end': 287, 'label': 'Disease'},
#    {'start': 298, 'end': 308, 'label': ''},
#    {'start': 328, 'end': 332, 'label': 'Species'},
#    {'start': 373, 'end': 376, 'label': ''},
#    {'start': 464, 'end': 467, 'label': ''},
#    {'start': 524, 'end': 537, 'label': 'Chemical'},
#    {'start': 539, 'end': 552, 'label': 'Chemical'},
#    {'start': 595, 'end': 602, 'label': 'Chemical'},
#    {'start': 595, 'end': 609, 'label': ''},
#    {'start': 626, 'end': 628, 'label': 'Disease'},
#    {'start': 747, 'end': 755, 'label': ''},
#    {'start': 830, 'end': 838, 'label': ''},
#    {'start': 842, 'end': 846, 'label': ''},
#    {'start': 888, 'end': 903, 'label': 'Species'},
#    {'start': 899, 'end': 903, 'label': ''},
#    {'start': 947, 'end': 952, 'label': ''},
#    {'start': 971, 'end': 974, 'label': ''},
#    {'start': 991, 'end': 1006, 'label': 'Species'},
#    {'start': 1002, 'end': 1006, 'label': ''},
#    {'start': 1045, 'end': 1052, 'label': ''},
#    {'start': 1276, 'end': 1280, 'label': ''},
#    {'start': 1285, 'end': 1291, 'label': ''},
#    {'start': 1292, 'end': 1296, 'label': 'Species'},
#    {'start': 1324, 'end': 1337, 'label': 'Chemical'},
#    {'start': 1417, 'end': 1432, 'label': 'Species'},
#    {'start': 1428, 'end': 1432, 'label': ''},
#    {'start': 1464, 'end': 1467, 'label': ''},
#    {'start': 1472, 'end': 1484, 'label': 'Gene'},
#    {'start': 1486, 'end': 1489, 'label': ''},
#    {'start': 1490, 'end': 1493, 'label': 'Gene'},
#    {'start': 1494, 'end': 1498, 'label': 'Species'},
#    {'start': 1560, 'end': 1563, 'label': ''},
#    {'start': 1596, 'end': 1601, 'label': 'Species'},
#    {'start': 1596, 'end': 1608, 'label': ''},
#    {'start': 1612, 'end': 1614, 'label': 'Disease'},
#    {'start': 1798, 'end': 1809, 'label': ''},
#    {'start': 1856, 'end': 1863, 'label': ''},
#    {'start': 1910, 'end': 1917, 'label': ''}]},
#  {'title': 'CCC_000653155500009',
#   'text': "An excellent electrochemical aptasensor for amyloid-beta oligomers based on a triple-helix aptamer switch via target-triggered signal transduction DNA displacement events.An excellent aptasensor for electrochemical detection of amyloid-beta oligomers (A beta Os) at trace levels was fabricated based on a triple-helix aptamer switch (THAS) via target-triggered signal transduction DNA displacement events. Specifically, a single-stranded anti-A beta O aptamer (Apt) carrying two symmetrical arm segments was first attached via Au-S binding to an Au electrode. Gold nanoparticle (GNP)-tagged signal transduction probes (GNP-STPs) were simultaneously hybridized with the two arm segments of the Apt, and a rigid THAS was formed on the Au electrode. Compared to the conventional hybrid, the number of GNPs on the Au electrode increased significantly with the THAS, effectively improving the stability of the Apt to avoid lodging. Trithiocyanuric acid (TA) was utilized to further gather the GNPs and form network-like TA/GNPs. As a result, the differential pulse voltammetry (DPV) response of GNPs was clearly enhanced. When A beta Os were present, target-triggered signal transduction DNA displacement events were carried out from THAS via the reaction of the Apt with the A beta Os, which caused the GNP-STP to dissociate from the Au electrode, and thus a significant reduction in the DPV response was observed. The assay was able to sensitively detect trace A beta Os by monitoring the A beta O-controlled DPV response change. It exhibited a wide linear range from 1 fM to 10 pM with a low detection limit of 0.5 fM, and was successfully employed for the determination of A beta Os in 20 serum samples, with good recovery. Moreover, the developed assay can provide a sensitive and selective platform for many studies or investigations related to Alzheimer's disease (AD) monitoring and treatment.",
#   'ents': [{'start': 44, 'end': 51, 'label': 'Chemical'},
#    {'start': 44, 'end': 56, 'label': ''},
#    {'start': 228, 'end': 235, 'label': 'Chemical'},
#    {'start': 228, 'end': 240, 'label': ''},
#    {'start': 927, 'end': 947, 'label': 'Chemical'},
#    {'start': 949, 'end': 951, 'label': 'Chemical'},
#    {'start': 1010, 'end': 1014, 'label': ''},
#    {'start': 1015, 'end': 1017, 'label': 'Chemical'},
#    {'start': 1122, 'end': 1128, 'label': 'Gene'},
#    {'start': 1271, 'end': 1277, 'label': 'Gene'},
#    {'start': 1415, 'end': 1420, 'label': ''},
#    {'start': 1458, 'end': 1464, 'label': 'Gene'},
#    {'start': 1486, 'end': 1492, 'label': 'Gene'},
#    {'start': 1672, 'end': 1678, 'label': 'Gene'},
#    {'start': 1694, 'end': 1701, 'label': ''},
#    {'start': 1747, 'end': 1752, 'label': ''},
#    {'start': 1804, 'end': 1808, 'label': ''},
#    {'start': 1809, 'end': 1816, 'label': ''},
#    {'start': 1846, 'end': 1865, 'label': 'Disease'},
#    {'start': 1867, 'end': 1869, 'label': 'Disease'},
#    {'start': 1886, 'end': 1895, 'label': ''}]}]

# %%
displacy.render(filtered_output, style="ent", manual=True, 
                options={"colors":{"GENE":"aqua", "DISEASE":"pink", "CHEMICAL":"violet",
                                   "SNP":"moccasin", "SPECIES":"lightgreen"}})
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">NLM_34060233</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">The
# <mark class="entity" style="background: aqua; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     BIN1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">Gene</span>
# </mark>
#
# <mark class="entity" style="background: moccasin; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     rs744373
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">SNP</span>
# </mark>
#
# <mark class="entity" style="background: pink; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Alzheimer's disease
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">Disease</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     risk
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem"></span>
# </mark>
#
# <mark class="entity" style="background: pink; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     SNP
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">Disease</span>
# </mark>
#  is associated with faster Aβ-associated
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     tau
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem"></span>
# </mark>
#  accumulation and
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     cognitive decline
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem"></span>
# </mark>
# .INTRODUCTION: The
# <mark class="entity" style="background: aqua; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     BIN1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">Gene</span>
# </mark>
#
# <mark class="entity" style="background: moccasin; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     rs744373
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">SNP</span>
# </mark>
#  single nucleotide polymorphism (
# <mark class="entity" style="background: pink; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     SNP
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">Disease</span>
# </mark>
# ) is a key genetic
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     risk
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem"></span>
# </mark>
#  locus for
# <mark class="entity" style="background: pink; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Alzheimer's disease
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">Disease</span>
# </mark>
#  (
# <mark class="entity" style="background: pink; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AD
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">Disease</span>
# </mark>
# ) associated with
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     tau pathology
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem"></span>
# </mark>
# . Because
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     tau
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem"></span>
# </mark>
#  typically accumulates in response to
# <mark class="entity" style="background: violet; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     amyloid
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">Chemical</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     amyloid beta
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem"></span>
# </mark>
#  (Aβ), we tested whether
# <mark class="entity" style="background: aqua; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     BIN1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">Gene</span>
# </mark>
#
# <mark class="entity" style="background: moccasin; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     rs744373
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">SNP</span>
# </mark>
#  accelerates Aβ-related
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     tau
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem"></span>
# </mark>
#  accumulation. METHODS: We included two
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     samples
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem"></span>
# </mark>
#  (
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Alzheimer's Disease Neuroimaging Initiative
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem"></span>
# </mark>
#  [
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ADNI
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem"></span>
# </mark>
# ], n = 153;
# <mark class="enti

# %% [markdown]
# ### ignore the lines below

# %%
# html = displacy.render(docs, style="ent", manual=True, options={"colors":{}})

# %%
# # errors for the html
# html_path = "/Users/yidesdo21/Projects/outputs/03_annotation_with_articles/html/"
# with open(html_path+"test.html", "w") as f:
#     f.write(html)

# %%
ex = [{"text": "But Google is starting from behind.",
       "ents": [{"start": 4, "end": 10, "label": "ORG"},
                {"start": 4, "end": 13, "label": "TEST"}
               ],
       "title": "Test"},]
#      {"text": "But Google is starting from behind.",
#        "ents": [
# #                 {"start": 4, "end": 10, "label": "ORG"},
#                 {"start": 4, "end": 13, "label": "TEST"}
#                ],
#        "title": "Test"}]
html = displacy.render(ex, style="ent", manual=True, options={"colors":{}})
#                        {"colors":{"ORG":"yellow"}})
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">Test</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">But
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Google
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Google is
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">TEST</span>
# </mark>
#  starting from behind.</div></span>

# %%
from spacy.tokens import Doc

Doc.set_extension('my_ents', default=None, force=True)

def move_ents_to_attr(doc):
    if doc._.my_ents is None:
        doc._.my_ents = []
    doc._.my_ents.extend(doc.ents)
    doc.ents = []
    return doc


nlp = spacy.load("en_core_web_sm")
nlp.add_pipe(move_ents_to_attr, last=True)

# %%
nlp = spacy.load("en_core_web_sm")

# %%
# text = "But Google is starting from behind."
text = "When Sebastian Thrun started working on self-driving cars at Google in 2007, few people outside of the company took him seriously."
doc = nlp(text)

# %%
doc
# Out:
# When Sebastian Thrun started working on self-driving cars at Google in 2007, few people outside of the company took him seriously.

# %%
displacy.render(doc, style="ent", options={"colors":{}})
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">When
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sebastian Thrun
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  started working on self-driving cars at
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Google
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2007
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , few people outside of the company took him seriously.</div></span>
